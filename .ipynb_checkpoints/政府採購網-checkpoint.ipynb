# %%
from bs4 import BeautifulSoup
import time
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import win32gui, win32con
import base64
import sqlite3
import win32crypt
from cryptography.hazmat.primitives.ciphers.aead import AESGCM
import requests as rq
import re
import datetime
import pymysql
import time

# %%
#
url = "https://web.pcc.gov.tw/tps/pss/tender.do?method=goSearch&searchMode=common&searchType=basic"
url_head = "https://web.pcc.gov.tw/tps/pss"
response = rq.get(url,cookies={'over18': '1'})
html_doc = response.text
#解析表單的 option 值，用以放到 post api 的 tenderWay & tenderType欄位
soup = BeautifulSoup(html_doc, 'lxml')

pages_option_type_html=soup.select('select#tenderType option')
pages_option_type=[]
for i in pages_option_type_html:
    pages_option_type.append(i.get('value'))
print(pages_option_type)

pages_option_way=[]
for i in soup.select('select#tenderWay option'):
    try:
        int(i.get('value'))
    except:
        pages_option_way_all = i.get('value')
        continue
    pages_option_way.append({'code': i.get('value'),'text': i.text.strip()})
print(pages_option_way_all)
# Out:
# ['tenderDeclaration', 'searchAppeal', 'publicRead', 'predict']
# 1,2,3,4,5,6,7,10,12

# %%
def GetString(LocalState):
    with open(LocalState,'r',encoding='utf-8') as f:
        s=json.load(f)['os_crypt']['encrypted_key']
    return s

def pull_the_key(base64_encrypted_key):
    encrypted_key_with_header=base64.b64decode(base64_encrypted_key)
    encrypted_key=encrypted_key_with_header[5:]
    key=win32crypt.CryptUnprotectData(encrypted_key,None,None,None,0)[1]
    return key

def DecryptString(key,data):
    nonce,cipherbytes=data[3:15],data[15:]
    aesgcm=AESGCM(key)
    plainbytes=aesgcm.decrypt(nonce,cipherbytes,None)
    plaintext=plainbytes.decode('utf-8')
    return plaintext

def test_cookies():
    LocalState = r'C:\Users\User\AppData\Local\Google\Chrome\User Data\Local State' #密钥文件
    Cookies = r'C:\Users\User\AppData\Local\Google\Chrome\User Data\Default\Network\Cookies' #cookie文件
    
    con = sqlite3.connect(Cookies)
    res_cookie = con.execute('select host_key,name,encrypted_value from cookies where host_key like "%web.pcc.gov.tw%"').fetchall()
    key = pull_the_key(GetString(LocalState))        
    con.close()

#    字典回傳  
    datas={}
    for i in res_cookie:
        datas[i[1]]=DecryptString(key, i[2])
    return datas
cookie_data = test_cookies()

# %%
# tenderType == tenderDeclaration
#form_data = {'method':'search','searchMethod':'true','tenderUpdate':'','searchTarget':'','orgName':'','orgId':'','hid_1':'1','tenderName':'','tenderId':'','tenderType':'tenderDeclaration','tenderWay':pages_option_way_all,'tenderDateRadio':'on','tenderStartDateStr':'111/01/06','tenderEndDateStr':'111/01/12','tenderStartDate':'111/01/12','tenderEndDate':'111/01/12','isSpdt':'N','proctrgCate':'','btnQuery':'查詢','hadUpdated':''}
#r = rq.post('https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic', data = form_data)
def tenderDeclaration_crawler():
    r = rq.get('https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1', cookies = cookie_data)
    html_doc = r.text

    raw_datas=[]
    for ii in range(1,100):
        soup = BeautifulSoup(html_doc, 'lxml')
        data = soup.select('div#print_area table tr')
        for i in data[1:-1]:
            no=i.select('td')[0].text.strip()
            proposer_name=i.select('td')[1].text.strip()
            bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
            if i.select('td')[2].select('font'):
                ischange=1
            else:
                ischange=0       
            bid_name=i.select('td')[2].select('a')[0].text.strip()
            times=i.select('td')[3].text.strip()
            typ=i.select('td')[4].text.strip()
            clas=i.select('td')[5].text.strip()
            date=i.select('td')[6].text.strip()
            enddate=i.select('td')[7].text.strip()
            budget=i.select('td')[8].text.strip()
            raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange})
        all_data = int(data[-1].select('span')[0].text)
        if ii*100 > all_data:
            print(len(raw_datas))
            print(all_data)
            break    
        next_page = data[-1].select('a')[-2].get('href')
        url = url_head + next_page[1:]
        response = rq.get(url, cookies = cookie_data)
        html_doc = response.text
        
    return raw_datas

# %%
tenderDeclaration_data = tenderDeclaration_crawler()
# Out:
# 1182
# 1182
# [{'no': '1',
#   'proposer_name': '雲林縣虎尾鎮安慶國民小學',
#   'bid_no': 'B1110111',
#   'bid_name': '110年度改善及充實音樂團隊設備',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '2000000',
#   'ischange': 1},
#  {'no': '2',
#   'proposer_name': '行政院農業委員會花蓮區農業改良場',
#   'bid_no': '111B002-A',
#   'bid_name': '原鄉生態農業核心技術管理與社經效益展現專案協作',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '4000000',
#   'ischange': 0},
#  {'no': '3',
#   'proposer_name': '臺南市歸仁區歸南國民小學',
#   'bid_no': '202201CH63',
#   'bid_name': '歸南國小運動場及籃球場整建工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '6277809',
#   'ischange': 0},
#  {'no': '4',
#   'proposer_name': '臺北市大安區幸安國民小學',
#   'bid_no': '11022',
#   'bid_name': '臺北市幸安國小110學年度第二學期暨111學年度中央廚房勞務委外採購案',
#   'times': '02',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '20032200',
#   'ischange': 0},
#  {'no': '5',
#   'proposer_name': '嘉義縣大埔鄉公所',
#   'bid_no': '110120201',
#   'bid_name': '110年度大埔社區活動中心耐震補強計畫委託勘測設計及監造服務契約',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '170635',
#   'ischange': 0},
#  {'no': '6',
#   'proposer_name': '台灣自來水股份有限公司第七區管理處',
#   'bid_no': 'WR-10-130311-01',
#   'bid_name': '潮州營運所辦公廳新建工程委託技術服務',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '4062450',
#   'ischange': 0},
#  {'no': '7',
#   'proposer_name': '交通部臺灣鐵路管理局',
#   'bid_no': 'L0511E1003L',
#   'bid_name': '花蓮機務段維修庫及房舍設施改善工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '3706856',
#   'ischange': 0},
#  {'no': '8',
#   'proposer_name': '台灣中油股份有限公司',
#   'bid_no': '11BV01',
#   'bid_name': '臥式三相離心機含工作平台1套及安裝',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '',
#   'ischange': 0},
#  {'no': '9',
#   'proposer_name': '交通部觀光局東部海岸國家風景區管理處',
#   'bid_no': 'C11101',
#   'bid_name': '綠島多元主題旅遊設施優化工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '18961688',
#   'ischange': 0},
#  {'no': '10',
#   'proposer_name': '澎湖縣政府',
#   'bid_no': 'CW-1111006',
#   'bid_name': '澎湖縣享居社福養生園區新建工程(土建標)',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/02/10',
#   'budget': '191679600',
#   'ischange': 0},
#  {'no': '11',
#   'proposer_name': '澎湖縣政府',
#   'bid_no': 'CW-1111005',
#   'bid_name': '澎湖縣享居社福養生園區新建工程(機電標)',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/02/10',
#   'budget': '43207774',
#   'ischange': 0},
#  {'no': '12',
#   'proposer_name': '經濟部水利署第九河川局',
#   'bid_no': '111-B-004-02-002-018',
#   'bid_name': '111年度花蓮轄管海堤構造物維修改善工程(開口合約)',
#   'times': '04',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '2314440',
#   'ischange': 0},
#  {'no': '13',
#   'proposer_name': '財團法人臺中市影視發展基金會',
#   'bid_no': '111-ZS-A001',
#   'bid_name': '「111年中山73影視藝文空間營運管理」 委託專業服務採購案',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '1340000',
#   'ischange': 1},
#  {'no': '14',
#   'proposer_name': '新北市三峽區三峽國民小學',
#   'bid_no': 'SHPS-11102',
#   'bid_name': '三峽國小附設幼兒園110學年度第二學期暨111學年度午餐點心食材委託採買',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/22',
#   'budget': '2849336',
#   'ischange': 0},
#  {'no': '15',
#   'proposer_name': '經濟部水利署第五河川局',
#   'bid_no': 'MOEAWRA1110101',
#   'bid_name': '北港溪流域整體改善與調適規劃(1/2)',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '4000000',
#   'ischange': 0},
#  {'no': '16',
#   'proposer_name': '經濟部水利署第五河川局',
#   'bid_no': '1110101p',
#   'bid_name': '111年度五河局公私協力工作坊',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '2200000',
#   'ischange': 0},
#  {'no': '17',
#   'proposer_name': '經濟部水利署第九河川局',
#   'bid_no': '111-I-01010-001-074',
#   'bid_name': '111年度花蓮轄管海岸緊急搶險(修)工程(開口合約)',
#   'times': '05',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '4341009',
#   'ischange': 0},
#  {'no': '18',
#   'proposer_name': '屏東縣政府',
#   'bid_no': '141-1110112-3',
#   'bid_name': '(110年07月及08月豪雨)萬丹鄉萬丹排水極樂橋至田厝橋災後復建工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '6926000',
#   'ischange': 0},
#  {'no': '19',
#   'proposer_name': '桃園市政府水務局',
#   'bid_no': '1101228-J1',
#   'bid_name': '111年度淡水河及磺溪二水系河川區域整頓計畫-桃園市轄河段執行計畫',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '4982561',
#   'ischange': 0},
#  {'no': '20',
#   'proposer_name': '嘉義市政府財政稅務局',
#   'bid_no': '1110106',
#   'bid_name': '不斷電設備汰換及電池組汰換採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '600000',
#   'ischange': 0},
#  {'no': '21',
#   'proposer_name': '行政院原子能委員會核能研究所',
#   'bid_no': 'NL1110103',
#   'bid_name': '核醫製藥中心製造/品管小組儀器年度校正',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '388200',
#   'ischange': 0},
#  {'no': '22',
#   'proposer_name': '衛生福利部嘉義醫院',
#   'bid_no': 'CHYI1102729',
#   'bid_name': '血液氣體分析檢驗試劑',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '780000',
#   'ischange': 0},
#  {'no': '23',
#   'proposer_name': '彰化縣民權華德福實驗國民中小學',
#   'bid_no': 'mcws11101',
#   'bid_name': '偏遠地區國中小行動載具計畫',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '280000',
#   'ischange': 0},
#  {'no': '24',
#   'proposer_name': '新北市三重區碧華國民小學',
#   'bid_no': 'BHES1110113',
#   'bid_name': '110學年度一至四年級校外教學委託服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '977700',
#   'ischange': 0},
#  {'no': '25',
#   'proposer_name': '苗栗縣竹南鎮竹南國民小學',
#   'bid_no': '11101B01',
#   'bid_name': '竹南國小110學年度下學期戶外教育活動勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '866490',
#   'ischange': 0},
#  {'no': '26',
#   'proposer_name': '國家災害防救科技中心',
#   'bid_no': 'NCDR-S-111011',
#   'bid_name': '都會區暴雨逕流管線資料收整、檢核與分析',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '980000',
#   'ischange': 0},
#  {'no': '27',
#   'proposer_name': '台灣中油股份有限公司油品行銷事業部台中營業處',
#   'bid_no': 'D4110R029',
#   'bid_name': '台中供油柴油引擎空壓機1台',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '840000',
#   'ischange': 0},
#  {'no': '28',
#   'proposer_name': '臺中市南屯區公所',
#   'bid_no': '11102',
#   'bid_name': '111年度臺中市南屯區基礎公共建設工程委託設計監造(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '599895',
#   'ischange': 0},
#  {'no': '29',
#   'proposer_name': '新北市政府養護工程處',
#   'bid_no': 'SRMC-1101208-A',
#   'bid_name': '110年度新北市3D智慧管線查詢及管理系統物聯網資訊介接計畫',
#   'times': '01',
#   'typ': '公開取得電子報價單',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '456000',
#   'ischange': 0},
#  {'no': '30',
#   'proposer_name': '屏東縣麟洛鄉麟洛國民小學',
#   'bid_no': '11101',
#   'bid_name': '麟洛國小110學年度第2學期學校午餐食材採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '967680',
#   'ischange': 0},
#  {'no': '31',
#   'proposer_name': '澎湖縣白沙鄉公所',
#   'bid_no': 'CW-1110208',
#   'bid_name': '111年度白沙鄉漁業導航標識燈修復工程(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/02/08',
#   'budget': '990000',
#   'ischange': 0},
#  {'no': '32',
#   'proposer_name': '台灣中油股份有限公司油品行銷事業部台中營業處',
#   'bid_no': 'D4110P015',
#   'bid_name': '111年台中供油漏油偵測器購置',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '498750',
#   'ischange': 0},
#  {'no': '33',
#   'proposer_name': '臺南市西港區公所',
#   'bid_no': '111-003',
#   'bid_name': '西港區慶安里新興街11號前側溝及中央市場停車場北側前道路改善工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '524000',
#   'ischange': 0},
#  {'no': '34',
#   'proposer_name': '新北市板橋區實踐國民小學',
#   'bid_no': '11101',
#   'bid_name': '松雲樓一、二樓地坪改善採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '300000',
#   'ischange': 0},
#  {'no': '35',
#   'proposer_name': '桃園市觀音區新坡國民小學',
#   'bid_no': '11028',
#   'bid_name': '桃園巿觀音區新坡國民小學改善校園安全監視系統採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '521700',
#   'ischange': 0},
#  {'no': '36',
#   'proposer_name': '新北市永和區秀朗國民小學',
#   'bid_no': 'hles111011901',
#   'bid_name': '秀朗國小110學年度第二學期學生美勞用品代辦採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '373939',
#   'ischange': 0},
#  {'no': '37',
#   'proposer_name': '嘉義縣文化觀光局',
#   'bid_no': 'Z081110000148',
#   'bid_name': '111年度嘉義縣執行旅宿業管理工作非全時公務車租賃案',
#   'times': '01',
#   'typ': '公開取得電子報價單',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '600000',
#   'ischange': 0},
#  {'no': '38',
#   'proposer_name': '花蓮縣政府',
#   'bid_no': 'HK11111602',
#   'bid_name': '洄瀾宜居微型創業平台計畫-設備及設施整建委託設計監造案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '462000',
#   'ischange': 0},
#  {'no': '39',
#   'proposer_name': '臺南市南化區公所',
#   'bid_no': '111A001',
#   'bid_name': '南化區北寮里4鄰道路排水改善工程',
#   'times': '02',
#   'typ': '公開取得電子報價單',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '314771',
#   'ischange': 0},
#  {'no': '40',
#   'proposer_name': '衛生福利部澎湖醫院',
#   'bid_no': '2286002072',
#   'bid_name': '手搖型護理床30台採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '',
#   'ischange': 0},
#  {'no': '41',
#   'proposer_name': '國立臺灣大學',
#   'bid_no': 'ch111001',
#   'bid_name': 'PP廢液推車（含PP管線施作）',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '299000',
#   'ischange': 0},
#  {'no': '42',
#   'proposer_name': '南投縣信義鄉公所',
#   'bid_no': 'D111-3',
#   'bid_name': '「南投縣信義鄉2022草坪頭櫻花季電子支付系統租用」勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '200000',
#   'ischange': 0},
#  {'no': '43',
#   'proposer_name': '嘉義縣立民和國民中學',
#   'bid_no': '111002',
#   'bid_name': '視訊攝影機財物採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '150000',
#   'ischange': 0},
#  {'no': '44',
#   'proposer_name': '屏東縣佳冬鄉佳冬國民小學',
#   'bid_no': 'JDPS1110121',
#   'bid_name': '屏東縣佳冬國小110學年度第1學期午餐食材採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '871454',
#   'ischange': 0},
#  {'no': '45',
#   'proposer_name': '內政部警政署保安警察第二總隊',
#   'bid_no': 'sppc11102',
#   'bid_name': '「安康訓練中心行政大樓線槽、餐廳及廚房環境改善工程及第二大隊第二中隊駐地房舍環境改善工程」委託技術服務案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '693165',
#   'ischange': 0},
#  {'no': '46',
#   'proposer_name': '臺中市立龍津高級中等學校',
#   'bid_no': '111-003',
#   'bid_name': '龍津高中舊警衛室旁地坪拆除工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '209790',
#   'ischange': 0},
#  {'no': '47',
#   'proposer_name': '勞動部勞動力發展署桃竹苗分署',
#   'bid_no': '111Y092',
#   'bid_name': '電氣裝配職類競賽場地電源系統配置',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '202000',
#   'ischange': 0},
#  {'no': '48',
#   'proposer_name': '衛生福利部恆春旅遊醫院',
#   'bid_no': 'HCTH11067',
#   'bid_name': '111年醫療機構綜合責任保險採購案',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '400000',
#   'ischange': 0},
#  {'no': '49',
#   'proposer_name': '衛生福利部臺中醫院',
#   'bid_no': 'TH111004',
#   'bid_name': '股骨撐開器1組',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '148000',
#   'ischange': 0},
#  {'no': '50',
#   'proposer_name': '衛生福利部臺中醫院',
#   'bid_no': 'TH111002',
#   'bid_name': '超音波膀胱容量測定儀1組',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '380000',
#   'ischange': 0},
#  {'no': '51',
#   'proposer_name': '新竹縣竹北市公所',
#   'bid_no': 'T1100113',
#   'bid_name': '竹北里環北路一段71巷等多條巷道路面改善工程委託設計監造',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '330000',
#   'ischange': 0},
#  {'no': '52',
#   'proposer_name': '彰化縣消防局',
#   'bid_no': '111-D008',
#   'bid_name': '彰化縣消防局111年度救護耗材1批採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '949580',
#   'ischange': 0},
#  {'no': '53',
#   'proposer_name': '臺中榮民總醫院',
#   'bid_no': 'TVG111J-05',
#   'bid_name': '電解水機組   壹組',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '367500',
#   'ischange': 0},
#  {'no': '54',
#   'proposer_name': '南投縣信義鄉公所',
#   'bid_no': 'D111-2',
#   'bid_name': '「南投縣信義鄉2022草坪頭櫻花季活動設備租用」勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '370000',
#   'ischange': 0},
#  {'no': '55',
#   'proposer_name': '臺中市和平區和平國民小學',
#   'bid_no': '1110104',
#   'bid_name': '臺中市和平區和平國民小學午餐廚房前環境改善',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '516982',
#   'ischange': 0},
#  {'no': '56',
#   'proposer_name': '國立宜蘭高級中學',
#   'bid_no': 'YLSH-11103',
#   'bid_name': '「110年度空間活化工程(第二階段)」委託設計監造服務案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '165034',
#   'ischange': 0},
#  {'no': '57',
#   'proposer_name': '臺北市中山區大佳國民小學',
#   'bid_no': 'DJA11101',
#   'bid_name': '111年度仁愛樓外牆暨遮陽板設施、專科教室(自然教室)、專科教室(電腦教室暨機房)改善工程委託設計監造技術服務案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '227188',
#   'ischange': 0},
#  {'no': '58',
#   'proposer_name': '國立南投高級商業職業學校',
#   'bid_no': '11105',
#   'bid_name': '111學年度學生生活教育暨民主法治教育教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '475200',
#   'ischange': 0},
#  {'no': '59',
#   'proposer_name': '新竹市東區東園國民小學',
#   'bid_no': '11101OE',
#   'bid_name': '110學年度三四五年級戶外教育教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '882464',
#   'ischange': 0},
#  {'no': '60',
#   'proposer_name': '南投縣國姓鄉公所',
#   'bid_no': '1110000170',
#   'bid_name': '110國姓鄉柑林村第五鄰昌榮巷旁擋土牆改善工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '219445',
#   'ischange': 0},
#  {'no': '61',
#   'proposer_name': '苗栗縣苑裡鎮中山國民小學',
#   'bid_no': 'js1110112',
#   'bid_name': '110學年度公立國民中小學校與國外姊妹校互惠機制實施計畫',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '400000',
#   'ischange': 0},
#  {'no': '62',
#   'proposer_name': '新北市泰山區義學國民小學',
#   'bid_no': 'ys11011',
#   'bid_name': '111年度2月至6月幸福晨飽早餐供應採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '190080',
#   'ischange': 0},
#  {'no': '63',
#   'proposer_name': '嘉義縣文化觀光局',
#   'bid_no': 'Z081110000053',
#   'bid_name': '111年度嘉義縣文化觀光局企劃科公務車租賃案',
#   'times': '01',
#   'typ': '公開取得電子報價單',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '249000',
#   'ischange': 0},
#  {'no': '64',
#   'proposer_name': '衛生福利部豐原醫院',
#   'bid_no': 'FYH1112101',
#   'bid_name': '全身麻醉機8台維護保養',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '640000',
#   'ischange': 0},
#  {'no': '65',
#   'proposer_name': '彰化縣政府',
#   'bid_no': '111-0020705-070-2-6',
#   'bid_name': '彰化縣政府111年兒童節慶祝活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '800000',
#   'ischange': 0},
#  {'no': '66',
#   'proposer_name': '臺中市政府農業局',
#   'bid_no': '111BC01',
#   'bid_name': '111年度國公有土地測量工作',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '635060',
#   'ischange': 0},
#  {'no': '67',
#   'proposer_name': '嘉義縣溪口鄉公所',
#   'bid_no': '110-23',
#   'bid_name': '坪頂村下菜園及游西村排水溝改善工程',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '536400',
#   'ischange': 0},
#  {'no': '68',
#   'proposer_name': '南投縣信義鄉公所',
#   'bid_no': 'D111-1',
#   'bid_name': '「南投縣信義鄉2022草坪頭櫻花季接駁車租用」勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '778000',
#   'ischange': 0},
#  {'no': '69',
#   'proposer_name': '屏東縣竹田鄉公所',
#   'bid_no': '111H002',
#   'bid_name': '111年度竹田鄉公共工程委託設計監造技術服務開口契約',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '800000',
#   'ischange': 0},
#  {'no': '70',
#   'proposer_name': '國立中科實驗高級中學',
#   'bid_no': 'nehs11101',
#   'bid_name': '111年度校園景觀維護勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '668500',
#   'ischange': 0},
#  {'no': '71',
#   'proposer_name': '臺中市立臺中家事商業高級中等學校',
#   'bid_no': 'tchcvs111002',
#   'bid_name': '111 年度實習食材採購開口契約採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '537928',
#   'ischange': 0},
#  {'no': '72',
#   'proposer_name': '嘉義縣溪口鄉公所',
#   'bid_no': '110-19',
#   'bid_name': '嘉義縣溪口鄉110年度轄內路燈增設工程',
#   'times': '05',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '',
#   'ischange': 0},
#  {'no': '73',
#   'proposer_name': '臺中榮民總醫院',
#   'bid_no': 'TVG111J-04',
#   'bid_name': '曳引車    壹組',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '383250',
#   'ischange': 0},
#  {'no': '74',
#   'proposer_name': '高雄市立六龜高級中學',
#   'bid_no': '111-01-001',
#   'bid_name': '110學年度高三、國三校外教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '390100',
#   'ischange': 0},
#  {'no': '75',
#   'proposer_name': '嘉義縣溪口鄉公所',
#   'bid_no': '110-26',
#   'bid_name': '溪口鄉林腳村10鄰柴林腳路面及排水溝改善工程',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '728400',
#   'ischange': 0},
#  {'no': '76',
#   'proposer_name': '臺中市政府衛生局',
#   'bid_no': '111D02',
#   'bid_name': '111年愛滋病防治用各類衛材採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '585200',
#   'ischange': 0},
#  {'no': '77',
#   'proposer_name': '新北市三芝區三芝國民小學',
#   'bid_no': 'm1110119',
#   'bid_name': '111年度合作社委外經營',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '184000',
#   'ischange': 0},
#  {'no': '78',
#   'proposer_name': '新竹縣竹北市光明國民小學',
#   'bid_no': 'KM1100117',
#   'bid_name': '110學年度全國學生音樂比賽個人項目全區決賽勞務採購案 -鋼琴租借與調音',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '238000',
#   'ischange': 0},
#  {'no': '79',
#   'proposer_name': '財團法人國際合作發展基金會',
#   'bid_no': 'ICDF-TM-110-047',
#   'bid_name': '111年駐諾魯技術團菇類太空包',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '205000',
#   'ischange': 0},
#  {'no': '80',
#   'proposer_name': '法務部矯正署',
#   'bid_no': '1101126',
#   'bid_name': '111年矯正機關自營商城維運工作委託承攬案',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '589560',
#   'ischange': 0},
#  {'no': '81',
#   'proposer_name': '法務部行政執行署',
#   'bid_no': 'AEA111001',
#   'bid_name': '感恩春酒餐飲委外採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '171600',
#   'ischange': 0},
#  {'no': '82',
#   'proposer_name': '苗栗縣政府',
#   'bid_no': '111012d',
#   'bid_name': '苑裡鎮苑坑里11鄰農路改善工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '204000',
#   'ischange': 0},
#  {'no': '83',
#   'proposer_name': '台灣自來水股份有限公司第三區管理處',
#   'bid_no': '1113F01001',
#   'bid_name': '實驗室廢氣處理設備、實驗桌櫃、庫板隔間改善',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '998340',
#   'ischange': 0},
#  {'no': '84',
#   'proposer_name': '高雄市仁武區八卦國民小學',
#   'bid_no': '11101',
#   'bid_name': '110學年度三年級校外教學參觀活動勞務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '108600',
#   'ischange': 0},
#  {'no': '85',
#   'proposer_name': '法務部矯正署高雄第二監獄',
#   'bid_no': 'KSSP111008',
#   'bid_name': '瓦斯貫流立式鍋爐設備維護保養',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '268500',
#   'ischange': 0},
#  {'no': '86',
#   'proposer_name': '文化部',
#   'bid_no': '11101137',
#   'bid_name': '文化部「推動臺灣數位出版品納入公共出借權之可行性及效益評估」勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/02/14',
#   'budget': '550000',
#   'ischange': 0},
#  {'no': '87',
#   'proposer_name': '臺中市立爽文國民中學',
#   'bid_no': 'swjh1110102',
#   'bid_name': '110學年度一年級學生戶外教育活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '433750',
#   'ischange': 0},
#  {'no': '88',
#   'proposer_name': '國立臺灣大學醫學院附設醫院新竹臺大分院',
#   'bid_no': 'GA1002320',
#   'bid_name': '整合式心血管手術頭燈攝影系統3組',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '240000',
#   'ischange': 0},
#  {'no': '89',
#   'proposer_name': '苗栗縣政府',
#   'bid_no': '111013d',
#   'bid_name': '西湖鄉金獅村13鄰農路改善工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '675200',
#   'ischange': 0},
#  {'no': '90',
#   'proposer_name': '臺灣菸酒股份有限公司豐原捲菸研發製造工廠',
#   'bid_no': '111-0220-1-006',
#   'bid_name': '菸草特有亞硝胺委託分析',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '252000',
#   'ischange': 0},
#  {'no': '91',
#   'proposer_name': '澎湖縣立中正國民中學',
#   'bid_no': 'MRSH111-01',
#   'bid_name': '偏遠地區國中小行動載具財物採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '279000',
#   'ischange': 0},
#  {'no': '92',
#   'proposer_name': '國立臺南第一高級中學',
#   'bid_no': '1110109',
#   'bid_name': '群英堂舞台與音響設備改善採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '551200',
#   'ischange': 0},
#  {'no': '93',
#   'proposer_name': '苗栗縣後龍鎮公所',
#   'bid_no': 'K1110120010',
#   'bid_name': '111年度後龍鎮公園綠地環境維護勞務採購(開口合約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '800000',
#   'ischange': 0},
#  {'no': '94',
#   'proposer_name': '臺南市南區區公所',
#   'bid_no': '1100113A',
#   'bid_name': '110年度7月及8月豪雨南區大成路一段193巷道路旁擋土牆修復災後復建工程',
#   'times': '06',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '373959',
#   'ischange': 0},
#  {'no': '95',
#   'proposer_name': '彰化縣花壇鄉三春國民小學',
#   'bid_no': '1110127',
#   'bid_name': '110學年度臺灣母語繪本製作暨電子書委託製作案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '297600',
#   'ischange': 0},
#  {'no': '96',
#   'proposer_name': '臺中市立烏日國民中學',
#   'bid_no': '1110121',
#   'bid_name': '111年度文中2預定地綠化植栽養護管理服務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '475000',
#   'ischange': 0},
#  {'no': '97',
#   'proposer_name': '嘉義縣政府',
#   'bid_no': '111QS031B3',
#   'bid_name': '111年度再生能源發電設備認定與查核電動公務車租賃',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '377850',
#   'ischange': 0},
#  {'no': '98',
#   'proposer_name': '臺中市太平區坪林國民小學',
#   'bid_no': '111001',
#   'bid_name': '臺中市太平區坪林國民小學110學年度學生戶外教育勞務採購',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '408510',
#   'ischange': 0},
#  {'no': '99',
#   'proposer_name': '新北市新店區新和國民小學',
#   'bid_no': 'sin11101',
#   'bid_name': '110學年度第2學期簿本及美勞材料採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '',
#   'ischange': 0},
#  {'no': '100',
#   'proposer_name': '新竹縣五峰鄉公所',
#   'bid_no': 'A111001',
#   'bid_name': '111年五峰鄉農民節表揚暨農特產業慶祝活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '850000',
#   'ischange': 0},
#  {'no': '1',
#   'proposer_name': '桃園市立永豐高級中等學校',
#   'bid_no': '11101',
#   'bid_name': '110學年度國二隔宿露營採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '850620',
#   'ischange': 0},
#  {'no': '2',
#   'proposer_name': '屏東縣枋寮鄉公所',
#   'bid_no': '110A28',
#   'bid_name': '110-枋寮鄉各村路燈增設工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '799500',
#   'ischange': 0},
#  {'no': '3',
#   'proposer_name': '彰化縣鹿港鎮公所',
#   'bid_no': '11101-205',
#   'bid_name': '2022鹿港減碳森活暨食農教育推廣',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '500000',
#   'ischange': 0},
#  {'no': '4',
#   'proposer_name': '臺中市東區進德國民小學',
#   'bid_no': 'jdes1110110',
#   'bid_name': '110學年度一至六年級戶外教育活動勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '333290',
#   'ischange': 0},
#  {'no': '5',
#   'proposer_name': '連江縣立介壽國民中小學',
#   'bid_no': 'PS11101001',
#   'bid_name': '委託辦理111年度國小部學生校外教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '',
#   'ischange': 0},
#  {'no': '6',
#   'proposer_name': '陽明山國家公園管理處',
#   'bid_no': '1110803',
#   'bid_name': '111年度影像資料庫系統維運案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '980000',
#   'ischange': 0},
#  {'no': '7',
#   'proposer_name': '國立苗栗高級農工職業學校',
#   'bid_no': '11103-11',
#   'bid_name': '110學年度第二學期學生職場參觀交通車勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '168000',
#   'ischange': 0},
#  {'no': '8',
#   'proposer_name': '雲林縣斗六市鎮西國民小學',
#   'bid_no': 'B1110124',
#   'bid_name': '110學年度下學期提供學生午餐食材費至全國平均標準補助政策',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '584856',
#   'ischange': 0},
#  {'no': '9',
#   'proposer_name': '屏東縣枋寮鄉公所',
#   'bid_no': '110A26',
#   'bid_name': '110-枋寮鄉天時村公正路56巷道路改善工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '531841',
#   'ischange': 0},
#  {'no': '10',
#   'proposer_name': '新北市土城區土城國民小學',
#   'bid_no': '1110107',
#   'bid_name': '111年度改善消防安全設備採購',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '172962',
#   'ischange': 0},
#  {'no': '11',
#   'proposer_name': '屏東縣政府環境保護局',
#   'bid_no': '1110113-A',
#   'bid_name': '111年度屏東縣飲用水項目查驗工作計畫',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '362000',
#   'ischange': 0},
#  {'no': '12',
#   'proposer_name': '臺南市南化區公所',
#   'bid_no': '111C004',
#   'bid_name': '111年度南化區公所資本門預算委託設計監造(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '488750',
#   'ischange': 0},
#  {'no': '13',
#   'proposer_name': '澎湖縣西嶼鄉公所',
#   'bid_no': '1110113',
#   'bid_name': '111年度各村公共設施工程(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '998160',
#   'ischange': 0},
#  {'no': '14',
#   'proposer_name': '臺灣菸酒股份有限公司豐原捲菸研發製造工廠',
#   'bid_no': '111-0220-1-007',
#   'bid_name': '74mmX3km白色濾嘴紙(520綠晶球菸)50卷',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '',
#   'ischange': 0},
#  {'no': '15',
#   'proposer_name': '臺北市南港區成德國民小學',
#   'bid_no': 'C11102',
#   'bid_name': '忠孝樓南向外牆窗戶雨遮整修及仁愛樓北向窗戶更新工程委託規劃設計監造技術服務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '407565',
#   'ischange': 0},
#  {'no': '16',
#   'proposer_name': '南投縣政府文化局',
#   'bid_no': '1102202062-E',
#   'bid_name': '南投縣「熊愛閱讀」閱讀護照印製及運送案',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '300000',
#   'ischange': 0},
#  {'no': '17',
#   'proposer_name': '臺中市清水區公所',
#   'bid_no': '11113',
#   'bid_name': '臺中市清水區111年度鰲峰段綠美化空地維護(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '170000',
#   'ischange': 0},
#  {'no': '18',
#   'proposer_name': '國立臺灣體育運動大學',
#   'bid_no': '110Y1201',
#   'bid_name': '111年中文圖書(開口契約)財物採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '700000',
#   'ischange': 0},
#  {'no': '19',
#   'proposer_name': '苗栗縣通霄鎮公所',
#   'bid_no': 'TSP-111',
#   'bid_name': '通霄鎮111年度春節敦親睦鄰暨節約能源宣導活動餐飲服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '200000',
#   'ischange': 0},
#  {'no': '20',
#   'proposer_name': '高雄市三民區莊敬國民小學',
#   'bid_no': 'jj11101',
#   'bid_name': '莊敬國小運動場整修工程委託規劃設計監造技術服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '413981',
#   'ischange': 0},
#  {'no': '21',
#   'proposer_name': '臺北市勞動檢查處',
#   'bid_no': '11105',
#   'bid_name': '111年度勞動檢查M化作業服務方案上網數據通訊及行動電話費招標案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '801900',
#   'ischange': 0},
#  {'no': '22',
#   'proposer_name': '苗栗縣立致民國民中學',
#   'bid_no': '111g003',
#   'bid_name': '110年度北側圍牆改善工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '673874',
#   'ischange': 0},
#  {'no': '23',
#   'proposer_name': '彰化縣立成功高級中學',
#   'bid_no': '11103',
#   'bid_name': '110學年度第二學期高中部教科書採購案',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '712210',
#   'ischange': 0},
#  {'no': '24',
#   'proposer_name': '新竹縣峨眉鄉公所',
#   'bid_no': '110032A',
#   'bid_name': '七星村五鄰災害復建工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '351096',
#   'ischange': 0},
#  {'no': '25',
#   'proposer_name': '高雄市立民生醫院',
#   'bid_no': 'KMSH11006',
#   'bid_name': '111年防疫計程車委外服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '892800',
#   'ischange': 0},
#  {'no': '26',
#   'proposer_name': '臺灣菸酒股份有限公司烏日啤酒廠',
#   'bid_no': '111-3000-1-002',
#   'bid_name': '0.5L瓶裝黑啤酒一打裝紙箱20,000個',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '630000',
#   'ischange': 0},
#  {'no': '27',
#   'proposer_name': '高雄市前鎮區瑞豐國民小學',
#   'bid_no': '1110113',
#   'bid_name': '110學年度一年級校外教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '126500',
#   'ischange': 0},
#  {'no': '28',
#   'proposer_name': '國立鳳山高級商工職業學校',
#   'bid_no': '1110101',
#   'bid_name': '111年圖書館圖書及視聽資料採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '250000',
#   'ischange': 0},
#  {'no': '29',
#   'proposer_name': '嘉義市博愛國民小學',
#   'bid_no': '1110001A',
#   'bid_name': '嘉義市博愛國小委託辦理110學年度寒假課後照顧班「融合班」勞務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '309150',
#   'ischange': 0},
#  {'no': '30',
#   'proposer_name': '雲林縣崙背鄉公所',
#   'bid_no': '110044',
#   'bid_name': '110年度「配合國家發展委員會-加速推動地方創生計劃地方創生觀光旅遊環境營造-崙背鄉遊客服務中心暨周邊引導設施整體改善計畫」委',
#   'times': '04',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '242868',
#   'ischange': 0},
#  {'no': '31',
#   'proposer_name': '高雄市苓雅區四維國民小學',
#   'bid_no': '110-13',
#   'bid_name': '110學年度四年級校外教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '286650',
#   'ischange': 0},
#  {'no': '32',
#   'proposer_name': '行政院農業委員會林務局阿里山林業鐵路及文化資產管理處',
#   'bid_no': '111AH-727-01',
#   'bid_name': '111年行車人員體檢及一般人員定期健檢',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '304500',
#   'ischange': 1},
#  {'no': '33',
#   'proposer_name': '新北市新莊區昌隆國民小學',
#   'bid_no': 'CLES-1110119',
#   'bid_name': '昌隆國小1024地震復建工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '823478',
#   'ischange': 0},
#  {'no': '34',
#   'proposer_name': '衛生福利部恆春旅遊醫院',
#   'bid_no': 'HCTH11102',
#   'bid_name': '救護車改裝復康巴士採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '480000',
#   'ischange': 0},
#  {'no': '35',
#   'proposer_name': '新北市新莊區豐年國民小學',
#   'bid_no': 'fnes-B11007',
#   'bid_name': '110學年度一二三四五年級戶外教育委託專業服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '505542',
#   'ischange': 0},
#  {'no': '36',
#   'proposer_name': '屏東縣林邊鄉仁和國民小學',
#   'bid_no': 'Ren1110120',
#   'bid_name': '屏東縣仁和國小110學年度第2學期學生午餐委外辦理',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '689472',
#   'ischange': 0},
#  {'no': '37',
#   'proposer_name': '花蓮縣立吉安國民中學',
#   'bid_no': '1110113',
#   'bid_name': '吉安國中110學年度九年級校外教學活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '374000',
#   'ischange': 0},
#  {'no': '38',
#   'proposer_name': '臺北市立啟明學校',
#   'bid_no': '111-07',
#   'bid_name': '111年度臺北市特殊教育學生線上教學影片製作',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '345000',
#   'ischange': 0},
#  {'no': '39',
#   'proposer_name': '桃園市中壢區青埔國民小學',
#   'bid_no': '11101',
#   'bid_name': '111年度兒童節禮物採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '141300',
#   'ischange': 0},
#  {'no': '40',
#   'proposer_name': '新北市新店區屈尺國民小學',
#   'bid_no': '111001',
#   'bid_name': '新北市新店區屈尺國民小學111年度自立午餐食材採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '825000',
#   'ischange': 0},
#  {'no': '41',
#   'proposer_name': '國立花蓮特殊教育學校',
#   'bid_no': '11102',
#   'bid_name': '採購大尺寸觸控螢幕4台',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '440000',
#   'ischange': 0},
#  {'no': '42',
#   'proposer_name': '臺南市善化區公所',
#   'bid_no': '111001',
#   'bid_name': '111年度善化區農水路工程委託規劃設計及監造案（開口契約）',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '950000',
#   'ischange': 0},
#  {'no': '43',
#   'proposer_name': '彰化縣政府',
#   'bid_no': '111-0022206-028-2-5',
#   'bid_name': '111年度防汛告示牌維護開口契約',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '502089',
#   'ischange': 0},
#  {'no': '44',
#   'proposer_name': '臺北市立忠孝國民中學',
#   'bid_no': '11105',
#   'bid_name': '110學年度七、八年級校外教學勞務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '387500',
#   'ischange': 0},
#  {'no': '45',
#   'proposer_name': '澎湖縣馬公市公所',
#   'bid_no': 'HY-11101',
#   'bid_name': '111年度馬公市道路設施及反視鏡新設及維修工作(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '350000',
#   'ischange': 1},
#  {'no': '46',
#   'proposer_name': '新北市新店區安坑國民小學',
#   'bid_no': '1110112',
#   'bid_name': '111年度安坑國小學務處辦公室整修工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '200000',
#   'ischange': 0},
#  {'no': '47',
#   'proposer_name': '國立花蓮高級工業職業學校',
#   'bid_no': '111-03',
#   'bid_name': '111級三年級成年禮活動勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '324000',
#   'ischange': 1},
#  {'no': '48',
#   'proposer_name': '新北市新莊區中港國民小學',
#   'bid_no': 'JGPS1110113',
#   'bid_name': '中港國小110學年度一二年級及幼兒園校外教學委託專業服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '845192',
#   'ischange': 0},
#  {'no': '49',
#   'proposer_name': '衛生福利部金門醫院',
#   'bid_no': '111012616',
#   'bid_name': 'BSS PLUS 500ML/BTL',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '209520',
#   'ischange': 0},
#  {'no': '50',
#   'proposer_name': '新竹縣芎林鄉芎林國民小學',
#   'bid_no': '1110111',
#   'bid_name': '111年度竹北市文小三（竹北市隘興段395地號）學校用地管理維護勞務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '300000',
#   'ischange': 0},
#  {'no': '51',
#   'proposer_name': '宜蘭縣動植物防疫所',
#   'bid_no': '1110114',
#   'bid_name': '平腹小蜂雌小蜂',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '240000',
#   'ischange': 0},
#  {'no': '52',
#   'proposer_name': '行政院農業委員會農業試驗所',
#   'bid_no': '1113002',
#   'bid_name': '精準農業複合酬載功能旋翼無人機及飛行控制模組一式',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '900000',
#   'ischange': 0},
#  {'no': '53',
#   'proposer_name': '桃園市立壽山高級中等學校',
#   'bid_no': 'SSSH11102',
#   'bid_name': '桃園市壽山高中「110學年度用品暨校園食品販售業務委外經營採購」',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '',
#   'ischange': 0},
#  {'no': '54',
#   'proposer_name': '基隆市中正區正濱國民小學',
#   'bid_no': '111c01',
#   'bid_name': '基隆校園建築不一樣成果書編輯製作委託專業服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '850500',
#   'ischange': 0},
#  {'no': '55',
#   'proposer_name': '國立宜蘭高級商業職業學校',
#   'bid_no': 'ilvs11101',
#   'bid_name': '校園空間改善計畫委託設計監造技術服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '232751',
#   'ischange': 0},
#  {'no': '56',
#   'proposer_name': '臺北市立育成高級中學',
#   'bid_no': '11105',
#   'bid_name': '111年度技工、工友人力外包',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '819684',
#   'ischange': 0},
#  {'no': '57',
#   'proposer_name': '臺北市立美術館',
#   'bid_no': '111EX0006',
#   'bid_name': '「李義弘：回顧展」影片製作案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '370000',
#   'ischange': 0},
#  {'no': '58',
#   'proposer_name': '臺中市立萬和國民中學',
#   'bid_no': '1110119',
#   'bid_name': '110學年度二年級戶外教育活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '513590',
#   'ischange': 0},
#  {'no': '59',
#   'proposer_name': '桃園市政府住宅發展處',
#   'bid_no': 'OHD1110113-1',
#   'bid_name': '「111年度桃園市社會住宅成果冊」委託專業服務案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '900000',
#   'ischange': 0},
#  {'no': '60',
#   'proposer_name': '行政院農業委員會農業藥物毒物試驗所',
#   'bid_no': '111c003',
#   'bid_name': '111年度實驗動物大鼠',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '948000',
#   'ischange': 0},
#  {'no': '61',
#   'proposer_name': '國立臺灣大學醫學院附設醫院',
#   'bid_no': 'PA2100683',
#   'bid_name': '神經調控程控儀系統(多功能版)2台',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '680000',
#   'ischange': 0},
#  {'no': '62',
#   'proposer_name': '臺南市安南區土城國民小學',
#   'bid_no': 'tcps11012',
#   'bid_name': '台南市土城國小學校運動操場及周邊設施整建工程委託規劃設計監造勞務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '508400',
#   'ischange': 0},
#  {'no': '63',
#   'proposer_name': '臺南市六甲區公所',
#   'bid_no': '11101003',
#   'bid_name': '六甲區大丘里北勢坑大丘高幹228左13至左1農路改善工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/02/10',
#   'budget': '548872',
#   'ischange': 0},
#  {'no': '64',
#   'proposer_name': '桃園市立楊梅高級中等學校',
#   'bid_no': '1110120C2',
#   'bid_name': '新建圖書館內部建置工程及設備採購設計監造委託技術服務勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '417672',
#   'ischange': 1},
#  {'no': '65',
#   'proposer_name': '桃園市觀音區公所',
#   'bid_no': '111-04',
#   'bid_name': '111年里基層工作經費反射鏡裝設工程(開口合約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '909966',
#   'ischange': 0},
#  {'no': '66',
#   'proposer_name': '新竹市政府',
#   'bid_no': '1100352',
#   'bid_name': '購置自行車乙批',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '504000',
#   'ischange': 0},
#  {'no': '67',
#   'proposer_name': '桃園市八德區茄苳國民小學',
#   'bid_no': '11014',
#   'bid_name': '110學年度戶外教育委託專業服務採購',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '513018',
#   'ischange': 0},
#  {'no': '68',
#   'proposer_name': '雲林縣古坑鄉永光國民小學',
#   'bid_no': 'C1110120',
#   'bid_name': '永光國小111年度附設幼兒園環境整備工程委託設計監造服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '150000',
#   'ischange': 0},
#  {'no': '69',
#   'proposer_name': '臺北市大同區蓬萊國民小學',
#   'bid_no': 'C11101',
#   'bid_name': '111年度視聽廣播工程委託監造設計服務勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '116411',
#   'ischange': 0},
#  {'no': '70',
#   'proposer_name': '屏東縣政府',
#   'bid_no': '141-1110106-3',
#   'bid_name': '(110年07月及08月豪雨)萬丹鄉田厝排水災後復建工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '841000',
#   'ischange': 0},
#  {'no': '71',
#   'proposer_name': '新北市金山區金山國民小學',
#   'bid_no': 'jses111010101',
#   'bid_name': '新北市金山區金山國民小學111年度消防安全設備改善案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/22',
#   'budget': '',
#   'ischange': 0},
#  {'no': '72',
#   'proposer_name': '新北市三峽區三峽國民小學',
#   'bid_no': 'SHPS-11104',
#   'bid_name': '三峽國小防火門安裝工程採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '165375',
#   'ischange': 0},
#  {'no': '73',
#   'proposer_name': '臺北市大同區日新國民小學',
#   'bid_no': '11101',
#   'bid_name': '111年度莊敬樓樓板修繕工程委託技術服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '215613',
#   'ischange': 0},
#  {'no': '74',
#   'proposer_name': '高雄市仁武區登發國民小學',
#   'bid_no': 'DF111003',
#   'bid_name': '登發國民小學111年02月-111年04月午餐冷凍肉品食材採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '638361',
#   'ischange': 0},
#  {'no': '75',
#   'proposer_name': '新北市立福和國民中學',
#   'bid_no': '111-02',
#   'bid_name': '110學年度九年級寒假輔導學生午餐財務採購',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '114500',
#   'ischange': 0},
#  {'no': '76',
#   'proposer_name': '嘉義縣太保市公所',
#   'bid_no': '11102',
#   'bid_name': '太保市新埤排水勞工住宅至農路段路燈復建工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '535364',
#   'ischange': 1},
#  {'no': '77',
#   'proposer_name': '臺中市太平區建平國民小學',
#   'bid_no': '111001',
#   'bid_name': '臺中市太平區建平國民小學資源班暨特教班大電視採購案',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '153000',
#   'ischange': 0},
#  {'no': '78',
#   'proposer_name': '新北市鶯歌區鶯歌國民小學',
#   'bid_no': '1110106',
#   'bid_name': '新北市鶯歌區鶯歌國民小學111年度消防安全設備改善',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '112080',
#   'ischange': 0},
#  {'no': '79',
#   'proposer_name': '彰化縣立二水國民中學',
#   'bid_no': 'Esjh1110101',
#   'bid_name': '111年度二水泰山體驗營及二水國中環境綠美化勞務採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '280000',
#   'ischange': 0},
#  {'no': '80',
#   'proposer_name': '新北市中和區光復國民小學',
#   'bid_no': '11101',
#   'bid_name': '110年度建築物公共安全檢查缺失改善工程',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '214436',
#   'ischange': 0},
#  {'no': '81',
#   'proposer_name': '國立臺北科技大學附屬桃園農工高級中等學校',
#   'bid_no': 'tyai111003',
#   'bid_name': '111年均質化計畫購買投籃訓練機',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '160000',
#   'ischange': 0},
#  {'no': '82',
#   'proposer_name': '臺中市和平區公所',
#   'bid_no': '111H08',
#   'bid_name': '111年度各里辦公處、鄰長及區民代表服務處政令宣導用報紙採購',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '795600',
#   'ischange': 0},
#  {'no': '83',
#   'proposer_name': '臺中捷運股份有限公司',
#   'bid_no': 'A11000104',
#   'bid_name': '信封等印刷品20項採購(開口契約)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '186525',
#   'ischange': 0},
#  {'no': '84',
#   'proposer_name': '國立曾文高級家事商業職業學校',
#   'bid_no': '11101',
#   'bid_name': '111年度因應新課綱規劃總體課程實施所需課室空間及適性學習空間活化需求改善計畫委託技術服務',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '145959',
#   'ischange': 0},
#  {'no': '85',
#   'proposer_name': '桃園市政府住宅發展處',
#   'bid_no': 'OHD1110113-2',
#   'bid_name': '八德二號社會住宅擴增監控設備工程',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '952552',
#   'ischange': 0},
#  {'no': '86',
#   'proposer_name': '新竹縣立湖口高級中學',
#   'bid_no': '111-004',
#   'bid_name': '110學年度國中部一年級校外教學招標案',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
# ...
#   'bid_no': '11062-1',
#   'bid_name': '110年固定資產-場部入口收費亭門面設置改善工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '1224500',
#   'ischange': 0},
#  {'no': '39',
#   'proposer_name': '嘉義縣中埔鄉公所',
#   'bid_no': '1100076',
#   'bid_name': '灣潭村公墓上方農路水保復建工程',
#   'times': '05',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '1489300',
#   'ischange': 0},
#  {'no': '40',
#   'proposer_name': '新竹縣立竹北國民中學',
#   'bid_no': '110A4',
#   'bid_name': '竹北國中和平樓校舍防水隔熱工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '2639774',
#   'ischange': 0},
#  {'no': '41',
#   'proposer_name': '國立臺灣大學醫學院附設醫院新竹臺大分院',
#   'bid_no': 'GA1002350',
#   'bid_name': '全數位高解析彩色超音波掃描儀',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '1800000',
#   'ischange': 0},
#  {'no': '42',
#   'proposer_name': '國立成功大學醫學院附設醫院',
#   'bid_no': 'AT111004',
#   'bid_name': '前哨淋巴偵測導航系統',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '3000000',
#   'ischange': 0},
#  {'no': '43',
#   'proposer_name': '行政院農業委員會農田水利署',
#   'bid_no': 'TC111A022',
#   'bid_name': '111年度大南站進水口設施工程開口契約',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '509646',
#   'ischange': 0},
#  {'no': '44',
#   'proposer_name': '經濟部水利署水利規劃試驗所',
#   'bid_no': '111103',
#   'bid_name': '曾文溪洪災信仰與治理歷程水文化研究',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '2800000',
#   'ischange': 0},
#  {'no': '45',
#   'proposer_name': '南投縣政府',
#   'bid_no': '111060403A',
#   'bid_name': '竹山瑞龍園區服務設施改善工程(111060403)',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '980000',
#   'ischange': 0},
#  {'no': '46',
#   'proposer_name': '台灣中油股份有限公司探採研究所',
#   'bid_no': 'F02106127',
#   'bid_name': '高速數位轉換器卡',
#   'times': '02',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '1062650',
#   'ischange': 0},
#  {'no': '47',
#   'proposer_name': '嘉義縣阿里山鄉公所',
#   'bid_no': '110077',
#   'bid_name': '達邦村簡易自來水災害復建工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '1648091',
#   'ischange': 0},
#  {'no': '48',
#   'proposer_name': '臺北市立聯合醫院',
#   'bid_no': '111CF02',
#   'bid_name': '可攜式居家睡眠檢查儀租賃',
#   'times': '03',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '1800000',
#   'ischange': 0},
#  {'no': '49',
#   'proposer_name': '屏東縣佳冬鄉公所',
#   'bid_no': '111-001',
#   'bid_name': '111年度佳冬鄉天然災害緊急搶(修)險工作(開口契約)',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '1793000',
#   'ischange': 0},
#  {'no': '50',
#   'proposer_name': '國立成功大學醫學院附設醫院',
#   'bid_no': 'BQ11107',
#   'bid_name': '腹腔鏡器械一批',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '306000',
#   'ischange': 0},
#  {'no': '51',
#   'proposer_name': '台灣自來水股份有限公司第五區管理處',
#   'bid_no': 'W5-11-0501-13',
#   'bid_name': '111年五區電氣設備檢驗',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '1463385',
#   'ischange': 0},
#  {'no': '52',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'B1101240',
#   'bid_name': '鹽埕區易淹水點排水改善工程',
#   'times': '03',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '9890000',
#   'ischange': 0},
#  {'no': '53',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100906205A',
#   'bid_name': '110年7月及8月豪雨G1-002中寮鄉永福村竹坑巷4-287無名橋下游野溪護岸災修復建工程等二件',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '1190412',
#   'ischange': 0},
#  {'no': '54',
#   'proposer_name': '國防部軍備局生產製造中心',
#   'bid_no': 'JE11109P090',
#   'bid_name': '防潮彈箱總成等2項(111年)',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '7864760',
#   'ischange': 0},
#  {'no': '55',
#   'proposer_name': '臺北大眾捷運股份有限公司',
#   'bid_no': 'C10A05911',
#   'bid_name': '煞車卡鉗樞軸等6項採購',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '6500000',
#   'ischange': 0},
#  {'no': '56',
#   'proposer_name': '南投縣政府',
#   'bid_no': '11005020995A',
#   'bid_name': '110年7月及8月豪雨C1-001中寮鄉139縣道51K+150道路災修復建工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '7415000',
#   'ischange': 0},
#  {'no': '57',
#   'proposer_name': '法務部矯正署桃園女子監獄',
#   'bid_no': '111002',
#   'bid_name': '111年與眷同住懇親宿舍工程採購案',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/22',
#   'budget': '900000',
#   'ischange': 1},
#  {'no': '58',
#   'proposer_name': '新北市政府環境保護局',
#   'bid_no': '111-005',
#   'bid_name': '111年度購置大小廚餘回收桶',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '6999990',
#   'ischange': 0},
#  {'no': '59',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'C1101235',
#   'bid_name': '內門區瑞山里瑞山1號橋上游護岸修復工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '3713382',
#   'ischange': 0},
#  {'no': '60',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'C1101265',
#   'bid_name': '高雄市仁武區灣內四巷分流工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '15580000',
#   'ischange': 0},
#  {'no': '61',
#   'proposer_name': '高雄市梓官區梓官國民小學',
#   'bid_no': '111A01',
#   'bid_name': '110學年第2學期午餐食材(畜肉、禽肉)財務採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '960000',
#   'ischange': 0},
#  {'no': '62',
#   'proposer_name': '台灣自來水股份有限公司第一區管理處',
#   'bid_no': '111012',
#   'bid_name': '新山水庫水質測量儀自動紀錄保養維護',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '703500',
#   'ischange': 0},
#  {'no': '63',
#   'proposer_name': '陸軍軍官學校',
#   'bid_no': 'FN11030P014',
#   'bid_name': '111年供水站保養',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '500000',
#   'ischange': 0},
#  {'no': '64',
#   'proposer_name': '財團法人工業技術研究院',
#   'bid_no': 'V070000034',
#   'bid_name': '高壓氣體壓縮機',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/02/14',
#   'budget': '6000000',
#   'ischange': 0},
#  {'no': '65',
#   'proposer_name': '南投縣竹山鎮公所',
#   'bid_no': '110105',
#   'bid_name': '111年度道路挖掘修復及道路坑洞修復工程(開口契約)',
#   'times': '04',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '7380000',
#   'ischange': 0},
#  {'no': '66',
#   'proposer_name': '國立臺灣大學醫學院附設醫院',
#   'bid_no': 'TD10E280',
#   'bid_name': '肌炎抗體測定(16項)等檢測試劑(附儀器)單價合約',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '2969120',
#   'ischange': 0},
#  {'no': '67',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100906203A',
#   'bid_name': '110年6月豪雨G1-010鹿谷鄉廣興村福德廟旁護岸災修復建工程',
#   'times': '06',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '5158000',
#   'ischange': 0},
#  {'no': '68',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'B1101252',
#   'bid_name': '美濃區龍肚里凌雲一號橋上游護岸修復工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '3561810',
#   'ischange': 0},
#  {'no': '69',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100906207A',
#   'bid_name': '110年7月及8月豪雨G1-008南投市東山里1鄰東山路39巷之1號旁災修復建工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '1989000',
#   'ischange': 0},
#  {'no': '70',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'B1101256',
#   'bid_name': '高雄市林園區東西汕海堤整體環境營造工程(第一期)',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '13446000',
#   'ischange': 0},
#  {'no': '71',
#   'proposer_name': '台灣電力股份有限公司台中供電區營運處',
#   'bid_no': '4801100004',
#   'bid_name': '111年度中港、中市及中科等轄所消防設備檢查申報及弱點改善工作',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '3339000',
#   'ischange': 0},
#  {'no': '72',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'B1101254',
#   'bid_name': '美濃區廣林里雙溪橋下游及甲河橋下游護岸修復工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '4677841',
#   'ischange': 0},
#  {'no': '73',
#   'proposer_name': '國立陽明交通大學附設醫院',
#   'bid_no': '110216Y51',
#   'bid_name': '滅菌治療巾單價開口契約',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '250000',
#   'ischange': 0},
#  {'no': '74',
#   'proposer_name': '雲林縣東勢鄉公所',
#   'bid_no': '11100001',
#   'bid_name': '111年東勢鄉國際臺灣胡蘿蔔日暨農特產品行銷活動',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '920000',
#   'ischange': 0},
#  {'no': '75',
#   'proposer_name': '台灣電力股份有限公司大甲溪發電廠',
#   'bid_no': '2551100002',
#   'bid_name': '大甲溪發電廠谷關分廠主變壓器低壓側套管採購帶安裝',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/21',
#   'budget': '735000',
#   'ischange': 0},
#  {'no': '76',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100502097A',
#   'bid_name': '110年7月及8月豪雨C1-004中寮鄉投22線12K+800~13K+000道路災修復建工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '6204100',
#   'ischange': 0},
#  {'no': '77',
#   'proposer_name': '高雄市政府水利局',
#   'bid_no': 'C1101249',
#   'bid_name': '瑞山里下尾埔6-6號(近林夏美宅)下邊坡滑落路基掏空災害復建工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '5784349',
#   'ischange': 0},
#  {'no': '78',
#   'proposer_name': '苗栗縣苗栗市公所',
#   'bid_no': 'A827',
#   'bid_name': '111年度鄰長為民服務無鉛汽油油料採購案',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '2541600',
#   'ischange': 0},
#  {'no': '79',
#   'proposer_name': '嘉義縣中埔鄉公所',
#   'bid_no': '1100088',
#   'bid_name': '三層村7鄰茅埔農路災修復建工程',
#   'times': '04',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '2448000',
#   'ischange': 0},
#  {'no': '80',
#   'proposer_name': '國立成功大學醫學院附設醫院',
#   'bid_no': 'H111053',
#   'bid_name': '化學抽氣櫃1個',
#   'times': '02',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/17',
#   'budget': '430000',
#   'ischange': 0},
#  {'no': '81',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100505160A',
#   'bid_name': '110南投市東山里大埤街30巷支線道路改善工程等2件',
#   'times': '06',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '934500',
#   'ischange': 0},
#  {'no': '82',
#   'proposer_name': '金門縣採購招標所',
#   'bid_no': 'N110230220353',
#   'bid_name': '110年度0.096L-53度金門高粱酒(53度)(廈門)標籤等六項',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '1047600',
#   'ischange': 0},
#  {'no': '83',
#   'proposer_name': '金門縣採購招標所',
#   'bid_no': 'N111320830016',
#   'bid_name': '柏村國小111年度學生早午餐廚工外包承攬(固定單價決標)',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '392700',
#   'ischange': 0},
#  {'no': '84',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1100505153A-1',
#   'bid_name': '110中寮鄉八仙村八杞山段679地號農路改善工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '1561800',
#   'ischange': 0},
#  {'no': '85',
#   'proposer_name': '新北市雙溪區公所',
#   'bid_no': '111002',
#   'bid_name': '111年度雙溪區市管河川維持河道暢通及環境整理等工程（開口合約）',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '4486272',
#   'ischange': 0},
#  {'no': '86',
#   'proposer_name': '彰化縣員林市饒明國民小學',
#   'bid_no': '1110113',
#   'bid_name': '幼兒園110學年度下學期及111學年度幼兒餐點食材採購',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '800290',
#   'ischange': 0},
#  {'no': '87',
#   'proposer_name': '台灣自來水股份有限公司第五區管理處',
#   'bid_no': '111052A007',
#   'bid_name': '延性鑄鐵製分水鞍乙批',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/26',
#   'budget': '3685290',
#   'ischange': 0},
#  {'no': '88',
#   'proposer_name': '交通部公路總局第三區養護工程處',
#   'bid_no': '1110004871',
#   'bid_name': '台20線明霸克露橋防避災資訊設備服務工作',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '2332302',
#   'ischange': 0},
#  {'no': '89',
#   'proposer_name': '南投縣政府',
#   'bid_no': '110060420A',
#   'bid_name': '仁愛鄉互助村互助國小周邊環境景觀改善工程(110060420)',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '2244000',
#   'ischange': 0},
#  {'no': '90',
#   'proposer_name': '交通部臺灣鐵路管理局',
#   'bid_no': 'L0511P1001R',
#   'bid_name': '臺北車站指標及視障引導設施改善工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '8813377',
#   'ischange': 0},
#  {'no': '91',
#   'proposer_name': '台灣電力股份有限公司大潭發電廠',
#   'bid_no': '3801100004',
#   'bid_name': '大潭發電廠111~112年度汽機閥類檢修工作',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/02/08',
#   'budget': '19949680',
#   'ischange': 0},
#  {'no': '92',
#   'proposer_name': '澎湖縣政府文化局',
#   'bid_no': 'PT-111001',
#   'bid_name': '111年度澎湖縣政府文化局圖書資料採購案',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/27',
#   'budget': '1069000',
#   'ischange': 0},
#  {'no': '93',
#   'proposer_name': '高雄榮民總醫院',
#   'bid_no': 'LP11190',
#   'bid_name': '碎冰機(3台)',
#   'times': '03',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '294000',
#   'ischange': 0},
#  {'no': '94',
#   'proposer_name': '國立臺灣大學醫學院附設醫院',
#   'bid_no': 'TM101120',
#   'bid_name': '111年首能取超音波內視鏡細針生檢系統（單次使用）單價合約招標案',
#   'times': '01',
#   'typ': '選擇性招標(個案)',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '986100',
#   'ischange': 0},
#  {'no': '95',
#   'proposer_name': '交通部高速公路局中區養護工程分局',
#   'bid_no': '110C010P087',
#   'bid_name': '111年南投段轄區邊坡維護工程',
#   'times': '01',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/25',
#   'budget': '34540559',
#   'ischange': 0},
#  {'no': '96',
#   'proposer_name': '南投縣政府',
#   'bid_no': '1110504045A',
#   'bid_name': '110國姓北坑溪排水(斗山橋上游)左側護岸及路面改善工程',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/19',
#   'budget': '14640000',
#   'ischange': 0},
#  {'no': '97',
#   'proposer_name': '苗栗縣政府',
#   'bid_no': '110233a',
#   'bid_name': '三義運動公園營造計畫暨新設休憩空間工程',
#   'times': '05',
#   'typ': '公開招標',
#   'clas': '工程類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '8867000',
#   'ischange': 0},
#  {'no': '98',
#   'proposer_name': '新竹市政府',
#   'bid_no': '1100344',
#   'bid_name': '建築線指示（定）案線上申辦暨書圖檔案數位化上傳系統開發案',
#   'times': '01',
#   'typ': '經公開評選或公開徵求之限制性招標',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/24',
#   'budget': '2600000',
#   'ischange': 0},
#  {'no': '99',
#   'proposer_name': '台灣電力股份有限公司第三核能發電廠',
#   'bid_no': '3521000255',
#   'bid_name': '鉛蓄電池 6V 36AH 密閉型一批(開放契約)',
#   'times': '02',
#   'typ': '公開招標',
#   'clas': '財物類',
#   'date': '111/01/13',
#   'enddate': '111/01/20',
#   'budget': '1552110',
#   'ischange': 0},
#  {'no': '100',
#   'proposer_name': '桃園市平鎮區平興國民小學',
#   'bid_no': 'C0312-298',
#   'bid_name': '111年度學生游泳教學',
#   'times': '01',
#   'typ': '公開取得報價單或企劃書',
#   'clas': '勞務類',
#   'date': '111/01/13',
#   'enddate': '111/01/18',
#   'budget': '369600',
#   'ischange': 0},
#  ...]

# %%
d
# import charts
# 資料庫參數設定
db_settings = {
    "host": "127.0.0.1",
    "port": 3306,
    "user": "root",
    "password": "As123459362",
    "db": "pttcrawler",
    "charset": "utf8",
    "autocommit":True
}
time_start = time.time() #開始計時
wrong = 0
try:
    # 建立Connection物件
    conn = pymysql.connect(**db_settings)
    # 建立Cursor物件
    with conn.cursor() as cursor:
      #資料表相關操作
        get_max_log_id="select MAX(UID) FROM log"
        # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
        command = "INSERT INTO gov_purchase(log_UID, proposer_name, bid_no, bid_name, times, typ, clas, date, enddate, budget, ischange)VALUES(%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s)"
        command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
        # 紀錄開始
        cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "start", "", ""))
        # 取得 log 的 UID
        cursor.execute(get_max_log_id)
        log_UID = str(cursor.fetchone()[0])
        # 執行
        for raw_data in raw_datas:
            try:
                cursor.execute(command, (int(log_UID), raw_data["proposer_name"], raw_data["bid_no"], raw_data["bid_name"], raw_data["times"], raw_data["typ"], raw_data["clas"], raw_data["date"], raw_data["enddate"], raw_data["budget"], raw_data["ischange"]))
            except Exception as err:
                wrong = wrong + 1
                cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "wrong", str(raw_data), str(err)))
                continue
        # 紀錄結束
        if wrong==0:
            cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "finish", "well_completed", ""))
        else:
            cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "finish", wrong + "records are wrong", ""))
except Exception as ex:
    print(ex)
        
time_end = time.time()    #結束計時
time_c= time_end - time_start   #執行所花時間
print('time cost', time_c, 's')
# Out:
# time cost 1.4671475887298584 s

# %%
len(raw_datas)
# Out:
# 866
