# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import datetime
import pymysql
from flask import Flask,jsonify, request
# from fake_useragent import UserAgent
import cv2
import numpy as np
import time
from urllib.parse import urlencode
import threading
import sys
import os
import json
import shutil
import traceback
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import base64

# %%
# db_settings = {
#     "host": "127.0.0.1",
#     "port": 3306,
#     "user": "root",
#     "password": "As123459362",
#     "db": "pttcrawler",
#     "charset": "utf8",
#     "autocommit":True
# }
db_settings = {
    "host": "60.250.109.71",
    "port": 23306,
    "user": "xuan",
    "password": "Qaz123",
    "db": "tender",
    "charset": "utf8mb4",
    "autocommit":True
}
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "web.pcc.gov.tw",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
     #使用者代理
}

# %%
#lxml pyinstaller編不動，nuitka不行
#parser = "lxml"
parser = "html.parser"
parser_detail = 'html5lib'

# %%
#創建一個資料夾存放驗證用撲克牌圖片
path = './temp_validate_img'
if os.path.exists(path):
    shutil.rmtree (path)
    os.mkdir(path)
else:
    os.mkdir(path)

# %%
# 從免費代理網站取得代理ip
def get_proxy_ip(isHttps):
    url = {"usproxy":"https://www.us-proxy.org/","freeproxylist":"https://free-proxy-list.net/"}
    metas=[]
    for i in url:
        print(i)
        r = rq.get(url[i],verify=False)
        html_doc = r.text
        soup = BeautifulSoup(html_doc, parser)
        trs = soup.select("table.table.table-striped.table-bordered tr")  
        for tr in trs:
            tds = tr.select("td")
            if len(tds) > 6:
                ifScheme = tds[6].text
                ip = tds[0].text
                port = tds[1].text
                anonymity = tds[4].text
                proxy = "%s:%s"%(ip, port)
                meta = {
                    'proxyIp': proxy,
                    'connect_times':1,
                    'successful_connect_times':0,
                    'qual_ratio':0,
                    'isDelete':False,
                    'fromm':i
                  }
                if ifScheme == isHttps:
                    if ifScheme == "yes":
                        meta['ishttps'] = True
                        # https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#https-proxy-error-http-proxy
                        meta['proxyIp'] = "http://" + meta['proxyIp']
                    elif ifScheme == "no":
                        meta['ishttps'] = False
                        meta['proxyIp'] = "http://" + meta['proxyIp']
                    meta = test_proxy(meta,timeout_sec=3)
                    metas.append(meta)
                    continue                    
    #------------------------------------
    headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "free-proxy.cz",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
    "User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
     #使用者代理
}
    
    if isHttps =="yes":
        pp = 'https'
    elif isHttps =="no":
        pp = 'http'
    with rq.session() as s:
        for j in range(1,4):
            try:
                r = s.get(f"http://free-proxy.cz/zh/",headers=headers,timeout=10)
                r = s.get(f"http://free-proxy.cz/zh/proxylist/country/all/{pp}/ping/all/{j}",headers=headers,timeout=10)
                print("free-proxy.cz抓取頁數： "+str(j))
            except Exception as e:
                print(e)
                continue
            print(r.url)
            html_doc = r.text
            soup = BeautifulSoup(html_doc, parser)
            proxylist = soup.select('table#proxy_list tr')[1:]
            print(len(proxylist))
            for i in proxylist:
                try:
                    try:
                        ip = base64.b64decode(re.search(r'Base64\.decode\(\"(.*)\"\)',str(i.select('td')[0])).group(1)).decode("utf-8")
                    except AttributeError :
                        continue
                    port = i.select('td')[1].text
                    Protocol  = i.select('td')[2].text.lower()
                    place=i.select('td')[2].text.lower()
                    meta = {
                        'proxyIp': 'http://'+ str(ip) +':'+ str(port),
                        'connect_times':1,
                        'successful_connect_times':0,
                        'qual_ratio':0,
                        'isDelete':False,
                        'fromm':'freeProxyCZ'
                      }
                    if Protocol =='https' and isHttps =="yes":
                        meta['ishttps'] = True
                        meta = test_proxy(meta,timeout_sec=3)
                        metas.append(meta)
                    elif Protocol =='http' and isHttps =="no":
                        meta['ishttps'] = False
                        meta = test_proxy(meta,timeout_sec=3)
                        metas.append(meta)
                except:
                    continue
                if len(proxylist)<37:
                    break
    return metas

# %%
# 測試 proxy 可用性
def test_proxy(proxy,timeout_sec,headers={}):
    print(proxy['proxyIp'])
    try:
        if proxy['ishttps'] == True:
            url = "https://icanhazip.com/"
            r = rq.get(url, headers = headers,proxies={'https':proxy['proxyIp'],},verify=False, timeout=timeout_sec)
        elif proxy['ishttps'] == False:
            url = "http://icanhazip.com/"
            r = rq.get(url, headers = headers,proxies={'http':proxy['proxyIp'],},verify=False, timeout=timeout_sec)
        print(r.status_code)
        if r.status_code==200:
            proxy['isValidate']=True
            proxy['successful_connect_times']=1
            proxy['qual_ratio']=1
        else:
            proxy['isValidate']=False
    except Exception as ex:
        proxy['isValidate']=False
        #print(ex)
    print("---------------")
    return proxy

# %%
# 將取得的代理ip寫入資料庫，此函數也可以更新已寫入資料庫的資料
def send_ip(proxies_pool_https, db_settings,typee="",send_log = True,new = False):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    wrong = 0
    try:
        # 建立Connection物件
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor() as cursor:
          #資料表相關操作
            get_max_log_id="select MAX(UID) FROM log"
            # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
            command = "INSERT INTO proxy_ip(log_UID, proxyIp, connect_times, successful_connect_times, qual_ratio, isValidate, ishttps,isDelete, fromm)VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),connect_times =connect_times+values(connect_times),successful_connect_times=successful_connect_times+values(successful_connect_times),qual_ratio=((successful_connect_times+values(successful_connect_times))/(connect_times+values(connect_times))),isValidate = values(isValidate),ishttps=values(ishttps),isDelete=values(isDelete)"
            if new:
                command = "INSERT INTO proxy_ip(log_UID, proxyIp, connect_times, successful_connect_times, qual_ratio, isValidate, ishttps,isDelete, fromm)VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),connect_times = values(connect_times),successful_connect_times=values(successful_connect_times),qual_ratio=values(qual_ratio),isValidate = values(isValidate),ishttps=values(ishttps),isDelete=values(isDelete)"
            command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
            # 紀錄開始 (暫時取消)
#             if send_log:
#                 cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "start", typee, ""))
            # 取得 log 的 UID
            cursor.execute(get_max_log_id)
            log_UID = str(cursor.fetchone()[0])
            # 組合數據
            if type(proxies_pool_https) == list:
                for proxy in proxies_pool_https:
                    data_combine.append((log_UID, proxy["proxyIp"], proxy["connect_times"], proxy["successful_connect_times"], proxy["qual_ratio"], proxy["isValidate"], proxy["ishttps"], proxy["isDelete"], proxy["fromm"]))  # 注意要用两个括号扩起来
            else:
                data_combine.append((log_UID, proxies_pool_https["proxyIp"], proxies_pool_https["connect_times"], proxies_pool_https["successful_connect_times"], proxies_pool_https["qual_ratio"], proxies_pool_https["isValidate"], proxies_pool_https["ishttps"], proxies_pool_https["isDelete"], proxies_pool_https["fromm"]))  # 注意要用两个括号扩起来
            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as err:
                print(err)
                wrong = wrong + 1
                print(wrong)
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "wrong" + str(wrong), "", str(err)))
            # 紀錄結束
            if wrong==0 and send_log:
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "success", "", ""))
            elif wrong>0 and send_log:
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "fail", str(wrong) + " records are wrong", ""))
    except Exception as ex:
        print(ex)
        print(data_combine)
    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('time cost', time_c, 's')

# %%
# p_yes=get_proxy_ip("yes")
# send_ip(p_yes, db_settings ,"only https",new = True)

# %%
# 從資料庫取出ip，未來有自架proxy的話，可以把proxy放到資料庫內，並設定 mine = 1，這樣就會固定抓這個proxy來用，如果沒有自架proxy的話，就還需要多寫 proxy expire 的處置方式。
def get_ip_from_db(isHttps,db_settings,qual_ratio=0,connect_times=4,new=True):
    try:
        # 建立Connection物件
        data=[]
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor(pymysql.cursors.DictCursor) as cursor:
          #資料表相關操作
            if isHttps=="yes":
                get_ip=f"select * FROM proxy_ip where (isValidate = 1 or isHttps = 1 or mine = 1) and isDelete is False and ( qual_ratio > {qual_ratio} or ( connect_times < {connect_times} ))"
            elif isHttps=="no":
                get_ip=f"select * FROM proxy_ip where isHttps = 0 and isDelete is False and ( qual_ratio > {qual_ratio} or ( connect_times < {connect_times} )) or (mine = 1 and isHttps = 0)"
            cursor.execute(get_ip)
            datas = cursor.fetchall()
        if new:
            for data in datas:
                data['successful_connect_times']=0
                data['connect_times']=0
                data['qual_ratio']=0
    except Exception as ex:
        print(ex)
    return datas

# %%
#撲克牌圖片驗證用算法
def pHash(img):
    # 感知哈希算法
    # 缩放32*32
    img = cv2.resize(img, (32, 32))   # , interpolation=cv2.INTER_CUBIC
 
    # 转换为灰度图
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # 将灰度图转为浮点型，再进行dct变换
    dct = cv2.dct(np.float32(gray))
    # opencv实现的掩码操作
    dct_roi = dct[0:8, 0:8]
 
    hash = []
    avreage = np.mean(dct_roi)
    for i in range(dct_roi.shape[0]):
        for j in range(dct_roi.shape[1]):
            if dct_roi[i, j] > avreage:
                hash.append(1)
            else:
                hash.append(0)
    return hash

# %%
#撲克牌圖片驗證用算法 - 比較
def cmpHash(hash1, hash2):
    # Hash值对比
    # 算法中1和0顺序组合起来的即是图片的指纹hash。顺序不固定，但是比较的时候必须是相同的顺序。
    # 对比两幅图的指纹，计算汉明距离，即两个64位的hash值有多少是不一样的，不同的位数越小，图片越相似
    # 汉明距离：一组二进制数据变成另一组数据所需要的步骤，可以衡量两图的差异，汉明距离越小，则相似度越高。汉明距离为0，即两张图片完全一样
    n = 0
    # hash长度不同则返回-1代表传参出错
    if len(hash1) != len(hash2):
        return -1
    # 遍历判断
    for i in range(len(hash1)):
        # 不相等则n计数+1，n最终为相似度
        if hash1[i] != hash2[i]:
            n = n + 1
    return n

# %%
#進行撲克牌驗證
def validate_ip(s,url,proxies):
    while True:
        response = s.get(url, proxies=proxies)
        html_doc = response.text
        soup = BeautifulSoup(html_doc, parser)
        img_url_d = soup.select('form#validateForm img')
        img_url_head = "http://web.pcc.gov.tw/tps/tpam/"
        img_data = []
        img_data.append({'img_src':img_url_head +img_url_d[0]['src'],'id':'question'})
        for j in img_url_d[2:]:
            d = {'img_src':img_url_head +j['src'],'id':j['alt']}
            img_data.append(d)
        right_hash_com =[]
        left_hash_com =[]
        
        path = './temp_validate_img'
        for k in img_data:
            response = s.get(k['img_src'])
            with open(path +'/'+ k['id']+'.jpg', 'wb') as file:
                file.write(response.content)
                file.close() 
            if k ==img_data[0]:
                img = cv2.imread(path +'/'+"question.jpg")
                crop_img = img[0:96, 6:77]
                ret,crop_img = cv2.threshold(crop_img,127,255,cv2.THRESH_BINARY)
                right_imageVar = pHash(crop_img)
                crop_img = img[0:96, 89:160]
                ret,crop_img = cv2.threshold(crop_img,127,255,cv2.THRESH_BINARY)
                left_imageVar = pHash(crop_img)
            image = cv2.imread(path +'/'+k['id']+'.jpg')
            ret,image = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
            right = cmpHash(pHash(image),right_imageVar)
            left = cmpHash(pHash(image),left_imageVar)
            right_hash_com.append(right)
            left_hash_com.append(left)

        right_idx = np.argmin(right_hash_com[1:])
        left_idx = np.argmin(left_hash_com[1:])
        data="choose=" +img_data[right_idx+1]['id']+"&choose="+img_data[left_idx+1]['id']+"&id="+re.match(r'.*id=(.*)', url, flags=0).group(1)
        response = s.post(url,headers = {'Content-Type':'application/x-www-form-urlencoded'}, proxies=proxies,data=data, timeout=10)
        if not re.search("為預防惡意程式針對本系統進行大量查詢致影響系統服務品質",response.text) and response.status_code == 200:
            print("通過驗證")
            break
        else:
            print("驗證失敗")

    return response

# %%
#取出字典某 key 值對應 value，若找無此 key 值，則回傳空字串 
def dicMemberCheck(key, dicObj):
    if key in dicObj:
        return dicObj[key]
    else:
        return ""
# dicMemberCheck('標案案號', {'標案案號':123,'ji3':456})

# %%
# 抓招標、決標內頁資料
def get_tenderDeclaration_detail(s,href,proxies,refresh_proxies,diff_seconds_conn=1.2,headers={},typee=""):
    #with requests.Session() as s:
    headers["User-Agent"] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
    breakdown = "no"
    x=0
    #測試proxy連線可用性
    while True:
        x=x+1
        #拉長每一次連接的時間
        time.sleep(diff_seconds_conn)
        ran = np.random.randint(len(proxies))
        try:
            proxies[ran]['connect_times'] =  proxies[ran]['connect_times'] + 1
            proxies[ran]['qual_ratio'] = proxies[ran]['successful_connect_times'] / proxies[ran]['connect_times']
            #s.get("https://web.pcc.gov.tw/pis/main/pis/client/index.do",verify=False , headers = headers, proxies={'http':proxies[0]['proxyIp']}, timeout=10)
            print(f"{proxies[ran]['proxyIp']} 準備進入，{href}")
            r = s.get(href, headers = headers,verify=False,proxies={'https':proxies[ran]['proxyIp']}, timeout=(4,7))
            print("內頁取得點存活")
            if re.match(r'.*validate.*',r.url, flags=0):
                print(f"{proxies[ran]['proxyIp']} 準備執行驗證")
                r = validate_ip(s,r.url,proxies={'https':proxies[ran]['proxyIp']})
                print("執行驗證完成")
            if re.search(r'公告日',r.text):
                proxies[ran]['successful_connect_times'] =  proxies[ran]['successful_connect_times'] + 1
                proxies[ran]['qual_ratio'] = proxies[ran]['successful_connect_times'] / proxies[ran]['connect_times']
                print("內頁連線數："+str(x))
                x = 0
                break
            else:
                print("內頁資料錯誤，嘗試切換proxy")
                refresh_proxies.append(proxies.pop(ran))
                print(str(refresh_proxies[-1]['proxyIp']) + "連接失敗，還剩餘 " + str(len(proxies)) +" 個proxy")
                pass            
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            #print(errMsg)
            if len(proxies) == 1:
                detail_data_html=""
                breakdown = "yes"
                print("proxy 不夠用了，重新獲取")
                refresh_proxies.append(proxies.pop(ran))
                break
            refresh_proxies.append(proxies.pop(ran))
            print(str(refresh_proxies[-1]['proxyIp']) + "連接失敗，還剩餘 " + str(len(proxies)) +" 個proxy")

    detail_data={}
    if breakdown == "yes":
        return detail_data,detail_data_html,proxies,refresh_proxies

    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser_detail)
    if typee=="predict":
        #政府採購預告
        detail_data_html = soup.select('div#printRange')[0]
        for i in detail_data_html.select('table'):
            for j in i.select('tr'):
                try:
                    col = j.select('th')[-1].text.strip()
                except:
                    col = j.select('td')[-2].text.strip()
                val = j.select('td')[-1].text.strip()
                detail_data[col]=val

    elif typee =="final":
        detail_data_html = soup.select('div#printArea.main table')[0]
        # 決標公告：無法決標、撤銷公告
        if soup.select('div#printArea.main div#hidden_message_id'):
            detail_data['really_final']=0
            block_data = detail_data_html.select('tr')
            if not block_data[0].text.strip():
                del block_data[0]
            if re.search(r'紅色字體表示此次更正公',block_data[0].text):
                del block_data[0]
            for j in block_data:
                try:
                    try:
                        col = j.select('th')[-1].text.strip()
                    except:
                        col = j.select('td')[-2].text.strip()
                    val = j.select('td')[-1].text.strip()
                    detail_data[col]=val
                except:
                    print("出錯了了了了了")
                    print(r.url)
                    print(j)
                    pass
                
        else:
            #決標公告：正常決標公告
            detail_data['really_final']=1
            for i in range(1,10):
                block_data = detail_data_html.select('tr.award_table_tr_'+str(i))
                if i == 1 and re.search(r'紅色字體表示此次更正公',block_data[0].text):
                    del block_data[0]
                if len(block_data) == 0 :
                    continue
                else:
                    del block_data[0]

                for j in block_data:
                    try:
                        try:
                            col = j.select('th.T11b')[-1].text.strip()
                        except:
                            col = j.select('td.newstop')[-2].text.strip()
                        val = j.select('td')[-1].text.strip()
                        detail_data[col]=val
                    except:
                        print("出錯啦啦啦啦啦")
                        print(r.url)
                        print(j)
                        continue                    
                        
    else:
        #招標公告
        detail_data_html = soup.select('div#print_area table.table_block.tender_table')[0]
        for i in range(1,10):
            block_data = detail_data_html.select('tr.tender_table_tr_'+str(i))
            if len(block_data) == 0 :
                continue
            for j in block_data:
                try:
                    try:
                        col = j.select('th')[-1].text.strip()
                    except:
                        col = j.select('td')[-2].text.strip()
                    val = j.select('td')[-1].text.strip()
                    detail_data[col]=val
                except:
                    pass
    return detail_data,detail_data_html,proxies,refresh_proxies

# %%
# 抓公開徵求內頁資料
def get_searchAppeal_detail(headers,detail_connect):
    detail_data={}
    detail_data_html=""
    headers['Content-Type']='application/x-www-form-urlencoded'
    url = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/tp.do?method=initialAppealViewVendor&pMenu=common"
    while True:
        try:
            r = rq.post(url,data = detail_connect, headers = headers)
            if r.status_code == 200:
                break
        except Exception as ex:
            time.sleep(1201)
            print(ex)
            print("get_searchAppeal_detail出錯")

    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser)
    if re.search(r'無符合此筆公開徵求廠商條件資料',html_doc):
        print("無符合此筆公開徵求廠商條件資料，可能公告已撤銷")
        detail_data_html = soup.select('center table')[0]
        return detail_data,detail_data_html
    
    detail_data_html = soup.select('div#printRange')[0]

    for i in detail_data_html.select('tr'):
        try:
            col = i.select('th')[-1].text.strip()
        except:
            col = i.select('td')[0].text.strip()
        val = i.select('td')[-1].text.strip()
        detail_data[col]=val
    return detail_data,detail_data_html

# %%
# 抓公開閱覽內頁資料
def get_publicRead_detail(detail_connect):
    while True:
        try:
            r = rq.get(detail_connect, headers = headers)
            if r.status_code == 200:
                break
        except Exception as ex:
            time.sleep(1201)
            print(ex)
            print("get_publicRead_detail出錯")
    
    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser)
    detail_data_html_1 = soup.select('div#printRange')[0]
    detail_data_html_2 = soup.select('td#page table table table table')[2]
    detail_data={}
    for i in detail_data_html_1.select('tr'):
        col = i.select('th')[-1].text.strip()
        val = i.select('td')[-1].text.strip()
        detail_data[col]=val
    return detail_data,str(detail_data_html_1) +str(detail_data_html_2)

# %%
# current_date = (datetime.date.today()- datetime.timedelta(days=30)).strftime("%Y/%m/%d")
# current_date = str(int(current_date[0:4])-1911) + current_date[4:]
# print(current_date)
# s = rq.session()

# url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance"
# data={'method':'search','searchMethod':'true','searchTarget':'ATM','hid_1':1,'hid_2':1,'hid_3':1,'tenderStatus':'5,6,20,28,8,21,22,29,33,9,23','btnQuery':'查詢','awardAnnounceStartDate':current_date,'awardAnnounceEndDate':current_date}
# r = s.post(url_first,data = data)

# url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex=1"
# r = s.get(url)
# soup = BeautifulSoup(r.text, parser)
# data = soup.select("div#print_area table tr")

# for i in data[1:3]:
#     #機關名稱
#     proposer_name=i.select('td')[1].text.strip()
#     print(proposer_name)
#     #標案案號
#     bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
#     print(bid_no)

# %%
def get_only_detail(tenderType,raw_datas,diff_seconds_data,diff_seconds_conn,headers, db_settings):
    global progress_final_detail
    global progress_tenderDeclaration_detail
    proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.3)
    refresh_proxies=[]
    longg = len(raw_datas)
    loses=[]
    x=0
    with rq.session() as s:
        s.mount('https://', requests.adapters.HTTPAdapter(pool_connections=25, pool_maxsize=50))
        s.mount('http://', requests.adapters.HTTPAdapter(pool_connections=20, pool_maxsize=40))
        for raw_data in raw_datas:
            time_start = datetime.datetime.now() #開始計時
            print("--------------------")
            try:
                while True:
                    if len(proxies)==0:
                        send_ip(refresh_proxies, db_settings,send_log=False)
                        proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.3)
                        # 避免既有的proxy在qual_ratio的情況下突然失效，要讓這種proxy的qual_ratio降到不會被抓取的水平要很久，所以設置如果 7次都用光proxy就重爬proxy一次
                        if len(proxies)==0 or len(loses)>7:
                            print(f"失敗總次數：{len(loses)}，強制重抓proxy！！！！！！！！！！")
                            loses=[]
                            proxies = get_proxy_ip("yes")
                            send_ip(proxies, db_settings,new = True)
                    (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(s, raw_data['detail_connect'],proxies,refresh_proxies,diff_seconds_conn,headers,typee=raw_data['tenderType']) 
                    str_detail_data_html=str(detail_data_html)
                    if len(detail_data)>0 and (re.search(raw_data['bid_no'],str_detail_data_html) or re.search(raw_data['proposer_name'],str_detail_data_html)):
                        raw_data['detail_data'] = detail_data
                        raw_data['detail_data_html'] = detail_data_html
                        print(raw_data['detail_data']['機關代碼'])
                        time_end = datetime.datetime.now()    #結束計時
                        diff=time_end-time_start
                        if diff.seconds<diff_seconds_data:
                            time.sleep(diff_seconds_data-diff.total_seconds())
                        time_end = datetime.datetime.now()    #結束計時
                        time_c= time_end - time_start   #執行所花時間
                        if tenderType=='tenderDeclaration':
                            progress_tenderDeclaration_detail = f'progress_tenderDeclaration_detail 目前是第 {x+1} 項，抓取該細項內頁花費 {time_c} 秒，進度：{(x+1)*100/longg}%，總共有 {longg} 項'
                            print(progress_tenderDeclaration_detail)
                        elif tenderType=='final':
                            progress_final_detail = f'progress_final_detail 目前是第 {x+1} 項，抓取該細項內頁花費 {time_c} 秒，進度：{(x+1)*100/longg}%，總共有 {longg} 項'
                            print(progress_final_detail)
                        loses=[]
                        x=x+1
                        break
                    else:
                        print(f"失敗總次數：{len(loses)}，危險！")
                        loses.append(1)
            except Exception as ex:
                error_class = ex.__class__.__name__ #取得錯誤類型
                detail = ex.args[0] #取得詳細內容
                cl, exc, tb = sys.exc_info() #取得Call Stack
                lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
                fileName = lastCallStack[0] #取得發生的檔案名稱
                lineNum = lastCallStack[1] #取得發生的行號
                funcName = lastCallStack[2] #取得發生的函數名稱
                errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
                print(errMsg)
                #print("其他錯誤...")
                pass
        
    if x>=1:
        send_ip(refresh_proxies, db_settings,send_log=False)
        send_db(raw_datas[0:x],"detail_data_"+tenderType, db_settings,Notchange=False)
    return x

# %%
#招標決標資料塞進DB
def send_db(raw_datas,data_class, db_settings,Notchange=True):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    # 建立Connection物件
    conn = pymysql.connect(**db_settings)
    # 建立Cursor物件
    with conn.cursor() as cursor:
      #資料表相關操作
        get_max_log_id="select MAX(UID) FROM log"
        # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
        if Notchange:
            command = "INSERT INTO gov_purchase(log_UID, proposer_name, bid_no, bid_name, times, typ, clas, date, enddate, budget, ischange, detail_connect, detail_data, detail_data_html, get_data_date, tenderType)VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),get_data_date=values(get_data_date),times =values(times),typ=values(typ),clas=values(clas),date = values(date),enddate=values(enddate),budget=values(budget),ischange=values(ischange),detail_connect=values(detail_connect)"
        else:
            command = "INSERT INTO gov_purchase(log_UID, proposer_name, bid_no, bid_name, times, typ, clas, date, enddate, budget, ischange, detail_connect, detail_data, detail_data_html, get_data_date, tenderType)VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),get_data_date=values(get_data_date),times =values(times),typ=values(typ),clas=values(clas),date = values(date),enddate=values(enddate),budget=values(budget),ischange=values(ischange),detail_connect=values(detail_connect),detail_data=values(detail_data),detail_data_html=values(detail_data_html)"
        command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
        # 紀錄開始 (暫時取消)
#         cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "start", data_class, ""))
        # 取得 log 的 UID
        cursor.execute(get_max_log_id)
        log_UID = str(cursor.fetchone()[0])
        # 空資料處理
        if len(raw_datas)==0:
            cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "wrong", data_class, "nodata"))
        # 組合數據
        else:
            #抓取到的資料是以公告日期最新到最舊，這樣寫進資料庫時最新的資料會被舊的資料覆蓋住，所以加一個reversed，讓最舊的先進去
            for raw_data in reversed(raw_datas):
                data_combine.append((int(log_UID), raw_data["proposer_name"], raw_data["bid_no"], raw_data["bid_name"], raw_data["times"], raw_data["typ"], raw_data["clas"], raw_data["date"], raw_data["enddate"], raw_data["budget"], raw_data["ischange"], raw_data["detail_connect"], json.dumps(raw_data["detail_data"]), str(raw_data["detail_data_html"]),raw_data["get_data_date"], raw_data["tenderType"]))  # 注意要用两个括号扩起来

            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as ex:
                error_class = ex.__class__.__name__ #取得錯誤類型
                detail = ex.args[0] #取得詳細內容
                cl, exc, tb = sys.exc_info() #取得Call Stack
                lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
                fileName = lastCallStack[0] #取得發生的檔案名稱
                lineNum = lastCallStack[1] #取得發生的行號
                funcName = lastCallStack[2] #取得發生的函數名稱
                errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
                print(errMsg)
                cursor.execute(command_log, (datetime.datetime.now(), "fail", "wrong", data_class, error_class + detail + errMsg))
        # 紀錄結束
        cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "success", data_class, str(len(raw_datas)) + " datas was completed"))


    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('招標決標資料塞進DB，time cost', time_c, 's')

# %%
# from collections import Counter   #引入Counter
# a = ll
# b = dict(Counter(a))
# print ([key for key,value in b.items()if value > 1])  #只展示重複元素

# %%
proxies = get_ip_from_db("yes",db_settings)
global waitt
waitt = False
x5 = gov_serach_crawler("searchAppeal",proxies,db_settings, headers = headers,start_page = 1,day_before=0)
# send_db(x5,"tenderDeclaration", db_settings)
# Out:
# ！！！！！爬取日期：111/03/13
# 外頁進入點存活
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=1
# 這是第 1 頁，的第 1 項，總共有 550 項，目前進度是 0.18181818181818182 %。
# 這是第 1 頁，的第 2 項，總共有 550 項，目前進度是 0.36363636363636365 %。
# 這是第 1 頁，的第 3 項，總共有 550 項，目前進度是 0.5454545454545455 %。
# 無符合此筆公開徵求廠商條件資料，可能公告已撤銷
# 這是第 1 頁，的第 4 項，總共有 550 項，目前進度是 0.7272727272727273 %。
# 無符合此筆公開徵求廠商條件資料，可能公告已撤銷
# 這是第 1 頁，的第 5 項，總共有 550 項，目前進度是 0.9090909090909091 %。
# 這是第 1 頁，的第 6 項，總共有 550 項，目前進度是 1.090909090909091 %。
# 這是第 1 頁，的第 7 項，總共有 550 項，目前進度是 1.2727272727272727 %。
# 這是第 1 頁，的第 8 項，總共有 550 項，目前進度是 1.4545454545454546 %。
# 這是第 1 頁，的第 9 項，總共有 550 項，目前進度是 1.6363636363636365 %。
# 這是第 1 頁，的第 10 項，總共有 550 項，目前進度是 1.8181818181818181 %。
# 此分頁抓取總耗時： 0:00:06.900987 s
# 550
# 10
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=2
# 這是第 2 頁，的第 1 項，總共有 550 項，目前進度是 2.0 %。
# 這是第 2 頁，的第 2 項，總共有 550 項，目前進度是 2.181818181818182 %。
# 這是第 2 頁，的第 3 項，總共有 550 項，目前進度是 2.3636363636363638 %。
# 這是第 2 頁，的第 4 項，總共有 550 項，目前進度是 2.5454545454545454 %。
# 這是第 2 頁，的第 5 項，總共有 550 項，目前進度是 2.727272727272727 %。
# 這是第 2 頁，的第 6 項，總共有 550 項，目前進度是 2.909090909090909 %。
# 這是第 2 頁，的第 7 項，總共有 550 項，目前進度是 3.090909090909091 %。
# 這是第 2 頁，的第 8 項，總共有 550 項，目前進度是 3.272727272727273 %。
# 這是第 2 頁，的第 9 項，總共有 550 項，目前進度是 3.4545454545454546 %。
# 這是第 2 頁，的第 10 項，總共有 550 項，目前進度是 3.6363636363636362 %。
# 此分頁抓取總耗時： 0:00:07.421987 s
# 550
# 20
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=3
# 這是第 3 頁，的第 1 項，總共有 550 項，目前進度是 3.8181818181818183 %。
# 這是第 3 頁，的第 2 項，總共有 550 項，目前進度是 4.0 %。
# 這是第 3 頁，的第 3 項，總共有 550 項，目前進度是 4.181818181818182 %。
# 這是第 3 頁，的第 4 項，總共有 550 項，目前進度是 4.363636363636364 %。
# 這是第 3 頁，的第 5 項，總共有 550 項，目前進度是 4.545454545454546 %。
# 這是第 3 頁，的第 6 項，總共有 550 項，目前進度是 4.7272727272727275 %。
# 這是第 3 頁，的第 7 項，總共有 550 項，目前進度是 4.909090909090909 %。
# 這是第 3 頁，的第 8 項，總共有 550 項，目前進度是 5.090909090909091 %。
# 這是第 3 頁，的第 9 項，總共有 550 項，目前進度是 5.2727272727272725 %。
# 這是第 3 頁，的第 10 項，總共有 550 項，目前進度是 5.454545454545454 %。
# 此分頁抓取總耗時： 0:00:09.355737 s
# 550
# 30
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=4
# 這是第 4 頁，的第 1 項，總共有 550 項，目前進度是 5.636363636363637 %。
# 這是第 4 頁，的第 2 項，總共有 550 項，目前進度是 5.818181818181818 %。
# 這是第 4 頁，的第 3 項，總共有 550 項，目前進度是 6.0 %。
# 這是第 4 頁，的第 4 項，總共有 550 項，目前進度是 6.181818181818182 %。
# 這是第 4 頁，的第 5 項，總共有 550 項，目前進度是 6.363636363636363 %。
# 這是第 4 頁，的第 6 項，總共有 550 項，目前進度是 6.545454545454546 %。
# 這是第 4 頁，的第 7 項，總共有 550 項，目前進度是 6.7272727272727275 %。
# 這是第 4 頁，的第 8 項，總共有 550 項，目前進度是 6.909090909090909 %。
# 這是第 4 頁，的第 9 項，總共有 550 項，目前進度是 7.090909090909091 %。
# 這是第 4 頁，的第 10 項，總共有 550 項，目前進度是 7.2727272727272725 %。
# 此分頁抓取總耗時： 0:00:07.308403 s
# 550
# 40
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=5
# 這是第 5 頁，的第 1 項，總共有 550 項，目前進度是 7.454545454545454 %。
# 這是第 5 頁，的第 2 項，總共有 550 項，目前進度是 7.636363636363637 %。
# 這是第 5 頁，的第 3 項，總共有 550 項，目前進度是 7.818181818181818 %。
# 這是第 5 頁，的第 4 項，總共有 550 項，目前進度是 8.0 %。
# 這是第 5 頁，的第 5 項，總共有 550 項，目前進度是 8.181818181818182 %。
# 這是第 5 頁，的第 6 項，總共有 550 項，目前進度是 8.363636363636363 %。
# 這是第 5 頁，的第 7 項，總共有 550 項，目前進度是 8.545454545454545 %。
# 這是第 5 頁，的第 8 項，總共有 550 項，目前進度是 8.727272727272728 %。
# 這是第 5 頁，的第 9 項，總共有 550 項，目前進度是 8.90909090909091 %。
# 這是第 5 頁，的第 10 項，總共有 550 項，目前進度是 9.090909090909092 %。
# 此分頁抓取總耗時： 0:00:06.491071 s
# 550
# 50
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=6
# 這是第 6 頁，的第 1 項，總共有 550 項，目前進度是 9.272727272727273 %。
# 這是第 6 頁，的第 2 項，總共有 550 項，目前進度是 9.454545454545455 %。
# 這是第 6 頁，的第 3 項，總共有 550 項，目前進度是 9.636363636363637 %。
# 這是第 6 頁，的第 4 項，總共有 550 項，目前進度是 9.818181818181818 %。
# 這是第 6 頁，的第 5 項，總共有 550 項，目前進度是 10.0 %。
# 這是第 6 頁，的第 6 項，總共有 550 項，目前進度是 10.181818181818182 %。
# 這是第 6 頁，的第 7 項，總共有 550 項，目前進度是 10.363636363636363 %。
# 這是第 6 頁，的第 8 項，總共有 550 項，目前進度是 10.545454545454545 %。
# 這是第 6 頁，的第 9 項，總共有 550 項，目前進度是 10.727272727272727 %。
# 這是第 6 頁，的第 10 項，總共有 550 項，目前進度是 10.909090909090908 %。
# 此分頁抓取總耗時： 0:00:05.418938 s
# 550
# 60
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=7
# 這是第 7 頁，的第 1 項，總共有 550 項，目前進度是 11.090909090909092 %。
# 這是第 7 頁，的第 2 項，總共有 550 項，目前進度是 11.272727272727273 %。
# 這是第 7 頁，的第 3 項，總共有 550 項，目前進度是 11.454545454545455 %。
# 這是第 7 頁，的第 4 項，總共有 550 項，目前進度是 11.636363636363637 %。
# 這是第 7 頁，的第 5 項，總共有 550 項，目前進度是 11.818181818181818 %。
# 這是第 7 頁，的第 6 項，總共有 550 項，目前進度是 12.0 %。
# 這是第 7 頁，的第 7 項，總共有 550 項，目前進度是 12.181818181818182 %。
# 這是第 7 頁，的第 8 項，總共有 550 項，目前進度是 12.363636363636363 %。
# 這是第 7 頁，的第 9 項，總共有 550 項，目前進度是 12.545454545454545 %。
# 這是第 7 頁，的第 10 項，總共有 550 項，目前進度是 12.727272727272727 %。
# 此分頁抓取總耗時： 0:00:05.681313 s
# 550
# 70
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=8
# 這是第 8 頁，的第 1 項，總共有 550 項，目前進度是 12.909090909090908 %。
# 這是第 8 頁，的第 2 項，總共有 550 項，目前進度是 13.090909090909092 %。
# 這是第 8 頁，的第 3 項，總共有 550 項，目前進度是 13.272727272727272 %。
# 這是第 8 頁，的第 4 項，總共有 550 項，目前進度是 13.454545454545455 %。
# 這是第 8 頁，的第 5 項，總共有 550 項，目前進度是 13.636363636363635 %。
# 這是第 8 頁，的第 6 項，總共有 550 項，目前進度是 13.818181818181818 %。
# 這是第 8 頁，的第 7 項，總共有 550 項，目前進度是 14.000000000000002 %。
# 這是第 8 頁，的第 8 項，總共有 550 項，目前進度是 14.181818181818182 %。
# 這是第 8 頁，的第 9 項，總共有 550 項，目前進度是 14.363636363636365 %。
# 這是第 8 頁，的第 10 項，總共有 550 項，目前進度是 14.545454545454545 %。
# 此分頁抓取總耗時： 0:00:04.600489 s
# 550
# 80
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=9
# 這是第 9 頁，的第 1 項，總共有 550 項，目前進度是 14.727272727272728 %。
# 這是第 9 頁，的第 2 項，總共有 550 項，目前進度是 14.909090909090908 %。
# 這是第 9 頁，的第 3 項，總共有 550 項，目前進度是 15.090909090909092 %。
# 這是第 9 頁，的第 4 項，總共有 550 項，目前進度是 15.272727272727273 %。
# 這是第 9 頁，的第 5 項，總共有 550 項，目前進度是 15.454545454545453 %。
# 這是第 9 頁，的第 6 項，總共有 550 項，目前進度是 15.636363636363637 %。
# 這是第 9 頁，的第 7 項，總共有 550 項，目前進度是 15.818181818181817 %。
# 這是第 9 頁，的第 8 項，總共有 550 項，目前進度是 16.0 %。
# 這是第 9 頁，的第 9 項，總共有 550 項，目前進度是 16.18181818181818 %。
# 這是第 9 頁，的第 10 項，總共有 550 項，目前進度是 16.363636363636363 %。
# 此分頁抓取總耗時： 0:00:04.463004 s
# 550
# 90
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=10
# 這是第 10 頁，的第 1 項，總共有 550 項，目前進度是 16.545454545454547 %。
# 這是第 10 頁，的第 2 項，總共有 550 項，目前進度是 16.727272727272727 %。
# 這是第 10 頁，的第 3 項，總共有 550 項，目前進度是 16.90909090909091 %。
# 這是第 10 頁，的第 4 項，總共有 550 項，目前進度是 17.09090909090909 %。
# 這是第 10 頁，的第 5 項，總共有 550 項，目前進度是 17.272727272727273 %。
# 這是第 10 頁，的第 6 項，總共有 550 項，目前進度是 17.454545454545457 %。
# 這是第 10 頁，的第 7 項，總共有 550 項，目前進度是 17.636363636363637 %。
# 這是第 10 頁，的第 8 項，總共有 550 項，目前進度是 17.81818181818182 %。
# 這是第 10 頁，的第 9 項，總共有 550 項，目前進度是 18.0 %。
# 這是第 10 頁，的第 10 項，總共有 550 項，目前進度是 18.181818181818183 %。
# 此分頁抓取總耗時： 0:00:05.987724 s
# 550
# 100
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=11
# 這是第 11 頁，的第 1 項，總共有 550 項，目前進度是 18.363636363636363 %。
# 這是第 11 頁，的第 2 項，總共有 550 項，目前進度是 18.545454545454547 %。
# 這是第 11 頁，的第 3 項，總共有 550 項，目前進度是 18.72727272727273 %。
# 這是第 11 頁，的第 4 項，總共有 550 項，目前進度是 18.90909090909091 %。
# 這是第 11 頁，的第 5 項，總共有 550 項，目前進度是 19.090909090909093 %。
# 這是第 11 頁，的第 6 項，總共有 550 項，目前進度是 19.272727272727273 %。
# 這是第 11 頁，的第 7 項，總共有 550 項，目前進度是 19.454545454545453 %。
# 這是第 11 頁，的第 8 項，總共有 550 項，目前進度是 19.636363636363637 %。
# 這是第 11 頁，的第 9 項，總共有 550 項，目前進度是 19.818181818181817 %。
# 這是第 11 頁，的第 10 項，總共有 550 項，目前進度是 20.0 %。
# 此分頁抓取總耗時： 0:00:05.300342 s
# 550
# 110
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=12
# 這是第 12 頁，的第 1 項，總共有 550 項，目前進度是 20.18181818181818 %。
# 這是第 12 頁，的第 2 項，總共有 550 項，目前進度是 20.363636363636363 %。
# 這是第 12 頁，的第 3 項，總共有 550 項，目前進度是 20.545454545454543 %。
# 這是第 12 頁，的第 4 項，總共有 550 項，目前進度是 20.727272727272727 %。
# 這是第 12 頁，的第 5 項，總共有 550 項，目前進度是 20.909090909090907 %。
# 這是第 12 頁，的第 6 項，總共有 550 項，目前進度是 21.09090909090909 %。
# 這是第 12 頁，的第 7 項，總共有 550 項，目前進度是 21.272727272727273 %。
# 這是第 12 頁，的第 8 項，總共有 550 項，目前進度是 21.454545454545453 %。
# 這是第 12 頁，的第 9 項，總共有 550 項，目前進度是 21.636363636363637 %。
# 這是第 12 頁，的第 10 項，總共有 550 項，目前進度是 21.818181818181817 %。
# 此分頁抓取總耗時： 0:00:04.703625 s
# 550
# 120
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=13
# 這是第 13 頁，的第 1 項，總共有 550 項，目前進度是 22.0 %。
# 這是第 13 頁，的第 2 項，總共有 550 項，目前進度是 22.181818181818183 %。
# 這是第 13 頁，的第 3 項，總共有 550 項，目前進度是 22.363636363636363 %。
# 這是第 13 頁，的第 4 項，總共有 550 項，目前進度是 22.545454545454547 %。
# 這是第 13 頁，的第 5 項，總共有 550 項，目前進度是 22.727272727272727 %。
# 這是第 13 頁，的第 6 項，總共有 550 項，目前進度是 22.90909090909091 %。
# 這是第 13 頁，的第 7 項，總共有 550 項，目前進度是 23.09090909090909 %。
# 這是第 13 頁，的第 8 項，總共有 550 項，目前進度是 23.272727272727273 %。
# 這是第 13 頁，的第 9 項，總共有 550 項，目前進度是 23.454545454545457 %。
# 這是第 13 頁，的第 10 項，總共有 550 項，目前進度是 23.636363636363637 %。
# 此分頁抓取總耗時： 0:00:03.710783 s
# 550
# 130
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=14
# 這是第 14 頁，的第 1 項，總共有 550 項，目前進度是 23.81818181818182 %。
# 這是第 14 頁，的第 2 項，總共有 550 項，目前進度是 24.0 %。
# 這是第 14 頁，的第 3 項，總共有 550 項，目前進度是 24.181818181818183 %。
# 這是第 14 頁，的第 4 項，總共有 550 項，目前進度是 24.363636363636363 %。
# 這是第 14 頁，的第 5 項，總共有 550 項，目前進度是 24.545454545454547 %。
# 這是第 14 頁，的第 6 項，總共有 550 項，目前進度是 24.727272727272727 %。
# 這是第 14 頁，的第 7 項，總共有 550 項，目前進度是 24.90909090909091 %。
# 這是第 14 頁，的第 8 項，總共有 550 項，目前進度是 25.09090909090909 %。
# 這是第 14 頁，的第 9 項，總共有 550 項，目前進度是 25.272727272727273 %。
# 這是第 14 頁，的第 10 項，總共有 550 項，目前進度是 25.454545454545453 %。
# 此分頁抓取總耗時： 0:00:06.184606 s
# 550
# 140
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=15
# 這是第 15 頁，的第 1 項，總共有 550 項，目前進度是 25.636363636363633 %。
# 這是第 15 頁，的第 2 項，總共有 550 項，目前進度是 25.818181818181817 %。
# 這是第 15 頁，的第 3 項，總共有 550 項，目前進度是 26.0 %。
# 這是第 15 頁，的第 4 項，總共有 550 項，目前進度是 26.181818181818183 %。
# 這是第 15 頁，的第 5 項，總共有 550 項，目前進度是 26.36363636363636 %。
# 這是第 15 頁，的第 6 項，總共有 550 項，目前進度是 26.545454545454543 %。
# 這是第 15 頁，的第 7 項，總共有 550 項，目前進度是 26.727272727272727 %。
# 這是第 15 頁，的第 8 項，總共有 550 項，目前進度是 26.90909090909091 %。
# 這是第 15 頁，的第 9 項，總共有 550 項，目前進度是 27.090909090909093 %。
# 這是第 15 頁，的第 10 項，總共有 550 項，目前進度是 27.27272727272727 %。
# 此分頁抓取總耗時： 0:00:05.270078 s
# 550
# 150
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=16
# 這是第 16 頁，的第 1 項，總共有 550 項，目前進度是 27.454545454545453 %。
# 這是第 16 頁，的第 2 項，總共有 550 項，目前進度是 27.636363636363637 %。
# 這是第 16 頁，的第 3 項，總共有 550 項，目前進度是 27.81818181818182 %。
# 這是第 16 頁，的第 4 項，總共有 550 項，目前進度是 28.000000000000004 %。
# 這是第 16 頁，的第 5 項，總共有 550 項，目前進度是 28.18181818181818 %。
# 這是第 16 頁，的第 6 項，總共有 550 項，目前進度是 28.363636363636363 %。
# 這是第 16 頁，的第 7 項，總共有 550 項，目前進度是 28.545454545454547 %。
# 這是第 16 頁，的第 8 項，總共有 550 項，目前進度是 28.72727272727273 %。
# 這是第 16 頁，的第 9 項，總共有 550 項，目前進度是 28.909090909090907 %。
# 這是第 16 頁，的第 10 項，總共有 550 項，目前進度是 29.09090909090909 %。
# 此分頁抓取總耗時： 0:00:05.229929 s
# 550
# 160
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=17
# 這是第 17 頁，的第 1 項，總共有 550 項，目前進度是 29.272727272727273 %。
# 這是第 17 頁，的第 2 項，總共有 550 項，目前進度是 29.454545454545457 %。
# 這是第 17 頁，的第 3 項，總共有 550 項，目前進度是 29.63636363636364 %。
# 這是第 17 頁，的第 4 項，總共有 550 項，目前進度是 29.818181818181817 %。
# 這是第 17 頁，的第 5 項，總共有 550 項，目前進度是 30.0 %。
# 這是第 17 頁，的第 6 項，總共有 550 項，目前進度是 30.181818181818183 %。
# 這是第 17 頁，的第 7 項，總共有 550 項，目前進度是 30.363636363636363 %。
# 這是第 17 頁，的第 8 項，總共有 550 項，目前進度是 30.545454545454547 %。
# 這是第 17 頁，的第 9 項，總共有 550 項，目前進度是 30.727272727272727 %。
# 這是第 17 頁，的第 10 項，總共有 550 項，目前進度是 30.909090909090907 %。
# 此分頁抓取總耗時： 0:00:06.689167 s
# 550
# 170
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=18
# 這是第 18 頁，的第 1 項，總共有 550 項，目前進度是 31.09090909090909 %。
# 這是第 18 頁，的第 2 項，總共有 550 項，目前進度是 31.272727272727273 %。
# 這是第 18 頁，的第 3 項，總共有 550 項，目前進度是 31.454545454545457 %。
# 這是第 18 頁，的第 4 項，總共有 550 項，目前進度是 31.636363636363633 %。
# 這是第 18 頁，的第 5 項，總共有 550 項，目前進度是 31.818181818181817 %。
# 這是第 18 頁，的第 6 項，總共有 550 項，目前進度是 32.0 %。
# 這是第 18 頁，的第 7 項，總共有 550 項，目前進度是 32.18181818181819 %。
# 這是第 18 頁，的第 8 項，總共有 550 項，目前進度是 32.36363636363636 %。
# 這是第 18 頁，的第 9 項，總共有 550 項，目前進度是 32.54545454545455 %。
# 這是第 18 頁，的第 10 項，總共有 550 項，目前進度是 32.72727272727273 %。
# 此分頁抓取總耗時： 0:00:07.895366 s
# 550
# 180
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=19
# 這是第 19 頁，的第 1 項，總共有 550 項，目前進度是 32.90909090909091 %。
# 這是第 19 頁，的第 2 項，總共有 550 項，目前進度是 33.09090909090909 %。
# 這是第 19 頁，的第 3 項，總共有 550 項，目前進度是 33.27272727272727 %。
# 這是第 19 頁，的第 4 項，總共有 550 項，目前進度是 33.45454545454545 %。
# 這是第 19 頁，的第 5 項，總共有 550 項，目前進度是 33.63636363636363 %。
# 這是第 19 頁，的第 6 項，總共有 550 項，目前進度是 33.81818181818182 %。
# 這是第 19 頁，的第 7 項，總共有 550 項，目前進度是 34.0 %。
# 這是第 19 頁，的第 8 項，總共有 550 項，目前進度是 34.18181818181818 %。
# 這是第 19 頁，的第 9 項，總共有 550 項，目前進度是 34.36363636363636 %。
# 這是第 19 頁，的第 10 項，總共有 550 項，目前進度是 34.54545454545455 %。
# 此分頁抓取總耗時： 0:00:06.320232 s
# 550
# 190
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=20
# 這是第 20 頁，的第 1 項，總共有 550 項，目前進度是 34.72727272727273 %。
# 這是第 20 頁，的第 2 項，總共有 550 項，目前進度是 34.909090909090914 %。
# 這是第 20 頁，的第 3 項，總共有 550 項，目前進度是 35.090909090909086 %。
# 這是第 20 頁，的第 4 項，總共有 550 項，目前進度是 35.27272727272727 %。
# 這是第 20 頁，的第 5 項，總共有 550 項，目前進度是 35.45454545454545 %。
# 這是第 20 頁，的第 6 項，總共有 550 項，目前進度是 35.63636363636364 %。
# 這是第 20 頁，的第 7 項，總共有 550 項，目前進度是 35.81818181818181 %。
# 這是第 20 頁，的第 8 項，總共有 550 項，目前進度是 36.0 %。
# 這是第 20 頁，的第 9 項，總共有 550 項，目前進度是 36.18181818181818 %。
# 這是第 20 頁，的第 10 項，總共有 550 項，目前進度是 36.36363636363637 %。
# 此分頁抓取總耗時： 0:00:08.426668 s
# 550
# 200
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=21
# 這是第 21 頁，的第 1 項，總共有 550 項，目前進度是 36.54545454545455 %。
# 這是第 21 頁，的第 2 項，總共有 550 項，目前進度是 36.72727272727273 %。
# 這是第 21 頁，的第 3 項，總共有 550 項，目前進度是 36.90909090909091 %。
# 這是第 21 頁，的第 4 項，總共有 550 項，目前進度是 37.09090909090909 %。
# 這是第 21 頁，的第 5 項，總共有 550 項，目前進度是 37.27272727272727 %。
# 這是第 21 頁，的第 6 項，總共有 550 項，目前進度是 37.45454545454546 %。
# 這是第 21 頁，的第 7 項，總共有 550 項，目前進度是 37.63636363636363 %。
# 這是第 21 頁，的第 8 項，總共有 550 項，目前進度是 37.81818181818182 %。
# 這是第 21 頁，的第 9 項，總共有 550 項，目前進度是 38.0 %。
# 這是第 21 頁，的第 10 項，總共有 550 項，目前進度是 38.18181818181819 %。
# 此分頁抓取總耗時： 0:00:05.833304 s
# 550
# 210
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=22
# 這是第 22 頁，的第 1 項，總共有 550 項，目前進度是 38.36363636363636 %。
# 這是第 22 頁，的第 2 項，總共有 550 項，目前進度是 38.54545454545455 %。
# 這是第 22 頁，的第 3 項，總共有 550 項，目前進度是 38.72727272727273 %。
# 這是第 22 頁，的第 4 項，總共有 550 項，目前進度是 38.90909090909091 %。
# 這是第 22 頁，的第 5 項，總共有 550 項，目前進度是 39.09090909090909 %。
# 這是第 22 頁，的第 6 項，總共有 550 項，目前進度是 39.27272727272727 %。
# 這是第 22 頁，的第 7 項，總共有 550 項，目前進度是 39.45454545454545 %。
# 這是第 22 頁，的第 8 項，總共有 550 項，目前進度是 39.63636363636363 %。
# 這是第 22 頁，的第 9 項，總共有 550 項，目前進度是 39.81818181818182 %。
# 這是第 22 頁，的第 10 項，總共有 550 項，目前進度是 40.0 %。
# 此分頁抓取總耗時： 0:00:06.393608 s
# 550
# 220
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=23
# 這是第 23 頁，的第 1 項，總共有 550 項，目前進度是 40.18181818181818 %。
# 這是第 23 頁，的第 2 項，總共有 550 項，目前進度是 40.36363636363636 %。
# 這是第 23 頁，的第 3 項，總共有 550 項，目前進度是 40.54545454545455 %。
# 這是第 23 頁，的第 4 項，總共有 550 項，目前進度是 40.72727272727273 %。
# 這是第 23 頁，的第 5 項，總共有 550 項，目前進度是 40.909090909090914 %。
# 這是第 23 頁，的第 6 項，總共有 550 項，目前進度是 41.090909090909086 %。
# 這是第 23 頁，的第 7 項，總共有 550 項，目前進度是 41.27272727272727 %。
# 這是第 23 頁，的第 8 項，總共有 550 項，目前進度是 41.45454545454545 %。
# 這是第 23 頁，的第 9 項，總共有 550 項，目前進度是 41.63636363636364 %。
# 這是第 23 頁，的第 10 項，總共有 550 項，目前進度是 41.81818181818181 %。
# 此分頁抓取總耗時： 0:00:06.844868 s
# 550
# 230
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=24
# 這是第 24 頁，的第 1 項，總共有 550 項，目前進度是 42.0 %。
# 這是第 24 頁，的第 2 項，總共有 550 項，目前進度是 42.18181818181818 %。
# 這是第 24 頁，的第 3 項，總共有 550 項，目前進度是 42.36363636363637 %。
# 這是第 24 頁，的第 4 項，總共有 550 項，目前進度是 42.54545454545455 %。
# 這是第 24 頁，的第 5 項，總共有 550 項，目前進度是 42.72727272727273 %。
# 這是第 24 頁，的第 6 項，總共有 550 項，目前進度是 42.90909090909091 %。
# 這是第 24 頁，的第 7 項，總共有 550 項，目前進度是 43.09090909090909 %。
# 這是第 24 頁，的第 8 項，總共有 550 項，目前進度是 43.27272727272727 %。
# 這是第 24 頁，的第 9 項，總共有 550 項，目前進度是 43.45454545454545 %。
# 這是第 24 頁，的第 10 項，總共有 550 項，目前進度是 43.63636363636363 %。
# 此分頁抓取總耗時： 0:00:06.794014 s
# 550
# 240
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=25
# 這是第 25 頁，的第 1 項，總共有 550 項，目前進度是 43.81818181818182 %。
# 這是第 25 頁，的第 2 項，總共有 550 項，目前進度是 44.0 %。
# 這是第 25 頁，的第 3 項，總共有 550 項，目前進度是 44.18181818181818 %。
# 這是第 25 頁，的第 4 項，總共有 550 項，目前進度是 44.36363636363637 %。
# 這是第 25 頁，的第 5 項，總共有 550 項，目前進度是 44.54545454545455 %。
# 這是第 25 頁，的第 6 項，總共有 550 項，目前進度是 44.72727272727273 %。
# 這是第 25 頁，的第 7 項，總共有 550 項，目前進度是 44.90909090909091 %。
# 這是第 25 頁，的第 8 項，總共有 550 項，目前進度是 45.09090909090909 %。
# 這是第 25 頁，的第 9 項，總共有 550 項，目前進度是 45.27272727272727 %。
# 這是第 25 頁，的第 10 項，總共有 550 項，目前進度是 45.45454545454545 %。
# 此分頁抓取總耗時： 0:00:06.733304 s
# 550
# 250
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=26
# 這是第 26 頁，的第 1 項，總共有 550 項，目前進度是 45.63636363636363 %。
# 這是第 26 頁，的第 2 項，總共有 550 項，目前進度是 45.81818181818182 %。
# 這是第 26 頁，的第 3 項，總共有 550 項，目前進度是 46.0 %。
# 這是第 26 頁，的第 4 項，總共有 550 項，目前進度是 46.18181818181818 %。
# 這是第 26 頁，的第 5 項，總共有 550 項，目前進度是 46.36363636363636 %。
# 這是第 26 頁，的第 6 項，總共有 550 項，目前進度是 46.54545454545455 %。
# 這是第 26 頁，的第 7 項，總共有 550 項，目前進度是 46.72727272727273 %。
# 這是第 26 頁，的第 8 項，總共有 550 項，目前進度是 46.909090909090914 %。
# 這是第 26 頁，的第 9 項，總共有 550 項，目前進度是 47.090909090909086 %。
# 這是第 26 頁，的第 10 項，總共有 550 項，目前進度是 47.27272727272727 %。
# 此分頁抓取總耗時： 0:00:07.655069 s
# 550
# 260
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=27
# 這是第 27 頁，的第 1 項，總共有 550 項，目前進度是 47.45454545454545 %。
# 這是第 27 頁，的第 2 項，總共有 550 項，目前進度是 47.63636363636364 %。
# 這是第 27 頁，的第 3 項，總共有 550 項，目前進度是 47.81818181818182 %。
# 這是第 27 頁，的第 4 項，總共有 550 項，目前進度是 48.0 %。
# 這是第 27 頁，的第 5 項，總共有 550 項，目前進度是 48.18181818181818 %。
# 這是第 27 頁，的第 6 項，總共有 550 項，目前進度是 48.36363636363637 %。
# 這是第 27 頁，的第 7 項，總共有 550 項，目前進度是 48.54545454545455 %。
# 這是第 27 頁，的第 8 項，總共有 550 項，目前進度是 48.72727272727273 %。
# 這是第 27 頁，的第 9 項，總共有 550 項，目前進度是 48.90909090909091 %。
# 這是第 27 頁，的第 10 項，總共有 550 項，目前進度是 49.09090909090909 %。
# 此分頁抓取總耗時： 0:00:06.407022 s
# 550
# 270
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=28
# 這是第 28 頁，的第 1 項，總共有 550 項，目前進度是 49.27272727272727 %。
# 這是第 28 頁，的第 2 項，總共有 550 項，目前進度是 49.45454545454545 %。
# 這是第 28 頁，的第 3 項，總共有 550 項，目前進度是 49.63636363636363 %。
# 這是第 28 頁，的第 4 項，總共有 550 項，目前進度是 49.81818181818182 %。
# 這是第 28 頁，的第 5 項，總共有 550 項，目前進度是 50.0 %。
# 這是第 28 頁，的第 6 項，總共有 550 項，目前進度是 50.18181818181818 %。
# 這是第 28 頁，的第 7 項，總共有 550 項，目前進度是 50.36363636363637 %。
# 這是第 28 頁，的第 8 項，總共有 550 項，目前進度是 50.54545454545455 %。
# 這是第 28 頁，的第 9 項，總共有 550 項，目前進度是 50.727272727272734 %。
# 這是第 28 頁，的第 10 項，總共有 550 項，目前進度是 50.90909090909091 %。
# 此分頁抓取總耗時： 0:00:06.180765 s
# 550
# 280
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=29
# 這是第 29 頁，的第 1 項，總共有 550 項，目前進度是 51.090909090909086 %。
# 這是第 29 頁，的第 2 項，總共有 550 項，目前進度是 51.272727272727266 %。
# 這是第 29 頁，的第 3 項，總共有 550 項，目前進度是 51.45454545454545 %。
# 這是第 29 頁，的第 4 項，總共有 550 項，目前進度是 51.63636363636363 %。
# 這是第 29 頁，的第 5 項，總共有 550 項，目前進度是 51.81818181818182 %。
# 這是第 29 頁，的第 6 項，總共有 550 項，目前進度是 52.0 %。
# 這是第 29 頁，的第 7 項，總共有 550 項，目前進度是 52.18181818181819 %。
# 這是第 29 頁，的第 8 項，總共有 550 項，目前進度是 52.36363636363637 %。
# 這是第 29 頁，的第 9 項，總共有 550 項，目前進度是 52.545454545454554 %。
# 這是第 29 頁，的第 10 項，總共有 550 項，目前進度是 52.72727272727272 %。
# 此分頁抓取總耗時： 0:00:06.686389 s
# 550
# 290
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=30
# 這是第 30 頁，的第 1 項，總共有 550 項，目前進度是 52.90909090909091 %。
# 這是第 30 頁，的第 2 項，總共有 550 項，目前進度是 53.090909090909086 %。
# 這是第 30 頁，的第 3 項，總共有 550 項，目前進度是 53.27272727272727 %。
# 這是第 30 頁，的第 4 項，總共有 550 項，目前進度是 53.45454545454545 %。
# 這是第 30 頁，的第 5 項，總共有 550 項，目前進度是 53.63636363636364 %。
# 這是第 30 頁，的第 6 項，總共有 550 項，目前進度是 53.81818181818182 %。
# 這是第 30 頁，的第 7 項，總共有 550 項，目前進度是 54.0 %。
# 這是第 30 頁，的第 8 項，總共有 550 項，目前進度是 54.18181818181819 %。
# 這是第 30 頁，的第 9 項，總共有 550 項，目前進度是 54.36363636363636 %。
# 這是第 30 頁，的第 10 項，總共有 550 項，目前進度是 54.54545454545454 %。
# 此分頁抓取總耗時： 0:00:05.929895 s
# 550
# 300
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=31
# 這是第 31 頁，的第 1 項，總共有 550 項，目前進度是 54.72727272727273 %。
# 這是第 31 頁，的第 2 項，總共有 550 項，目前進度是 54.90909090909091 %。
# 這是第 31 頁，的第 3 項，總共有 550 項，目前進度是 55.09090909090909 %。
# 這是第 31 頁，的第 4 項，總共有 550 項，目前進度是 55.27272727272727 %。
# 這是第 31 頁，的第 5 項，總共有 550 項，目前進度是 55.45454545454545 %。
# 這是第 31 頁，的第 6 項，總共有 550 項，目前進度是 55.63636363636364 %。
# 這是第 31 頁，的第 7 項，總共有 550 項，目前進度是 55.81818181818182 %。
# 這是第 31 頁，的第 8 項，總共有 550 項，目前進度是 56.00000000000001 %。
# 這是第 31 頁，的第 9 項，總共有 550 項，目前進度是 56.18181818181818 %。
# 這是第 31 頁，的第 10 項，總共有 550 項，目前進度是 56.36363636363636 %。
# 此分頁抓取總耗時： 0:00:05.602344 s
# 550
# 310
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=32
# 這是第 32 頁，的第 1 項，總共有 550 項，目前進度是 56.54545454545455 %。
# 這是第 32 頁，的第 2 項，總共有 550 項，目前進度是 56.72727272727273 %。
# 這是第 32 頁，的第 3 項，總共有 550 項，目前進度是 56.90909090909091 %。
# 這是第 32 頁，的第 4 項，總共有 550 項，目前進度是 57.09090909090909 %。
# 這是第 32 頁，的第 5 項，總共有 550 項，目前進度是 57.27272727272727 %。
# 這是第 32 頁，的第 6 項，總共有 550 項，目前進度是 57.45454545454546 %。
# 這是第 32 頁，的第 7 項，總共有 550 項，目前進度是 57.63636363636364 %。
# 這是第 32 頁，的第 8 項，總共有 550 項，目前進度是 57.81818181818181 %。
# 這是第 32 頁，的第 9 項，總共有 550 項，目前進度是 57.99999999999999 %。
# 這是第 32 頁，的第 10 項，總共有 550 項，目前進度是 58.18181818181818 %。
# 此分頁抓取總耗時： 0:00:05.598149 s
# 550
# 320
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=33
# 這是第 33 頁，的第 1 項，總共有 550 項，目前進度是 58.36363636363636 %。
# 這是第 33 頁，的第 2 項，總共有 550 項，目前進度是 58.54545454545455 %。
# 這是第 33 頁，的第 3 項，總共有 550 項，目前進度是 58.72727272727273 %。
# 這是第 33 頁，的第 4 項，總共有 550 項，目前進度是 58.909090909090914 %。
# 這是第 33 頁，的第 5 項，總共有 550 項，目前進度是 59.09090909090909 %。
# 這是第 33 頁，的第 6 項，總共有 550 項，目前進度是 59.27272727272728 %。
# 這是第 33 頁，的第 7 項，總共有 550 項，目前進度是 59.45454545454546 %。
# 這是第 33 頁，的第 8 項，總共有 550 項，目前進度是 59.63636363636363 %。
# 這是第 33 頁，的第 9 項，總共有 550 項，目前進度是 59.81818181818181 %。
# 這是第 33 頁，的第 10 項，總共有 550 項，目前進度是 60.0 %。
# 此分頁抓取總耗時： 0:00:06.209236 s
# 550
# 330
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=34
# 這是第 34 頁，的第 1 項，總共有 550 項，目前進度是 60.18181818181818 %。
# 這是第 34 頁，的第 2 項，總共有 550 項，目前進度是 60.36363636363637 %。
# 這是第 34 頁，的第 3 項，總共有 550 項，目前進度是 60.54545454545455 %。
# 這是第 34 頁，的第 4 項，總共有 550 項，目前進度是 60.72727272727273 %。
# 這是第 34 頁，的第 5 項，總共有 550 項，目前進度是 60.909090909090914 %。
# 這是第 34 頁，的第 6 項，總共有 550 項，目前進度是 61.09090909090909 %。
# 這是第 34 頁，的第 7 項，總共有 550 項，目前進度是 61.272727272727266 %。
# 這是第 34 頁，的第 8 項，總共有 550 項，目前進度是 61.45454545454545 %。
# 這是第 34 頁，的第 9 項，總共有 550 項，目前進度是 61.63636363636363 %。
# 這是第 34 頁，的第 10 項，總共有 550 項，目前進度是 61.81818181818181 %。
# 此分頁抓取總耗時： 0:00:06.141806 s
# 550
# 340
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=35
# 這是第 35 頁，的第 1 項，總共有 550 項，目前進度是 62.0 %。
# 這是第 35 頁，的第 2 項，總共有 550 項，目前進度是 62.18181818181818 %。
# 這是第 35 頁，的第 3 項，總共有 550 項，目前進度是 62.36363636363637 %。
# 這是第 35 頁，的第 4 項，總共有 550 項，目前進度是 62.54545454545455 %。
# 這是第 35 頁，的第 5 項，總共有 550 項，目前進度是 62.727272727272734 %。
# 這是第 35 頁，的第 6 項，總共有 550 項，目前進度是 62.909090909090914 %。
# 這是第 35 頁，的第 7 項，總共有 550 項，目前進度是 63.090909090909086 %。
# 這是第 35 頁，的第 8 項，總共有 550 項，目前進度是 63.272727272727266 %。
# 這是第 35 頁，的第 9 項，總共有 550 項，目前進度是 63.45454545454545 %。
# 這是第 35 頁，的第 10 項，總共有 550 項，目前進度是 63.63636363636363 %。
# 此分頁抓取總耗時： 0:00:06.566038 s
# 550
# 350
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=36
# 這是第 36 頁，的第 1 項，總共有 550 項，目前進度是 63.81818181818182 %。
# 這是第 36 頁，的第 2 項，總共有 550 項，目前進度是 64.0 %。
# 這是第 36 頁，的第 3 項，總共有 550 項，目前進度是 64.18181818181819 %。
# 這是第 36 頁，的第 4 項，總共有 550 項，目前進度是 64.36363636363637 %。
# 這是第 36 頁，的第 5 項，總共有 550 項，目前進度是 64.54545454545455 %。
# 這是第 36 頁，的第 6 項，總共有 550 項，目前進度是 64.72727272727272 %。
# 這是第 36 頁，的第 7 項，總共有 550 項，目前進度是 64.9090909090909 %。
# 這是第 36 頁，的第 8 項，總共有 550 項，目前進度是 65.0909090909091 %。
# 這是第 36 頁，的第 9 項，總共有 550 項，目前進度是 65.27272727272727 %。
# 這是第 36 頁，的第 10 項，總共有 550 項，目前進度是 65.45454545454545 %。
# 此分頁抓取總耗時： 0:00:05.968464 s
# 550
# 360
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=37
# 這是第 37 頁，的第 1 項，總共有 550 項，目前進度是 65.63636363636364 %。
# 這是第 37 頁，的第 2 項，總共有 550 項，目前進度是 65.81818181818181 %。
# 這是第 37 頁，的第 3 項，總共有 550 項，目前進度是 66.0 %。
# 這是第 37 頁，的第 4 項，總共有 550 項，目前進度是 66.18181818181819 %。
# 這是第 37 頁，的第 5 項，總共有 550 項，目前進度是 66.36363636363637 %。
# 這是第 37 頁，的第 6 項，總共有 550 項，目前進度是 66.54545454545455 %。
# 這是第 37 頁，的第 7 項，總共有 550 項，目前進度是 66.72727272727272 %。
# 這是第 37 頁，的第 8 項，總共有 550 項，目前進度是 66.9090909090909 %。
# 這是第 37 頁，的第 9 項，總共有 550 項，目前進度是 67.0909090909091 %。
# 這是第 37 頁，的第 10 項，總共有 550 項，目前進度是 67.27272727272727 %。
# 此分頁抓取總耗時： 0:00:06.562233 s
# 550
# 370
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=38
# 這是第 38 頁，的第 1 項，總共有 550 項，目前進度是 67.45454545454545 %。
# 這是第 38 頁，的第 2 項，總共有 550 項，目前進度是 67.63636363636364 %。
# 這是第 38 頁，的第 3 項，總共有 550 項，目前進度是 67.81818181818183 %。
# 這是第 38 頁，的第 4 項，總共有 550 項，目前進度是 68.0 %。
# 這是第 38 頁，的第 5 項，總共有 550 項，目前進度是 68.18181818181817 %。
# 這是第 38 頁，的第 6 項，總共有 550 項，目前進度是 68.36363636363636 %。
# 這是第 38 頁，的第 7 項，總共有 550 項，目前進度是 68.54545454545455 %。
# 這是第 38 頁，的第 8 項，總共有 550 項，目前進度是 68.72727272727272 %。
# 這是第 38 頁，的第 9 項，總共有 550 項，目前進度是 68.9090909090909 %。
# 這是第 38 頁，的第 10 項，總共有 550 項，目前進度是 69.0909090909091 %。
# 此分頁抓取總耗時： 0:00:08.532410 s
# 550
# 380
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=39
# 這是第 39 頁，的第 1 項，總共有 550 項，目前進度是 69.27272727272728 %。
# 這是第 39 頁，的第 2 項，總共有 550 項，目前進度是 69.45454545454545 %。
# 這是第 39 頁，的第 3 項，總共有 550 項，目前進度是 69.63636363636364 %。
# 這是第 39 頁，的第 4 項，總共有 550 項，目前進度是 69.81818181818183 %。
# 這是第 39 頁，的第 5 項，總共有 550 項，目前進度是 70.0 %。
# 這是第 39 頁，的第 6 項，總共有 550 項，目前進度是 70.18181818181817 %。
# 這是第 39 頁，的第 7 項，總共有 550 項，目前進度是 70.36363636363636 %。
# 這是第 39 頁，的第 8 項，總共有 550 項，目前進度是 70.54545454545455 %。
# 這是第 39 頁，的第 9 項，總共有 550 項，目前進度是 70.72727272727273 %。
# 這是第 39 頁，的第 10 項，總共有 550 項，目前進度是 70.9090909090909 %。
# 此分頁抓取總耗時： 0:00:06.336046 s
# 550
# 390
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=40
# 這是第 40 頁，的第 1 項，總共有 550 項，目前進度是 71.0909090909091 %。
# 這是第 40 頁，的第 2 項，總共有 550 項，目前進度是 71.27272727272728 %。
# 這是第 40 頁，的第 3 項，總共有 550 項，目前進度是 71.45454545454545 %。
# 這是第 40 頁，的第 4 項，總共有 550 項，目前進度是 71.63636363636363 %。
# 這是第 40 頁，的第 5 項，總共有 550 項，目前進度是 71.81818181818181 %。
# 這是第 40 頁，的第 6 項，總共有 550 項，目前進度是 72.0 %。
# 這是第 40 頁，的第 7 項，總共有 550 項，目前進度是 72.18181818181819 %。
# 這是第 40 頁，的第 8 項，總共有 550 項，目前進度是 72.36363636363636 %。
# 這是第 40 頁，的第 9 項，總共有 550 項，目前進度是 72.54545454545455 %。
# 這是第 40 頁，的第 10 項，總共有 550 項，目前進度是 72.72727272727273 %。
# 此分頁抓取總耗時： 0:00:05.971870 s
# 550
# 400
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=41
# 這是第 41 頁，的第 1 項，總共有 550 項，目前進度是 72.9090909090909 %。
# 這是第 41 頁，的第 2 項，總共有 550 項，目前進度是 73.0909090909091 %。
# 這是第 41 頁，的第 3 項，總共有 550 項，目前進度是 73.27272727272728 %。
# 這是第 41 頁，的第 4 項，總共有 550 項，目前進度是 73.45454545454545 %。
# 這是第 41 頁，的第 5 項，總共有 550 項，目前進度是 73.63636363636363 %。
# 這是第 41 頁，的第 6 項，總共有 550 項，目前進度是 73.81818181818181 %。
# 這是第 41 頁，的第 7 項，總共有 550 項，目前進度是 74.0 %。
# 這是第 41 頁，的第 8 項，總共有 550 項，目前進度是 74.18181818181819 %。
# 這是第 41 頁，的第 9 項，總共有 550 項，目前進度是 74.36363636363636 %。
# 這是第 41 頁，的第 10 項，總共有 550 項，目前進度是 74.54545454545455 %。
# 此分頁抓取總耗時： 0:00:06.083212 s
# 550
# 410
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=42
# 這是第 42 頁，的第 1 項，總共有 550 項，目前進度是 74.72727272727273 %。
# 這是第 42 頁，的第 2 項，總共有 550 項，目前進度是 74.90909090909092 %。
# 這是第 42 頁，的第 3 項，總共有 550 項，目前進度是 75.09090909090908 %。
# 這是第 42 頁，的第 4 項，總共有 550 項，目前進度是 75.27272727272727 %。
# 這是第 42 頁，的第 5 項，總共有 550 項，目前進度是 75.45454545454545 %。
# 這是第 42 頁，的第 6 項，總共有 550 項，目前進度是 75.63636363636364 %。
# 這是第 42 頁，的第 7 項，總共有 550 項，目前進度是 75.81818181818181 %。
# 這是第 42 頁，的第 8 項，總共有 550 項，目前進度是 76.0 %。
# 這是第 42 頁，的第 9 項，總共有 550 項，目前進度是 76.18181818181819 %。
# 這是第 42 頁，的第 10 項，總共有 550 項，目前進度是 76.36363636363637 %。
# 此分頁抓取總耗時： 0:00:06.223952 s
# 550
# 420
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=43
# 這是第 43 頁，的第 1 項，總共有 550 項，目前進度是 76.54545454545455 %。
# 這是第 43 頁，的第 2 項，總共有 550 項，目前進度是 76.72727272727272 %。
# 這是第 43 頁，的第 3 項，總共有 550 項，目前進度是 76.9090909090909 %。
# 這是第 43 頁，的第 4 項，總共有 550 項，目前進度是 77.0909090909091 %。
# 這是第 43 頁，的第 5 項，總共有 550 項，目前進度是 77.27272727272727 %。
# 這是第 43 頁，的第 6 項，總共有 550 項，目前進度是 77.45454545454545 %。
# 這是第 43 頁，的第 7 項，總共有 550 項，目前進度是 77.63636363636364 %。
# 這是第 43 頁，的第 8 項，總共有 550 項，目前進度是 77.81818181818181 %。
# 這是第 43 頁，的第 9 項，總共有 550 項，目前進度是 78.0 %。
# 這是第 43 頁，的第 10 項，總共有 550 項，目前進度是 78.18181818181819 %。
# 此分頁抓取總耗時： 0:00:06.101006 s
# 550
# 430
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=44
# 這是第 44 頁，的第 1 項，總共有 550 項，目前進度是 78.36363636363637 %。
# 這是第 44 頁，的第 2 項，總共有 550 項，目前進度是 78.54545454545455 %。
# 這是第 44 頁，的第 3 項，總共有 550 項，目前進度是 78.72727272727272 %。
# 這是第 44 頁，的第 4 項，總共有 550 項，目前進度是 78.9090909090909 %。
# 這是第 44 頁，的第 5 項，總共有 550 項，目前進度是 79.0909090909091 %。
# 這是第 44 頁，的第 6 項，總共有 550 項，目前進度是 79.27272727272727 %。
# 這是第 44 頁，的第 7 項，總共有 550 項，目前進度是 79.45454545454545 %。
# 這是第 44 頁，的第 8 項，總共有 550 項，目前進度是 79.63636363636364 %。
# 這是第 44 頁，的第 9 項，總共有 550 項，目前進度是 79.81818181818183 %。
# 這是第 44 頁，的第 10 項，總共有 550 項，目前進度是 80.0 %。
# 此分頁抓取總耗時： 0:00:06.357368 s
# 550
# 440
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=45
# 這是第 45 頁，的第 1 項，總共有 550 項，目前進度是 80.18181818181817 %。
# 這是第 45 頁，的第 2 項，總共有 550 項，目前進度是 80.36363636363636 %。
# 這是第 45 頁，的第 3 項，總共有 550 項，目前進度是 80.54545454545455 %。
# 這是第 45 頁，的第 4 項，總共有 550 項，目前進度是 80.72727272727272 %。
# 這是第 45 頁，的第 5 項，總共有 550 項，目前進度是 80.9090909090909 %。
# 這是第 45 頁，的第 6 項，總共有 550 項，目前進度是 81.0909090909091 %。
# 這是第 45 頁，的第 7 項，總共有 550 項，目前進度是 81.27272727272728 %。
# 這是第 45 頁，的第 8 項，總共有 550 項，目前進度是 81.45454545454545 %。
# 這是第 45 頁，的第 9 項，總共有 550 項，目前進度是 81.63636363636364 %。
# 這是第 45 頁，的第 10 項，總共有 550 項，目前進度是 81.81818181818183 %。
# 此分頁抓取總耗時： 0:00:07.304740 s
# 550
# 450
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=46
# 這是第 46 頁，的第 1 項，總共有 550 項，目前進度是 82.0 %。
# 這是第 46 頁，的第 2 項，總共有 550 項，目前進度是 82.18181818181817 %。
# 這是第 46 頁，的第 3 項，總共有 550 項，目前進度是 82.36363636363636 %。
# 這是第 46 頁，的第 4 項，總共有 550 項，目前進度是 82.54545454545455 %。
# 這是第 46 頁，的第 5 項，總共有 550 項，目前進度是 82.72727272727273 %。
# 這是第 46 頁，的第 6 項，總共有 550 項，目前進度是 82.9090909090909 %。
# 這是第 46 頁，的第 7 項，總共有 550 項，目前進度是 83.0909090909091 %。
# 這是第 46 頁，的第 8 項，總共有 550 項，目前進度是 83.27272727272728 %。
# 這是第 46 頁，的第 9 項，總共有 550 項，目前進度是 83.45454545454545 %。
# 這是第 46 頁，的第 10 項，總共有 550 項，目前進度是 83.63636363636363 %。
# 此分頁抓取總耗時： 0:00:06.611274 s
# 550
# 460
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=47
# 這是第 47 頁，的第 1 項，總共有 550 項，目前進度是 83.81818181818181 %。
# 這是第 47 頁，的第 2 項，總共有 550 項，目前進度是 84.0 %。
# 這是第 47 頁，的第 3 項，總共有 550 項，目前進度是 84.18181818181819 %。
# 這是第 47 頁，的第 4 項，總共有 550 項，目前進度是 84.36363636363636 %。
# 這是第 47 頁，的第 5 項，總共有 550 項，目前進度是 84.54545454545455 %。
# 這是第 47 頁，的第 6 項，總共有 550 項，目前進度是 84.72727272727273 %。
# 這是第 47 頁，的第 7 項，總共有 550 項，目前進度是 84.9090909090909 %。
# 這是第 47 頁，的第 8 項，總共有 550 項，目前進度是 85.0909090909091 %。
# 這是第 47 頁，的第 9 項，總共有 550 項，目前進度是 85.27272727272728 %。
# 這是第 47 頁，的第 10 項，總共有 550 項，目前進度是 85.45454545454545 %。
# 此分頁抓取總耗時： 0:00:07.186912 s
# 550
# 470
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=48
# 這是第 48 頁，的第 1 項，總共有 550 項，目前進度是 85.63636363636363 %。
# 這是第 48 頁，的第 2 項，總共有 550 項，目前進度是 85.81818181818181 %。
# 這是第 48 頁，的第 3 項，總共有 550 項，目前進度是 86.0 %。
# 這是第 48 頁，的第 4 項，總共有 550 項，目前進度是 86.18181818181819 %。
# 這是第 48 頁，的第 5 項，總共有 550 項，目前進度是 86.36363636363636 %。
# 這是第 48 頁，的第 6 項，總共有 550 項，目前進度是 86.54545454545455 %。
# 這是第 48 頁，的第 7 項，總共有 550 項，目前進度是 86.72727272727273 %。
# 這是第 48 頁，的第 8 項，總共有 550 項，目前進度是 86.9090909090909 %。
# 這是第 48 頁，的第 9 項，總共有 550 項，目前進度是 87.09090909090908 %。
# 這是第 48 頁，的第 10 項，總共有 550 項，目前進度是 87.27272727272727 %。
# 此分頁抓取總耗時： 0:00:06.591917 s
# 550
# 480
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=49
# 這是第 49 頁，的第 1 項，總共有 550 項，目前進度是 87.45454545454545 %。
# 這是第 49 頁，的第 2 項，總共有 550 項，目前進度是 87.63636363636364 %。
# 這是第 49 頁，的第 3 項，總共有 550 項，目前進度是 87.81818181818181 %。
# 這是第 49 頁，的第 4 項，總共有 550 項，目前進度是 88.0 %。
# 這是第 49 頁，的第 5 項，總共有 550 項，目前進度是 88.18181818181819 %。
# 這是第 49 頁，的第 6 項，總共有 550 項，目前進度是 88.36363636363636 %。
# 這是第 49 頁，的第 7 項，總共有 550 項，目前進度是 88.54545454545455 %。
# 這是第 49 頁，的第 8 項，總共有 550 項，目前進度是 88.72727272727273 %。
# 這是第 49 頁，的第 9 項，總共有 550 項，目前進度是 88.9090909090909 %。
# 這是第 49 頁，的第 10 項，總共有 550 項，目前進度是 89.0909090909091 %。
# 此分頁抓取總耗時： 0:00:05.387511 s
# 550
# 490
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=50
# 這是第 50 頁，的第 1 項，總共有 550 項，目前進度是 89.27272727272727 %。
# 這是第 50 頁，的第 2 項，總共有 550 項，目前進度是 89.45454545454545 %。
# 這是第 50 頁，的第 3 項，總共有 550 項，目前進度是 89.63636363636364 %。
# 這是第 50 頁，的第 4 項，總共有 550 項，目前進度是 89.81818181818181 %。
# 這是第 50 頁，的第 5 項，總共有 550 項，目前進度是 90.0 %。
# 這是第 50 頁，的第 6 項，總共有 550 項，目前進度是 90.18181818181819 %。
# 這是第 50 頁，的第 7 項，總共有 550 項，目前進度是 90.36363636363637 %。
# 這是第 50 頁，的第 8 項，總共有 550 項，目前進度是 90.54545454545455 %。
# 這是第 50 頁，的第 9 項，總共有 550 項，目前進度是 90.72727272727272 %。
# 這是第 50 頁，的第 10 項，總共有 550 項，目前進度是 90.9090909090909 %。
# 此分頁抓取總耗時： 0:00:06.133838 s
# 550
# 500
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=51
# 這是第 51 頁，的第 1 項，總共有 550 項，目前進度是 91.0909090909091 %。
# 這是第 51 頁，的第 2 項，總共有 550 項，目前進度是 91.27272727272727 %。
# 這是第 51 頁，的第 3 項，總共有 550 項，目前進度是 91.45454545454545 %。
# 這是第 51 頁，的第 4 項，總共有 550 項，目前進度是 91.63636363636364 %。
# 這是第 51 頁，的第 5 項，總共有 550 項，目前進度是 91.81818181818183 %。
# 這是第 51 頁，的第 6 項，總共有 550 項，目前進度是 92.0 %。
# 這是第 51 頁，的第 7 項，總共有 550 項，目前進度是 92.18181818181819 %。
# 這是第 51 頁，的第 8 項，總共有 550 項，目前進度是 92.36363636363636 %。
# 這是第 51 頁，的第 9 項，總共有 550 項，目前進度是 92.54545454545455 %。
# 這是第 51 頁，的第 10 項，總共有 550 項，目前進度是 92.72727272727272 %。
# 此分頁抓取總耗時： 0:00:05.297318 s
# 550
# 510
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=52
# 這是第 52 頁，的第 1 項，總共有 550 項，目前進度是 92.9090909090909 %。
# 這是第 52 頁，的第 2 項，總共有 550 項，目前進度是 93.0909090909091 %。
# 這是第 52 頁，的第 3 項，總共有 550 項，目前進度是 93.27272727272728 %。
# 這是第 52 頁，的第 4 項，總共有 550 項，目前進度是 93.45454545454545 %。
# 這是第 52 頁，的第 5 項，總共有 550 項，目前進度是 93.63636363636364 %。
# 這是第 52 頁，的第 6 項，總共有 550 項，目前進度是 93.81818181818183 %。
# 這是第 52 頁，的第 7 項，總共有 550 項，目前進度是 94.0 %。
# 這是第 52 頁，的第 8 項，總共有 550 項，目前進度是 94.18181818181817 %。
# 這是第 52 頁，的第 9 項，總共有 550 項，目前進度是 94.36363636363636 %。
# 這是第 52 頁，的第 10 項，總共有 550 項，目前進度是 94.54545454545455 %。
# 此分頁抓取總耗時： 0:00:05.551336 s
# 550
# 520
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=53
# 這是第 53 頁，的第 1 項，總共有 550 項，目前進度是 94.72727272727272 %。
# 這是第 53 頁，的第 2 項，總共有 550 項，目前進度是 94.9090909090909 %。
# 這是第 53 頁，的第 3 項，總共有 550 項，目前進度是 95.0909090909091 %。
# 這是第 53 頁，的第 4 項，總共有 550 項，目前進度是 95.27272727272728 %。
# 這是第 53 頁，的第 5 項，總共有 550 項，目前進度是 95.45454545454545 %。
# 這是第 53 頁，的第 6 項，總共有 550 項，目前進度是 95.63636363636364 %。
# 這是第 53 頁，的第 7 項，總共有 550 項，目前進度是 95.81818181818181 %。
# 這是第 53 頁，的第 8 項，總共有 550 項，目前進度是 96.0 %。
# 這是第 53 頁，的第 9 項，總共有 550 項，目前進度是 96.18181818181817 %。
# 這是第 53 頁，的第 10 項，總共有 550 項，目前進度是 96.36363636363636 %。
# 此分頁抓取總耗時： 0:00:05.303679 s
# 550
# 530
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=54
# 這是第 54 頁，的第 1 項，總共有 550 項，目前進度是 96.54545454545455 %。
# 這是第 54 頁，的第 2 項，總共有 550 項，目前進度是 96.72727272727273 %。
# 這是第 54 頁，的第 3 項，總共有 550 項，目前進度是 96.9090909090909 %。
# 這是第 54 頁，的第 4 項，總共有 550 項，目前進度是 97.0909090909091 %。
# 這是第 54 頁，的第 5 項，總共有 550 項，目前進度是 97.27272727272728 %。
# 這是第 54 頁，的第 6 項，總共有 550 項，目前進度是 97.45454545454545 %。
# 這是第 54 頁，的第 7 項，總共有 550 項，目前進度是 97.63636363636363 %。
# 這是第 54 頁，的第 8 項，總共有 550 項，目前進度是 97.81818181818181 %。
# 這是第 54 頁，的第 9 項，總共有 550 項，目前進度是 98.0 %。
# 這是第 54 頁，的第 10 項，總共有 550 項，目前進度是 98.18181818181819 %。
# 此分頁抓取總耗時： 0:00:05.552638 s
# 550
# 540
# 外頁列表頁存活
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=55
# 這是第 55 頁，的第 1 項，總共有 550 項，目前進度是 98.36363636363636 %。
# 這是第 55 頁，的第 2 項，總共有 550 項，目前進度是 98.54545454545455 %。
# 這是第 55 頁，的第 3 項，總共有 550 項，目前進度是 98.72727272727273 %。
# 這是第 55 頁，的第 4 項，總共有 550 項，目前進度是 98.9090909090909 %。
# 這是第 55 頁，的第 5 項，總共有 550 項，目前進度是 99.0909090909091 %。
# 這是第 55 頁，的第 6 項，總共有 550 項，目前進度是 99.27272727272727 %。
# 這是第 55 頁，的第 7 項，總共有 550 項，目前進度是 99.45454545454545 %。
# 這是第 55 頁，的第 8 項，總共有 550 項，目前進度是 99.63636363636364 %。
# 這是第 55 頁，的第 9 項，總共有 550 項，目前進度是 99.81818181818181 %。
# 這是第 55 頁，的第 10 項，總共有 550 項，目前進度是 100.0 %。
# 此分頁抓取總耗時： 0:00:05.962863 s
# 550
# 550

# %%
def gov_serach_crawler(url_type,proxies,db_settings,headers={},cookies={},account="",password="",start_page=1,day_before=0):
    global waitt
    current_date = (datetime.date.today() - datetime.timedelta(days=day_before)).strftime("%Y/%m/%d")
    current_date = str(int(current_date[0:4])-1911) + current_date[4:]
    print("！！！！！爬取日期："+current_date)
    s = rq.session()
    s.keep_alive = True
    headers["User-Agent"] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
    if url_type == "tenderDeclaration":
        datarow_of_end = -1
        count_per_page = 100
        url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex="
        url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic"
        data={'method':'search','searchMethod':'true','hid_1':'1','tenderType':'tenderDeclaration','tenderWay':'1,2,3,4,5,6,7,10,12','tenderDateRadio':'on','isSpdt':'N','btnQuery':'查詢','tenderEndDate':current_date,'tenderStartDate':current_date,'tenderEndDateStr':current_date,'tenderStartDateStr':current_date}
        r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
        global progress_tenderDeclaration
    elif url_type == "searchAppeal":  
        datarow_of_end = -1
        count_per_page = 10
        url = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex="
        url_first = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchAppealVendor.do?pMenu=common"
        data={'method':'searchVendor','isVendor':'Y','startDateStr':current_date,'endDateStr':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_searchAppeal
    elif url_type == "publicRead":
        datarow_of_end = -2
        count_per_page = 10
        url = "https://web.pcc.gov.tw/tps/tps/tp/main/pms/tps/tp/commonPublicReadFormListPageControl.do?__PageBase=0&__PageIndex="
        url_first = "https://web.pcc.gov.tw/tps/tps/tp/main/pms/tps/tp/QueryPublicReadData.do?pMenu=common"
        data={'method':'queryPublicReadData','isVendor':'Y','startDateStr':current_date,'endDateStr':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_publicRead
    elif url_type == "predict":
        datarow_of_end = -1
        count_per_page = 10
        login_url = "https://web.pcc.gov.tw/pis/main/sso/login.jsp"
        login_data = {"VTI-GROUP":0,"id":account,"password":password}
        #login_data = urlencode(login_data)
        r = s.post(login_url, headers = headers, cookies = cookies ,data = login_data)
        print(r.text)
        url = ""
        url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic"
        data={'method':'searchPredict','searchMethod':'true','hid_1':1,'isSpdt':'N','btnQuery':'查詢','tenderType':'predict','tenderWay':'各式預定招標方式','tenderDateRadio':'on','tenderStartDateStr':current_date,'tenderEndDateStr':current_date,'tenderStartDate':current_date,'tenderEndDate':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_predict
    elif url_type == "final":  
        datarow_of_end = -1
        count_per_page = 100
        url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex="
        url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance"
        data={'method':'search','searchMethod':'true','searchTarget':'ATM','hid_1':1,'hid_2':1,'hid_3':1,'tenderStatus':'5,6,20,28,8,21,22,29,33,9,23','btnQuery':'查詢','awardAnnounceStartDate':current_date,'awardAnnounceEndDate':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_final
    else:
        raise Exception("url_type is wrong") 


    print("外頁進入點存活")  
    refresh_proxies=[]
    raw_datas=[]
    for ii in range(start_page,2000):
        #s = rq.session()
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖_phase2")
                time.sleep(60)
        while True:
            try:
                r = s.get(url + str(ii), headers = headers)
                print("外頁列表頁存活")  
                if r.status_code == 200:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖_phase2")
                print(ex)
                waitt = True
                time.sleep(1200)
        print("頁面前往："+str(r.url))
        html_doc = r.text
        if re.search(r'無符合條件資料',html_doc):
            print("無符合條件資料")
            break
        soup = BeautifulSoup(html_doc, parser)
        
        time_start = datetime.datetime.now()
        if url_type == "tenderDeclaration":
            data = soup.select('div#print_area table tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxx = 0
            for i in data[1:datarow_of_end]:
                t_s = datetime.datetime.now()
                xxx = xxx + 1
                progress_tenderDeclaration = "這是第 " + str(ii) + " 頁，的第 "+ str(xxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxx)/all_data*100) + " %。"
                print(progress_tenderDeclaration)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[1].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
                # 是否更正
                if i.select('td')[2].select('font'):
                    ischange=1
                else:
                    ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[2].select('a')[0].text.strip()
                # 傳輸次數
                times=i.select('td')[3].text.strip()
                # 招標方式
                typ=i.select('td')[4].text.strip()
                # 採購性質
                clas=i.select('td')[5].text.strip()
                # 公告日期
                date=i.select('td')[6].text.strip()
                # 截止投標
                enddate=i.select('td')[7].text.strip()
                # 預算金額
                budget=i.select('td')[8].text.strip()
                # 內文連結
                detail_connect = "https://web.pcc.gov.tw/tps/" + i.select('td')[2].select('a')[0]['href'][3:]
                detail_data ={}
                detail_data_html=""
#                 while True:
#                     if len(proxies)==0:
#                         send_ip(refresh_proxies, db_settings,send_log=False)
#                         refresh_proxies=[]
#                         proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.3)
#                         if proxies == []:
#                             xx = get_proxy_ip("yes")
#                             send_ip(xx, db_settings)
#                             proxies = get_ip_from_db("yes",db_settings)
#                         #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
#                     (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
#                     str_detail_data_html=str(detail_data_html)
#                     if len(detail_data)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
#                         print(detail_data['機關代碼'])
#                         break
                t_e = datetime.datetime.now()
                time_se= t_e - t_s
                print('此細項已抓取完成，總耗時：', time_se, 's')
                print("------------------------------------")
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"tenderDeclaration"})
        elif url_type == "searchAppeal":
            data = soup.select('center table:nth-child(1) tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxx = 0
            for i in data[17:datarow_of_end]:
                xxxx = xxxx + 1
                progress_searchAppeal = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxx)/all_data*100) + " %。"
                print(progress_searchAppeal)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=i.select('td')[2].text.strip()
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[3].text.strip()
                # 傳輸次數 (公告次數)
                times=i.select('td')[4].text.strip()
                # 招標方式
                typ=""
                # 採購性質
                clas=""
                # 公告日期
                date=re.match(r'(.*)\s*－\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(1).strip()
                # 截止投標
                enddate=re.match(r'(.*)\s*－\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(2).strip()
                # 預算金額
                budget=""
                # 內文連結
                detail_connect = {}
                detail_connects = i.select('td.T12 input')
                for ij in detail_connects:
                    try:
                        detail_connect[ij['id']]=ij['value']
                    except:
                        break
                detail_connect=urlencode(detail_connect)
                (detail_data,detail_data_html) = get_searchAppeal_detail(headers,detail_connect)
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_data':detail_data, 'detail_connect':detail_connect,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"searchAppeal"})
        elif url_type == "publicRead":
            data = soup.select('td#page table:nth-child(3) tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxx=0
            for i in data[15:datarow_of_end]:
                xxxxx = xxxxx + 1
                progress_publicRead = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " +str(((ii-1)*count_per_page+xxxxx)/all_data*100) + " %。"
                print(progress_publicRead)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                # 項次
                no=i.select('td')[0].text.strip()
                # 機關名稱
                proposer_name=i.select('td')[1].text.strip()
                # 標案案號
                bid_no=i.select('td')[2].text.strip()
                # 內文連結
                detail_connect = "https://web.pcc.gov.tw" + i.select('td')[2].select('a')[0]['href']
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[3].text.strip()
                # 傳輸次數 (公告次數)
                times=i.select('td')[4].text.strip()
                # 招標方式
                typ=""
                # 採購性質
                clas=""
                # 公告日期
                date=re.match(r'(.*)\s*─\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(1).strip()
                # 截止投標
                enddate=re.match(r'(.*)\s*─\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(2).strip()
                # 預算金額
                budget=""
                (detail_data,detail_data_html)=get_publicRead_detail(detail_connect)
                detail_data=""
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"publicRead"})
        elif url_type == "predict" : 
            data = soup.select("div#print_area table tr")
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxx = 0
            for i in data[1:datarow_of_end]:
                xxxxx = xxxxx + 1
                progress_predict = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxxx)/all_data*100) + " %。"
                print(progress_predict)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[3].text.strip()
                #標案案號
                bid_no=i.select('td')[1].text.strip()
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[2].select('a')[0].text.strip()
                # 傳輸次數
                times=""
                # 招標方式
                typ=i.select('td')[4].text.strip()
                # 採購性質
                clas=""
                # 公告日期
                date=i.select('td')[5].text.strip()
                # 截止投標
                enddate=""
                # 預算金額
                budget=""
                # 內文連結
                detail_connect = "https://web.pcc.gov.tw/tps/" + i.select('td')[6].select('a')[0]['href'][5:]
                print(detail_connect)
                while True:
                    if len(proxies)==0:
                        send_ip(refresh_proxies, db_settings,send_log=False)
                        refresh_proxies=[]
                        proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.3)
                        if proxies == []:
                            xx = get_proxy_ip("yes")
                            send_ip(xx, db_settings)
                            proxies = get_ip_from_db("yes",db_settings)
                        #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
                    (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers,typee="predict") 
                    str_detail_data_html=str(detail_data_html)
                    if len(proxies)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
                        print("predict detail 通過")
                        if re.search(r'勞務類',str_detail_data_html):
                            clas=clas+'勞務類'
                        if re.search(r'工程類',str_detail_data_html):
                            clas=clas+'工程類'
                        if re.search(r'財物類',str_detail_data_html):
                            clas=clas+'財物類'
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"predict"})
        elif url_type == "final" : 
            data = soup.select("div#print_area table tr")
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxxx = 0
            for i in data[1:datarow_of_end]:
                t_s = datetime.datetime.now()
                xxxxxx = xxxxxx + 1
                progress_final = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxxxx)/all_data*100) + " %。"
                print(progress_final)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
                # 是否更正
                if i.select('td')[2].select('font'):
                    ischange=1
                else:
                    ischange=0   
                # 標案名稱    
                bid_name=i.select('td')[2].select('u')[0].text.strip()
                # 傳輸次數
                times=""
                # 這樣可以從內頁資料抓傳輸次數： 上面有定義 dicMemberCheck 可以吐出字典裡對應key的value
#                 if detail_data['ischange'] ==0 and not re.search(r'限制性招標',detail_data['招標方式']) and not re.search(r'選擇性招標',detail_data['招標方式']):
#                     print(detail_data['新增公告傳輸次數'])
                
                # 招標方式
                typ=i.select('td')[3].text.strip()
                # 採購性質
                clas=i.select('td')[4].text.strip()
                # 公告日期
                date=i.select('td')[5].text.strip()
                # 截止投標
                enddate=""
                # 預算金額
                budget=i.select('td')[6].text.strip()
                # 內文連結
                detail_connect = "https://web.pcc.gov.tw/tps/" + i.select('td')[2].select('a')[0]['href'][3:]
                detail_data={}
                detail_data_html=""
#                 while True:
#                     if len(proxies)==0:
#                         send_ip(refresh_proxies, db_settings,send_log=False)
#                         refresh_proxies=[]
#                         proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.3)
#                         if proxies == []:
#                             xx = get_proxy_ip("yes")
#                             send_ip(xx, db_settings)
#                             proxies = get_ip_from_db("yes",db_settings)
#                         #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
#                     (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(s, detail_connect,proxies,refresh_proxies,headers,typee="final") 
#                     str_detail_data_html=str(detail_data_html)
#                     if len(detail_data)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
#                         print(detail_data['機關代碼'])
#                         break
                t_e = datetime.datetime.now()
                time_se= t_e - t_s
                print('此細項已抓取完成，總耗時：', time_se, 's')
                print("------------------------------------")
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"final"})
        time_end = datetime.datetime.now()
        time_c= time_end - time_start
        print('此分頁抓取總耗時：', time_c, 's')
        #all_data = int(data[datarow_of_end].select('span')[-1].text)
        print(all_data)
        print(ii*count_per_page)
        if ii*count_per_page >= all_data:
            if url_type == "tenderDeclaration":
                del progress_tenderDeclaration
            elif url_type == "searchAppeal":
                del progress_searchAppeal
            elif url_type == "publicRead":    
                del progress_publicRead
            elif url_type == "predict":    
                del progress_predict
            elif url_type == "final":    
                del progress_final
            break
    return raw_datas

# %%
def search_by_date(s,start_date, end_date,if_publish,headers):
    r = s.get("https://web.pcc.gov.tw/prkms/prms-viewDailyTenderListClient.do?root=tps",headers=headers)
    html_doc = r.text
    if r.status_code == 500 or re.search(r'The server encountered an internal error or misconfiguration and was unable to complete your request',html_doc):
        raise Exception("打不進去header頁") 
        return ""
    soup = BeautifulSoup(html_doc, parser)
    publishs_href=[]
    publishs_date=[]
    not_publishs_href=[]
    not_publishs_date=[]
    left = soup.select('td#page table tr td:nth-child(2) li a')
    right = soup.select('td#page table tr td:nth-child(4) li a')
    for i in left:
        publishs_href.append(i['href'])
        y=str(int(re.match(r'(.*)年(.*)月(.*)日',i['title']).group(1))+1911)
        m=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(2)
        d=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(3)
        ymd = datetime.datetime.strptime("-".join([y,m,d]), "%Y-%m-%d")
        publishs_date.append(ymd)
    for i in right:
        not_publishs_href.append(i['href'])
        y=str(int(re.match(r'(.*)年(.*)月(.*)日',i['title']).group(1))+1911)
        m=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(2)
        d=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(3)
        ymd = datetime.datetime.strptime("-".join([y,m,d]), "%Y-%m-%d")
        not_publishs_date.append(ymd)
    for i in publishs_date:
        publishs_start_date_index = publishs_date.index(i)
        if i < start_date:
            break
    for i in not_publishs_date:
        not_publishs_start_date_index = not_publishs_date.index(i)
        if i < start_date:
            break
    for i in publishs_date:
        publishs_end_date_index = publishs_date.index(i)
        if i <= end_date:
            break
    for i in not_publishs_date:
        not_publishs_end_date_index = not_publishs_date.index(i)
        if i <= end_date:
            break

    if not_publishs_start_date_index<not_publishs_end_date_index:
        raise Exception("開始日期不可大於結束日期")
    if publishs_start_date_index<publishs_end_date_index:
        raise Exception("開始日期不可大於結束日期")
    if start_date > not_publishs_date[0] or start_date > publishs_date[0]:
        raise Exception("無資料可爬，初始日期大於網站最新日期")
    
    total_hrefs=[]
    if if_publish=="all" or if_publish=="yes":
        for i in range(0,len(publishs_href[publishs_end_date_index:publishs_start_date_index])):
            total_href={'href':publishs_href[publishs_end_date_index+i],'date':publishs_date[publishs_end_date_index+i],'ispublish':1}
            total_hrefs.append(total_href)
    if if_publish=="all" or if_publish=="no":
        for i in range(0,len(not_publishs_href[not_publishs_end_date_index:not_publishs_start_date_index])):
            total_href={'href':not_publishs_href[not_publishs_end_date_index+i],'date':not_publishs_date[not_publishs_end_date_index+i],'ispublish':0}
            total_hrefs.append(total_href)
    return total_hrefs

# %%
def date_serach_crawler(s,search_date,headers):
    url_head = "https://web.pcc.gov.tw/prkms/"
    len_search_date=len(search_date)
    global progress_date_serach
    if len_search_date==0:
        return
    xxxxxx = 0
    for i in search_date:
        xxxxxx = xxxxxx + 1
        progress_date_serach = "這是第 " + str(xxxxxx) + " 個，總共有 " + str(len_search_date) + " 個要爬"
        print(search_date.index(i))
        r = s.get(url_head + i['href'], headers=headers)
        html_doc = r.text
        soup = BeautifulSoup(html_doc, parser)
        i['detail_data'] = soup.select('td#page table table table table tr td')[0]
    del progress_date_serach
    return search_date

# %%
def send_db_2(raw_datas,data_class, db_settings):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    try:
        # 建立Connection物件
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor() as cursor:
          #資料表相關操作
            get_max_log_id="select MAX(UID) FROM log"
            # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
            command = "INSERT INTO date_search_by_date(log_UID, date, ispublish, upper, lower, href)VALUES(%s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),date=values(date),ispublish =values(ispublish),upper=values(upper),lower=values(lower),href = values(href)"
            command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
            # 紀錄開始 (暫時取消)
#             cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "start", data_class, ""))
            # 取得 log 的 UID
            cursor.execute(get_max_log_id)
            log_UID = str(cursor.fetchone()[0])
            # 組合數據
            for raw_data in raw_datas:
                data_combine.append((int(log_UID), raw_data["date"], raw_data["ispublish"], "", raw_data["detail_data"], raw_data["href"]))  # 注意要用两个括号扩起来

            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as ex:
                print(ex)
                error_class = ex.__class__.__name__ #取得錯誤類型
                detail = ex.args[0] #取得詳細內容
                cl, exc, tb = sys.exc_info() #取得Call Stack
                lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
                fileName = lastCallStack[0] #取得發生的檔案名稱
                lineNum = lastCallStack[1] #取得發生的行號
                funcName = lastCallStack[2] #取得發生的函數名稱
                errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
                print(errMsg)
                cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "fail", data_class, error_class + detail + errMsg))
            # 紀錄結束
            cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "success", data_class, str(len(raw_datas)) + " datas was completed"))

    except Exception as ex:
        print(ex)

    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('time cost', time_c, 's')

# %%
# proxies = get_ip_from_db("yes",db_settings)
# # x4 = gov_serach_crawler("predict",proxies,db_settings, headers = headers)
# # send_db(x4,"predict", db_settings)
# x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers)
# send_db(x5,"final", db_settings)

# %%
#雙重 thread
my_host=input("請輸入主機ip ( 若要從本機啟動，可輸入127.0.0.1 )：")
#account=input("請輸入政府採購網帳號，目前請隨便輸入我還沒做：")
#password=input("請輸入政府採購網密碼，目前請隨便輸入我還沒做：")
my_host=str(my_host)
app = Flask(__name__)
# db_settings = {
#     "host": "127.0.0.1",
#     "port": 3306,
#     "user": "root",
#     "password": "As123459362",
#     "db": "pttcrawler",
#     "charset": "utf8",
#     "autocommit":True
# }
db_settings = {
    "host": "60.250.109.71",
    "port": 23306,
    "user": "xuan",
    "password": "Qaz123",
    "db": "tender",
    "charset": "utf8mb4",
    "autocommit":True
}
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "web.pcc.gov.tw",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
     #使用者代理
}
command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"

@app.route('/', methods=['GET'])
def test():
#     ip = request.remote_addr
#     print(ip)
#     conn = pymysql.connect(**db_settings)
#     # 建立Cursor物件
#     with conn.cursor() as cursor:
#         if_finish_command="SELECT status FROM log where task ='api_process_list' order by UID DESC"
#         cursor.execute(if_finish_command)
#         if cursor.fetchone() is None:
#             cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "initial", "", ""))
#         cursor.execute(if_finish_command)
#         if_finish = str(cursor.fetchone()[0])
#     if re.search(r'finish', if_finish, flags=0) or if_finish == "initial":
#         wording ='<p>恭喜!網站建置成功!</p><p>api說明：</p><p>1.&nbsp;/thread：查看當前執行緒狀態，無須參數 (get請求)</p><p>2.&nbsp;/start_task_all：開始執行爬蟲，若要強制重啟，參數帶 restart = 1 (get請求)</p><p>3.&nbsp;/date_serach_crawler：公告日期執行爬蟲，參數帶 start_date、end_date、if_publish (get請求)<br />start_date、end_date =&gt; 以字串型態帶日期，ex:20210125，if_publish =&gt; 以字串形式帶 all | yes | no </p><p>http://127.0.0.1:5000/date_serach_crawler?start_date=20210128&end_date=20210204&if_publish=yes</p><p>4.&nbsp;/progress：查看當前執行緒進度，無須參數 (get請求)</p><p>5. /proxy : 從免費代理網站抓取proxy進資料庫，無須參數 (get請求)'
#         status_code = 200
#     else:
#         wording ="I am busy now, please wait"
#         status_code = 500
        
    wording ='<p>恭喜!網站建置成功!</p><p>api說明：</p><p>1.&nbsp;/thread：查看當前執行緒狀態，無須參數 (get請求)</p><p>2.&nbsp;/start_task_list：執行爬蟲：抓列表資料，若要強制重啟，參數帶 restart = 1；若要設定爬取的初始頁面，參數帶 start_page=[x,x,x,x] ([招標公告頁數、公開徵求頁數、公開閱覽頁數、決標公告頁數])；若想要設定爬取 N 天前的資料，參數要帶 day_before，以 int 的方式放值，ex: day_before=0  (get請求)</p><p>http://127.0.0.1:5000/start_task_list?restart=1&start_page=[1,1,1,1]&day_before=0</p><p><p>3.&nbsp;/start_task_detail：執行爬蟲：抓內頁資料，要晚於 /start_task_list 5分鐘，可設定連接等待時間，參數帶 (float)diff_seconds_conn (要求每一次嘗試連接內頁的時間需大於多少秒)、(float)diff_seconds_data (要求確實取得內頁資料的時間需大於多少秒) (get請求)</p><p>http://127.0.0.1:5000/start_task_detail?diff_seconds_conn=0&diff_seconds_data=0</p>4.&nbsp;/date_serach_crawler：執行爬蟲：依公告日期查詢，參數帶 start_date、end_date、if_publish (get請求)<br />start_date、end_date =&gt; 以字串型態帶日期，ex:20210125，if_publish =&gt; 以字串形式帶 all | yes | no </p><p>http://127.0.0.1:5000/date_serach_crawler?start_date=20210128&end_date=20210204&if_publish=yes</p><p>5.&nbsp;/progress：查看當前執行緒進度，無須參數 (get請求)</p><p>6. /proxy : 從免費代理網站抓取proxy進資料庫，無須參數 (get請求)' 
    status_code = 200

    return wording,status_code

@app.route('/thread', methods=['GET'])
def thread_status():
    wording =""
    wording2 =""
    wording3 =""
    wording4 =""
    wording5=""
    wording6=""
    code =200
    print(str(threading.enumerate()))
    try:
        if str(threading.enumerate()).find("thread_tenderDeclaration_searchAppeal") >=0:
            wording = "當前正在執行 thread_tenderDeclaration_searchAppeal 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_date_serach_crawler") >=0:
            wording2 = "當前正在執行 thread_date_serach_crawler 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_proxy_crawler") >=0:
            wording3 = "當前正在執行 thread_proxy_crawler 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_final_datesearch_publicRead") >=0:
            wording4 = "當前正在執行 thread_final_datesearch_publicRead 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_tenderDeclaration_detail") >=0:
            wording5 = "當前正在執行 thread_tenderDeclaration_detail 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_final_detail") >=0:
            wording6 = "當前正在執行 thread_final_detail 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
        
    return wording + " " + wording2 + " " + wording3 + " " + wording4 + " " + wording5 + " " + wording6,code
        
@app.route('/proxy', methods=['GET'])
def proxy():
    def proxyy():
        p_yes=get_proxy_ip("yes")
        #p_no=get_proxy_ip("no")
        send_ip(p_yes, db_settings ,"only https",new = True)
        #send_ip(p_no, db_settings ,"only http",new = True)
    try:
        if str(threading.enumerate()).find("thread_proxy_crawler") >=0:
            return "已經在爬 proxy 了，別吵",500
    except Exception as ex:
        print(ex)
        pass    
    
    thread_proxy_crawler = threading.Thread(target=proxyy, kwargs={},name="thread_proxy_crawler")
    thread_proxy_crawler.start()
    return "started",200
    
@app.route('/start_task_list', methods=['GET'])
def start_task_all():
    if request.args:
        dd= request.args.to_dict()
        if set(['start_page','restart','day_before']) >= set(dd.keys()):
            print("傳參成功")
        else:
            return "傳參失敗，參數只允許"+' start_page '+'restart '+'day_before',500
    def do_work(start_page,day_before,db_settings,headers):
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", str(ip) + " start", "tenderDeclaration_searchAppeal", f"tenderDeclaration 從第 {start_page[0]} 頁開始爬，searchAppeal 從第 {start_page[1]} 頁開始爬"))
        time_start = time.time()
        proxies = get_ip_from_db("yes",db_settings)
        print("=====1=======")
        
        try:
            x1 = gov_serach_crawler("tenderDeclaration",proxies,db_settings, headers = headers,start_page = int(start_page[0]),day_before=day_before)
            send_db(x1,"tenderDeclaration", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "wrong", "tenderDeclaration", errMsg))
        print("=====2=======")
        try:
            x2 = gov_serach_crawler("searchAppeal",proxies,db_settings, headers = headers,start_page = int(start_page[1]),day_before=day_before)
            send_db(x2,"searchAppeal", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "wrong", "searchAppeal", errMsg))
        
#         try:
#             x4 = gov_serach_crawler("predict",proxies,db_settings, headers = headers, account=account,password=password)
#             send_db(x4,"predict", db_settings)
#         except Exception as ex:
#             print(ex)
#             error_class = ex.__class__.__name__ #取得錯誤類型
#             detail = ex.args[0] #取得詳細內容
#             cl, exc, tb = sys.exc_info() #取得Call Stack
#             lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
#             fileName = lastCallStack[0] #取得發生的檔案名稱
#             lineNum = lastCallStack[1] #取得發生的行號
#             funcName = lastCallStack[2] #取得發生的函數名稱
#             errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
#             print(errMsg)
#             conn = pymysql.connect(**db_settings)
#             with conn.cursor() as cursor:
#                 cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "wrong", "predict", errMsg))
        print("=====4=======")
        time_d = time.time()
        time_c = time_d - time_start
        print("！！！！！  thread_tenderDeclaration_searchAppeal 總執行時間 "+str(time_c) +" 秒")
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", str(ip) + " finish", "tenderDeclaration_searchAppeal", ""))
            
    def do_work_final(start_page,day_before,db_settings,headers):
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", str(ip) + " start", "final_publicRead_datesearch", f"final 從第 {start_page[3]} 頁開始爬，publicRead 從第 {start_page[2]} 頁開始爬，datesearch爬當日"))
        time_start = time.time()
        proxies = get_ip_from_db("yes",db_settings)
        try:
            x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers,start_page = int(start_page[3]),day_before=day_before)
            send_db(x5,"final", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "wrong", "final", errMsg))
                
        try:
            x3 = gov_serach_crawler("publicRead",proxies,db_settings, headers = headers,start_page = int(start_page[3]),day_before=day_before)
            send_db(x3,"publicRead", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "wrong", "publicRead", errMsg))

        try:
            s = rq.session()
            xx = search_by_date(s,datetime.datetime.today()- datetime.timedelta(days=1), datetime.datetime.today(),"all", headers = headers)
            print(xx)
            xxx = date_serach_crawler(s,xx,headers)
            send_db_2(xxx,"date_search_by_date", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "wrong", "date_serach_crawler", error_class + detail + errMsg))
      
        time_d = time.time()
        time_c = time_d - time_start
        print("！！！！！  thread_final_datesearch_publicRead 總執行時間 "+str(time_c) +" 秒")
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", str(ip) + " finish", "final_publicRead_datesearch", ""))
    
    #驗證用圖片資料夾
    path = './temp_validate_img'
    if os.path.exists(path):
        shutil.rmtree (path)
        os.mkdir(path)
    else:
        os.mkdir(path)
    #資料庫log檢查
    ip = request.remote_addr
    conn = pymysql.connect(**db_settings)
    if_finish_command="SELECT status FROM log where task ='api_process_list' order by UID DESC"
    with conn.cursor() as cursor:
        cursor.execute(if_finish_command)
        if cursor.fetchone() is None:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_list", "initial", "", ""))
        cursor.execute(if_finish_command)
        if_finish = str(cursor.fetchone()[0])
    
    # 不判斷資料庫log強制重啟
    if re.search(r'finish', if_finish, flags=0) or re.search(r'wrong', if_finish, flags=0) or if_finish == "initial":
        pass
    elif "restart" in request.args:
        try:
            if request.args.get("restart")==1:
                pass
        except:
            return "若想要重啟爬蟲，參數要帶restart，值請放 1 "
    else:
        return "資料庫未收到結束log，可帶參數 restart=1 忽略資料庫log判斷",500
    #執行序之間任一ip被鎖block全部
    global waitt
    waitt = False
    
    day_before=0
    if 'day_before' in request.args:
        try:
            day_before = eval(request.args.get("day_before"))
        except:
            return "若想要設定爬取 N 天前的資料，參數要帶 day_before，以 int 的方式放值，ex: day_before=0 "

    
    #設定起始頁面
    start_page=[1,1,1,1]
    if 'start_page' in request.args:
        try:
            start_page = eval(request.args.get("start_page"))
            if len(start_page) !=4:
                return "start_page 參數長度不足 4 (須設定 4 個：tenderDeclaration、searchAppeal、publicRead、final)，無須爬取的項目可輸入1999！"
            else:
                print("頁數參數接收成功")
        except:
            return "若想要設定爬取的初始頁數，參數要帶 start_page，以 list 的方式放值=>[招標公告頁數,公開徵求頁數,公開閱覽頁數,決標公告頁數]，ex: start_page=[1,1,1,1] "
    print(f"tenderDeclaration 從第 {start_page[0]} 頁開始爬取")
    print(f"searchAppeal 從第 {start_page[1]} 頁開始爬取")
    print(f"publicRead 從第 {start_page[2]} 頁開始爬取")
    print(f"final 從第 {start_page[3]} 頁開始爬取")
    
    try:
        if str(threading.enumerate()).find("thread_tenderDeclaration_searchAppeal") >= 0 :
            wording0="thread_tenderDeclaration_searchAppeal 執行緒正在執行；"
        else:
            thread_tenderDeclaration_searchAppeal = threading.Thread(target=do_work, kwargs={'start_page':start_page,'day_before':day_before,'db_settings': db_settings,'headers': headers},name="thread_tenderDeclaration_searchAppeal")
            thread_tenderDeclaration_searchAppeal.start()
            wording0="啟動 thread_tenderDeclaration_searchAppeal 執行緒；"
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_final_datesearch_publicRead") >= 0 :
            wording1="thread_final_datesearch_publicRead 執行緒正在執行"
        else:
            thread_final_datesearch_publicRead = threading.Thread(target=do_work_final, kwargs={'start_page':start_page,'day_before':day_before,'db_settings': db_settings,'headers': headers},name="thread_final_datesearch_publicRead")
            thread_final_datesearch_publicRead.start()
            wording1="啟動 thread_final_datesearch_publicRead 執行緒"
    except Exception as ex:
        print(ex)
        pass

    return wording0+wording1,200

@app.route('/start_task_detail', methods=['GET'])
def start_task_detail():
    path = './temp_validate_img'
    if os.path.exists(path):
        shutil.rmtree (path)
        os.mkdir(path)
    else:
        os.mkdir(path)
    ip = request.remote_addr

    def do_work_detail(tenderType,diff_seconds_data,diff_seconds_conn,db_settings,headers):
        global progress_final_detail
        progress_final_detail =''
        global progress_tenderDeclaration_detail
        progress_tenderDeclaration_detail =''
        
        conn = pymysql.connect(**db_settings)
        get_data="SELECT * FROM tender.gov_purchase where (detail_data_html ='' and detail_data like '%{}%') and tenderType='"+tenderType+"'"
        # 建立Cursor物件
        with conn.cursor(pymysql.cursors.DictCursor) as cursor:
          #資料表相關操作
            cursor.execute(get_data)
            raw_datas = cursor.fetchall()            
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_detail", str(ip) + " start", tenderType, f"共有 {len(raw_datas)} 項需處理"))
        print(f'{tenderType} 一共抓出 {len(raw_datas)} 筆還沒有內頁資料')
        
        try:
            #限制嘗試抓取次數，避免死機
            x=0
            while len(raw_datas)>0:
                #避免過長抓取失敗
                if len(raw_datas)>=1000:
                    raw_datas=raw_datas[0:1000]
                ll = get_only_detail(tenderType,raw_datas,diff_seconds_data,diff_seconds_conn,headers, db_settings)
                # get_only_detail會回傳成功抓取的筆數 (ll)
                if ll>1:
                    x = 0
                else:
                    x = x + 1 
                conn = pymysql.connect(**db_settings)
                # 建立Cursor物件
                with conn.cursor(pymysql.cursors.DictCursor) as cursor:
                  #資料表相關操作
                    cursor.execute(get_data)
                    raw_datas = cursor.fetchall()
                if len(raw_datas) ==0:
                    print('都抓完了！！！！')
                    break
                else:
                    if x>4:
                        print(f'{tenderType} 出現 {len(raw_datas)} 筆無法抓取內頁資料')
                        break
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_detail", str(ip)+"finish", tenderType, ""))

        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_detail", "wrong", "tenderDeclaration_final_detail", errMsg))
        
        if tenderType=='tenderDeclaration':
            del progress_tenderDeclaration_detail
        elif tenderType=='final':
            del progress_final_detail
            
    diff_seconds_data=0
    diff_seconds_conn=0
    
    if request.args:
        dd= request.args.to_dict()
        if set(['diff_seconds_data','diff_seconds_conn']) >= set(dd.keys()):
            print("傳參成功")
        else:
            return "傳參失敗，參數只允許"+' diff_seconds_data '+'diff_seconds_conn',500
        try:
            #限制取得內頁資料的時間
            diff_seconds_data = dicMemberCheck('diff_seconds_data',dd)
            print(f"diff_seconds_data {diff_seconds_data}")
            if diff_seconds_data !="":
                diff_seconds_data=float(diff_seconds_data)
            #限制每一次嘗試取得內頁資料的時間
            diff_seconds_conn = dicMemberCheck('diff_seconds_conn',dd)
            print(f"diff_seconds_conn {diff_seconds_conn}")
            if diff_seconds_conn !="":
                diff_seconds_conn=float(diff_seconds_conn)     
        except Exception as ex:
            print(ex)
            return "參數轉換錯誤",500
    
    
    if str(threading.enumerate()).find("thread_tenderDeclaration_detail") >= 0 :
        wording1="thread_tenderDeclaration_detail 執行緒正在執行"
    else:
        thread_tenderDeclaration_detail = threading.Thread(target=do_work_detail, kwargs={'tenderType':'tenderDeclaration','diff_seconds_data':diff_seconds_data,'diff_seconds_conn':diff_seconds_conn,'headers':headers,'db_settings': db_settings},name="thread_tenderDeclaration_detail")
        thread_tenderDeclaration_detail.start()
        wording1="啟動 thread_tenderDeclaration_detail 執行緒"
        
    if str(threading.enumerate()).find("thread_final_detail") >= 0 :
        wording2="thread_final_detail 執行緒正在執行"
    else:
        thread_final_detail = threading.Thread(target=do_work_detail, kwargs={'tenderType':'final','diff_seconds_data':diff_seconds_data,'diff_seconds_conn':diff_seconds_conn,'headers':headers,'db_settings': db_settings},name="thread_final_detail")
        thread_final_detail.start()
        wording2="啟動 thread_final_detail 執行緒"
        
    return wording1 +" "+ wording2,200



@app.route('/progress', methods=['GET'])
def get_progress():
    wording={}
    try:
        wording['tenderDeclaration'] = progress_tenderDeclaration
    except:
        wording['tenderDeclaration'] = "tenderDeclaration 任務未啟動"
        
    try:
        wording['searchAppeal'] = progress_searchAppeal
    except:
        wording['searchAppeal'] = "searchAppeal 任務未啟動"
        
    try:
        wording['publicRead'] = progress_publicRead
    except:
        wording['publicRead'] = "publicRead 任務未啟動"
        
    try:
        wording['predict'] = progress_predict
    except:
        wording['predict'] = "predict 任務未啟動"
    
    try:
        wording['final'] = progress_final
    except:
        wording['final'] = "final 任務未啟動"
        
    try:
        wording['date_serach'] = progress_date_serach
    except:
        wording['date_serach'] = "date_serach 任務未啟動"

    try:
        wording['tenderDeclaration_detail'] = progress_tenderDeclaration_detail
    except:
        wording['tenderDeclaration_detail'] = "tenderDeclaration_detail 任務未啟動"
        
    try:
        wording['final_detail'] = progress_final_detail
    except:
        wording['final'] = "final_detail 任務未啟動"
        
    return wording,200

# @app.route('/test', methods=['GET'])
# def tesddt():
#     if request.args:
#         dd= request.args.to_dict()
#         if set(['start_date','end_date','']) >= set(dd.keys()):
#             return "傳參成功",200
#         else:
#             return "傳參失敗",200


@app.route('/date_serach_crawler', methods=['GET'])
def date_serach():
    if request.args:
        dd= request.args.to_dict()
        if set(['start_date','end_date','if_publish']) >= set(dd.keys()):
            print("傳參成功")
        else:
            return "傳參失敗，參數只允許"+' start_date '+'end_date '+'if_publish',500
    headers["User-Agent"] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
    def do_work_2(start_date,end_date,if_publish,db_settings,headers):
        s = rq.session()
        try:
            xx = search_by_date(s,start_date, end_date,if_publish,headers)
            print(xx)
            xxx = date_serach_crawler(s,xx,headers)
            send_db_2(xxx,"date_search_by_date", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "wrong", "date_serach_crawler", error_class + detail + errMsg))
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", str(ip) + " finish", "date_serach_crawler", ""))
        
        
    try:
        if str(threading.enumerate()).find("thread_start_date_serach_crawler") >=0:
            return "當前執行緒正在執行",500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        start_date = str(request.args.get("start_date"))
        start_date = datetime.datetime.strptime(start_date, "%Y%m%d")
    except Exception as ex:    
        return "start_date 參數格式錯誤",500
    
    try:
        end_date = str(request.args.get("end_date"))
        end_date = datetime.datetime.strptime(end_date, "%Y%m%d")
    except Exception as ex:    
        return "end_date 參數格式錯誤",500
    
    try:
        if_publish = str(request.args.get("if_publish"))
        if not (if_publish == "yes" or if_publish == "no" or if_publish == "all"):
            return "if_publish 參數格式錯誤",500
    except Exception as ex:
        return "if_publish 參數沒帶",500
        
    
    ip = request.remote_addr
    conn = pymysql.connect(**db_settings)
    with conn.cursor() as cursor:
        if_finish_command="SELECT status FROM log where task ='api_process_date_serach' order by UID DESC"
        cursor.execute(if_finish_command)
        if cursor.fetchone() is None:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "initial", "", ""))
        cursor.execute(if_finish_command)
        if_finish = str(cursor.fetchone()[0])
    
    print(if_finish)    
    if re.search(r'finish', if_finish, flags=0) or re.search(r'wrong', if_finish, flags=0) or if_finish == "initial":
        pass
    else:
        wording ="資料庫未收到結束log"
        status_code = 500
        return wording,status_code
    
    conn = pymysql.connect(**db_settings)
    with conn.cursor() as cursor:
        cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", str(ip) + " start", "date_serach_crawler", ""))
    
    thread_date_serach_crawler = threading.Thread(target=do_work_2, kwargs={'start_date': start_date,'end_date': end_date,'if_publish':if_publish,'db_settings':db_settings,'headers':headers},name="thread_date_serach_crawler")
    thread_date_serach_crawler.start()    
    return "started",200


if __name__ == '__main__':
    app.debug = False
    app.config['JSON_AS_ASCII'] = False
    app.run(host=my_host, port=5000)
    #serve(app, host=my_host, port=5000)
# Out:
# 請輸入主機ip ( 若要從本機啟動，可輸入127.0.0.1 )：
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Mar/2022 22:42:48] "GET /start_task_detail?diff_seconds_conn=0&diff_seconds_data=0 HTTP/1.1" 200 -
# 傳參成功
# diff_seconds_data 0
# diff_seconds_conn 0
# final 一共抓出 48840 筆還沒有內頁資料
# --------------------
# time cost 0:00:00.388353 s
# 失敗總次數：0，強制重抓proxy！！！！！！！！！！
# usproxy
# tenderDeclaration 一共抓出 46263 筆還沒有內頁資料
# --------------------
# time cost 0:00:00.175159 s
# http://149.28.120.8:59394
# 失敗總次數：0，強制重抓proxy！！！！！！！！！！
# usproxy
# http://149.28.120.8:59394
# ---------------
# http://12.218.209.130:53281
# ---------------
# http://12.218.209.130:53281
# ---------------
# http://20.47.108.204:8888
# ---------------
# http://74.207.235.154:8082
# ---------------
# http://20.47.108.204:8888
# ---------------
# http://74.207.235.154:8082
# ---------------
# http://154.85.35.235:8888
# ---------------
# freeproxylist
# ---------------
# http://154.85.35.235:8888
# ---------------
# freeproxylist
# http://27.72.147.22:40009
# http://27.72.147.22:40009
# ---------------
# http://213.139.32.14:8080
# ---------------
# http://213.139.32.14:8080
# ---------------
# http://103.73.194.2:80
# 200
# ---------------
# http://170.155.5.235:8080
# 200
# ---------------
# http://182.72.150.242:8080
# ---------------
# http://103.73.194.2:80
# ---------------
# http://170.155.5.235:8080
# ---------------
# http://149.28.120.8:59394
# 200
# ---------------
# http://182.72.150.242:8080
# ---------------
# http://20.105.253.176:8080
# ---------------
# http://149.28.120.8:59394
# ---------------
# http://20.105.253.176:8080
# ---------------
# http://12.218.209.130:53281
# ---------------
# http://185.88.37.107:8085
# ---------------
# http://12.218.209.130:53281
# ---------------
# http://37.61.222.165:1080
# ---------------
# http://185.88.37.107:8085
# ---------------
# http://122.15.131.65:57873
# ---------------
# http://37.61.222.165:1080
# ---------------
# http://20.47.108.204:8888
# ---------------
# http://195.158.24.221:3128
# ---------------
# http://101.32.186.80:60080
# ---------------
# http://187.49.70.238:8080
# ---------------
# http://115.79.198.18:55443
# ---------------
# http://122.15.131.65:57873
# ---------------
# http://95.137.240.30:60030
# ---------------
# http://20.47.108.204:8888
# ---------------
# http://195.158.24.221:3128
# ---------------
# http://109.194.101.128:3128
# ---------------
# http://101.32.186.80:60080
# ---------------
# http://109.75.145.152:15392
# ---------------
# http://187.49.70.238:8080
# ---------------
# http://83.166.241.233:3130
# ---------------
# http://115.79.198.18:55443
# ---------------
# http://74.207.235.154:8082
# ---------------
# http://95.137.240.30:60030
# ---------------
# http://121.146.167.17:4001
# ---------------
# http://109.194.101.128:3128
# ---------------
# http://85.195.86.229:1080
# ---------------
# http://109.75.145.152:15392
# ---------------
# http://83.166.241.233:3130
# ---------------
# http://195.191.246.53:53281
# ---------------
# http://74.207.235.154:8082
# ---------------
# http://154.85.35.235:8888
# ---------------
# http://85.114.112.22:8083
# ---------------
# http://121.146.167.17:4001
# ---------------
# http://212.34.1.110:8080
# ---------------
# http://85.195.86.229:1080
# ---------------
# free-proxy.cz抓取頁數： 1
# http://free-proxy.cz/zh/proxylist/country/all/https/ping/all
# 37
# http://64.235.204.107:3128
# ---------------
# http://198.255.17.202:3129
# ---------------
# http://195.191.246.53:53281
# ---------------
# http://45.33.26.53:3128
# ---------------
# http://154.85.35.235:8888
# ---------------
# http://85.114.112.22:8083
# ---------------
# http://12.3.243.178:8080
# ---------------
# http://212.34.1.110:8080
# ---------------
# http://165.225.218.108:10605
# ---------------
# ---------------
# http://51.195.76.214:3128
# free-proxy.cz抓取頁數： 1
# http://free-proxy.cz/zh/proxylist/country/all/https/ping/all
# 37
# http://64.235.204.107:3128
# ---------------
# http://147.161.169.25:10185
# ---------------
# http://154.236.179.226:1981
# ---------------
# http://198.255.17.202:3129
# ---------------
# http://62.3.30.22:8080
# ---------------
# http://45.33.26.53:3128
# ---------------
# http://165.225.16.40:10011
# ---------------
# http://147.161.167.7:10043
# ---------------
# http://12.3.243.178:8080
# ---------------
# http://147.161.166.249:10308
# ---------------
# http://165.225.20.238:10062
# ---------------
# http://41.65.103.22:1981
# ---------------
# http://165.225.218.108:10605
# ---------------
# http://51.195.76.214:3128
# ---------------
# http://165.225.12.232:10030
# ---------------
# http://147.161.169.25:10185
# ---------------
# http://165.225.77.128:10605
# ---------------
# http://154.236.179.226:1981
# ---------------
# http://165.225.16.39:10029
# ---------------
# http://165.225.193.152:10013
# ---------------
# http://147.161.167.2:10006
# ---------------
# http://165.225.76.81:10605
# ---------------
# http://62.3.30.22:8080
# ---------------
# http://165.225.192.32:10116
# ---------------
# http://156.200.116.68:1976
# ---------------
# http://165.225.16.40:10011
# ---------------
# http://147.161.167.7:10043
# ---------------
# http://147.161.166.249:10308
# ---------------
# http://165.225.192.165:10622
# ---------------
# http://165.225.26.31:10089
# ---------------
# http://165.225.20.238:10062
# ---------------
# http://165.225.27.16:10576
# ---------------
# http://41.65.103.22:1981
# ---------------
# http://165.225.210.152:10223
# ---------------
# http://165.225.27.14:10197
# ---------------
# http://165.225.12.232:10030
# ---------------
# http://165.225.192.31:10007
# ---------------
# http://165.225.77.128:10605
# ---------------
# http://165.225.24.48:10012
# ---------------
# http://165.225.16.39:10029
# ---------------
# http://165.225.194.150:10127
# ---------------
# http://165.225.193.152:10013
# ---------------
# http://165.225.80.236:10605
# ---------------
# http://147.161.167.2:10006
# ---------------
# http://165.225.196.84:10605
# ---------------
# http://165.225.76.81:10605
# ---------------
# http://165.225.12.251:10526
# ---------------
# http://165.225.192.32:10116
# ---------------
# http://165.225.12.110:10605
# ---------------
# http://156.200.116.68:1976
# ---------------
# http://77.79.182.191:53281
# ---------------
# http://165.225.192.165:10622
# ---------------
# ---------------
# http://165.225.26.31:10089
# ---------------
# http://165.225.27.16:10576
# ---------------
# http://165.225.210.152:10223
# ---------------
# http://165.225.27.14:10197
# ---------------
# http://165.225.192.31:10007
# ---------------
# http://165.225.24.48:10012
# ---------------
# http://165.225.194.150:10127
# ---------------
# http://165.225.80.236:10605
# ---------------
# http://165.225.196.84:10605
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ---------------
# http://165.225.12.251:10526
# ---------------
# http://165.225.12.110:10605
# ---------------
# http://77.79.182.191:53281
# ---------------
# HTTPConnectionPool(host='free-proxy.cz', port=80): Max retries exceeded with url: /zh/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000026167C8F280>, 'Connection to free-proxy.cz timed out. (connect timeout=10)'))
# time cost 0:00:00.575523 s
# http://74.207.235.154:8082 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://74.207.235.154:8082連接失敗，還剩餘 66 個proxy
# http://213.139.32.14:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://213.139.32.14:8080連接失敗，還剩餘 65 個proxy
# http://74.207.235.154:8082 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://74.207.235.154:8082連接失敗，還剩餘 64 個proxy
# http://83.166.241.233:3130 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# HTTPConnectionPool(host='free-proxy.cz', port=80): Max retries exceeded with url: /zh/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000026167C88040>, 'Connection to free-proxy.cz timed out. (connect timeout=10)'))
# time cost 0:00:00.346314 s
# http://154.85.35.235:8888 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://154.85.35.235:8888連接失敗，還剩餘 66 個proxy
# http://165.225.16.39:10029 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.16.39:10029連接失敗，還剩餘 65 個proxy
# http://156.200.116.68:1976 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://83.166.241.233:3130連接失敗，還剩餘 63 個proxy
# http://109.194.101.128:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://156.200.116.68:1976連接失敗，還剩餘 64 個proxy
# http://165.225.196.84:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.196.84:10605連接失敗，還剩餘 63 個proxy
# http://165.225.194.150:10127 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://109.194.101.128:3128連接失敗，還剩餘 62 個proxy
# http://165.225.192.31:10007 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.194.150:10127連接失敗，還剩餘 62 個proxy
# http://20.47.108.204:8888 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://20.47.108.204:8888連接失敗，還剩餘 61 個proxy
# http://122.15.131.65:57873 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.192.31:10007連接失敗，還剩餘 61 個proxy
# http://154.85.35.235:8888 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://154.85.35.235:8888連接失敗，還剩餘 60 個proxy
# http://165.225.16.39:10029 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.16.39:10029連接失敗，還剩餘 59 個proxy
# http://165.225.192.32:10116 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.32:10116連接失敗，還剩餘 58 個proxy
# http://165.225.193.152:10013 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.193.152:10013連接失敗，還剩餘 57 個proxy
# http://115.79.198.18:55443 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://122.15.131.65:57873連接失敗，還剩餘 60 個proxy
# http://165.225.27.16:10576 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.27.16:10576連接失敗，還剩餘 59 個proxy
# http://213.139.32.14:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://115.79.198.18:55443連接失敗，還剩餘 56 個proxy
# http://62.3.30.22:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://213.139.32.14:8080連接失敗，還剩餘 58 個proxy
# http://154.85.35.235:8888 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://154.85.35.235:8888連接失敗，還剩餘 57 個proxy
# http://83.166.241.233:3130 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://62.3.30.22:8080連接失敗，還剩餘 55 個proxy
# http://195.158.24.221:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://83.166.241.233:3130連接失敗，還剩餘 56 個proxy
# http://41.65.103.22:1981 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://195.158.24.221:3128連接失敗，還剩餘 54 個proxy
# http://198.255.17.202:3129 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://198.255.17.202:3129連接失敗，還剩餘 53 個proxy
# http://165.225.218.108:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.218.108:10605連接失敗，還剩餘 52 個proxy
# http://27.72.147.22:40009 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://41.65.103.22:1981連接失敗，還剩餘 55 個proxy
# http://165.225.12.110:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.12.110:10605連接失敗，還剩餘 54 個proxy
# http://147.161.167.7:10043 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://147.161.167.7:10043連接失敗，還剩餘 53 個proxy
# http://147.161.167.2:10006 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://147.161.167.2:10006連接失敗，還剩餘 52 個proxy
# http://85.114.112.22:8083 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://27.72.147.22:40009連接失敗，還剩餘 51 個proxy
# http://12.218.209.130:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://85.114.112.22:8083連接失敗，還剩餘 51 個proxy
# http://20.105.253.176:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://12.218.209.130:53281連接失敗，還剩餘 50 個proxy
# http://20.47.108.204:8888 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://20.47.108.204:8888連接失敗，還剩餘 49 個proxy
# http://103.73.194.2:80 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://103.73.194.2:80連接失敗，還剩餘 48 個proxy
# http://64.235.204.107:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://64.235.204.107:3128連接失敗，還剩餘 47 個proxy
# http://85.195.86.229:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://20.105.253.176:8080連接失敗，還剩餘 50 個proxy
# http://64.235.204.107:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://85.195.86.229:1080連接失敗，還剩餘 46 個proxy
# http://187.49.70.238:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://64.235.204.107:3128連接失敗，還剩餘 49 個proxy
# http://77.79.182.191:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://187.49.70.238:8080連接失敗，還剩餘 45 個proxy
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://77.79.182.191:53281連接失敗，還剩餘 48 個proxy
# http://101.32.186.80:60080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://101.32.186.80:60080連接失敗，還剩餘 47 個proxy
# http://37.61.222.165:1080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://170.155.5.235:8080連接失敗，還剩餘 44 個proxy
# http://185.88.37.107:8085 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://185.88.37.107:8085連接失敗，還剩餘 43 個proxy
# http://165.225.27.16:10576 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.27.16:10576連接失敗，還剩餘 42 個proxy
# http://165.225.210.152:10223 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.210.152:10223連接失敗，還剩餘 41 個proxy
# http://45.33.26.53:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://37.61.222.165:1080連接失敗，還剩餘 46 個proxy
# http://187.49.70.238:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://45.33.26.53:3128連接失敗，還剩餘 40 個proxy
# http://95.137.240.30:60030 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://187.49.70.238:8080連接失敗，還剩餘 45 個proxy
# http://165.225.193.152:10013 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://95.137.240.30:60030連接失敗，還剩餘 39 個proxy
# http://182.72.150.242:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.193.152:10013連接失敗，還剩餘 44 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://182.72.150.242:8080連接失敗，還剩餘 38 個proxy
# http://20.105.253.176:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://149.28.120.8:59394連接失敗，還剩餘 43 個proxy
# http://212.34.1.110:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://20.105.253.176:8080連接失敗，還剩餘 37 個proxy
# http://165.225.16.40:10011 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.16.40:10011連接失敗，還剩餘 36 個proxy
# http://121.146.167.17:4001 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://121.146.167.17:4001連接失敗，還剩餘 35 個proxy
# http://165.225.80.236:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.80.236:10605連接失敗，還剩餘 34 個proxy
# http://165.225.12.232:10030 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.12.232:10030連接失敗，還剩餘 33 個proxy
# http://12.218.209.130:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://212.34.1.110:8080連接失敗，還剩餘 42 個proxy
# http://165.225.76.81:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.76.81:10605連接失敗，還剩餘 41 個proxy
# http://85.195.86.229:1080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://12.218.209.130:53281連接失敗，還剩餘 32 個proxy
# http://165.225.12.251:10526 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.12.251:10526連接失敗，還剩餘 31 個proxy
# http://165.225.20.238:10062 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.20.238:10062連接失敗，還剩餘 30 個proxy
# http://165.225.12.110:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.12.110:10605連接失敗，還剩餘 29 個proxy
# http://37.61.222.165:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://37.61.222.165:1080連接失敗，還剩餘 28 個proxy
# http://147.161.167.2:10006 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://147.161.167.2:10006連接失敗，還剩餘 27 個proxy
# http://165.225.194.150:10127 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.194.150:10127連接失敗，還剩餘 26 個proxy
# http://147.161.167.7:10043 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://85.195.86.229:1080連接失敗，還剩餘 40 個proxy
# http://109.194.101.128:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://147.161.167.7:10043連接失敗，還剩餘 25 個proxy
# http://147.161.169.25:10185 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://147.161.169.25:10185連接失敗，還剩餘 24 個proxy
# http://212.34.1.110:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://212.34.1.110:8080連接失敗，還剩餘 23 個proxy
# http://101.32.186.80:60080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://101.32.186.80:60080連接失敗，還剩餘 22 個proxy
# http://165.225.192.165:10622 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.165:10622連接失敗，還剩餘 21 個proxy
# http://154.85.35.235:8888 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://154.85.35.235:8888連接失敗，還剩餘 20 個proxy
# http://122.15.131.65:57873 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://109.194.101.128:3128連接失敗，還剩餘 39 個proxy
# http://115.79.198.18:55443 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://122.15.131.65:57873連接失敗，還剩餘 19 個proxy
# http://77.79.182.191:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://115.79.198.18:55443連接失敗，還剩餘 38 個proxy
# http://165.225.12.232:10030 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.12.232:10030連接失敗，還剩餘 37 個proxy
# http://198.255.17.202:3129 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://77.79.182.191:53281連接失敗，還剩餘 18 個proxy
# http://20.47.108.204:8888 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://20.47.108.204:8888連接失敗，還剩餘 17 個proxy
# http://109.75.145.152:15392 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://198.255.17.202:3129連接失敗，還剩餘 36 個proxy
# http://165.225.24.48:10012 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.24.48:10012連接失敗，還剩餘 35 個proxy
# http://165.225.192.31:10007 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.192.31:10007連接失敗，還剩餘 34 個proxy
# http://165.225.27.14:10197 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://109.75.145.152:15392連接失敗，還剩餘 16 個proxy
# http://154.236.179.226:1981 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.27.14:10197連接失敗，還剩餘 33 個proxy
# http://51.195.76.214:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://154.236.179.226:1981連接失敗，還剩餘 15 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://51.195.76.214:3128連接失敗，還剩餘 32 個proxy
# http://165.225.26.31:10089 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.26.31:10089連接失敗，還剩餘 31 個proxy
# http://12.218.209.130:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://149.28.120.8:59394連接失敗，還剩餘 14 個proxy
# http://156.200.116.68:1976 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://12.218.209.130:53281連接失敗，還剩餘 30 個proxy
# http://165.225.80.236:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.80.236:10605連接失敗，還剩餘 29 個proxy
# http://147.161.166.249:10308 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://147.161.166.249:10308連接失敗，還剩餘 28 個proxy
# http://195.158.24.221:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://156.200.116.68:1976連接失敗，還剩餘 13 個proxy
# http://41.65.103.22:1981 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://195.158.24.221:3128連接失敗，還剩餘 27 個proxy
# http://12.218.209.130:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://41.65.103.22:1981連接失敗，還剩餘 12 個proxy
# http://165.225.27.14:10197 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://12.218.209.130:53281連接失敗，還剩餘 26 個proxy
# http://165.225.192.165:10622 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.27.14:10197連接失敗，還剩餘 11 個proxy
# http://85.114.112.22:8083 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.165:10622連接失敗，還剩餘 25 個proxy
# http://185.88.37.107:8085 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://85.114.112.22:8083連接失敗，還剩餘 10 個proxy
# http://165.225.196.84:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.196.84:10605連接失敗，還剩餘 9 個proxy
# http://165.225.77.128:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://185.88.37.107:8085連接失敗，還剩餘 24 個proxy
# http://62.3.30.22:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.77.128:10605連接失敗，還剩餘 8 個proxy
# http://195.191.246.53:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://62.3.30.22:8080連接失敗，還剩餘 23 個proxy
# http://12.3.243.178:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://195.191.246.53:53281連接失敗，還剩餘 7 個proxy
# http://165.225.24.48:10012 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.24.48:10012連接失敗，還剩餘 6 個proxy
# http://51.195.76.214:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://12.3.243.178:8080連接失敗，還剩餘 22 個proxy
# http://154.236.179.226:1981 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://51.195.76.214:3128連接失敗，還剩餘 5 個proxy
# http://165.225.26.31:10089 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.26.31:10089連接失敗，還剩餘 4 個proxy
# http://165.225.76.81:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://154.236.179.226:1981連接失敗，還剩餘 21 個proxy
# http://74.207.235.154:8082 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.76.81:10605連接失敗，還剩餘 3 個proxy
# http://147.161.166.249:10308 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://147.161.166.249:10308連接失敗，還剩餘 2 個proxy
# http://12.3.243.178:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://74.207.235.154:8082連接失敗，還剩餘 20 個proxy
# http://74.207.235.154:8082 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://12.3.243.178:8080連接失敗，還剩餘 1 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://74.207.235.154:8082連接失敗，還剩餘 19 個proxy
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# proxy 不夠用了，重新獲取
# 失敗總次數：0，危險！
# time cost 0:00:00.308280 s
# http://165.225.192.165:10622 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.165:10622連接失敗，還剩餘 56 個proxy
# http://165.225.26.31:10089 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.26.31:10089連接失敗，還剩餘 55 個proxy
# http://165.225.12.251:10526 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.12.251:10526連接失敗，還剩餘 54 個proxy
# http://20.105.253.176:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://20.105.253.176:8080連接失敗，還剩餘 53 個proxy
# http://165.225.27.14:10197 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://170.155.5.235:8080連接失敗，還剩餘 18 個proxy
# http://109.75.145.152:15392 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.27.14:10197連接失敗，還剩餘 52 個proxy
# http://187.49.70.238:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://109.75.145.152:15392連接失敗，還剩餘 17 個proxy
# http://103.73.194.2:80 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://103.73.194.2:80連接失敗，還剩餘 16 個proxy
# http://20.47.108.204:8888 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://20.47.108.204:8888連接失敗，還剩餘 15 個proxy
# http://121.146.167.17:4001 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://121.146.167.17:4001連接失敗，還剩餘 14 個proxy
# http://165.225.192.32:10116 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://187.49.70.238:8080連接失敗，還剩餘 51 個proxy
# http://165.225.192.32:10116 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.32:10116連接失敗，還剩餘 13 個proxy
# http://165.225.20.238:10062 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.192.32:10116連接失敗，還剩餘 50 個proxy
# http://182.72.150.242:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.20.238:10062連接失敗，還剩餘 12 個proxy
# http://165.225.77.128:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.77.128:10605連接失敗，還剩餘 11 個proxy
# http://165.225.210.152:10223 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.210.152:10223連接失敗，還剩餘 10 個proxy
# http://45.33.26.53:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://182.72.150.242:8080連接失敗，還剩餘 49 個proxy
# http://51.195.76.214:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://45.33.26.53:3128連接失敗，還剩餘 9 個proxy
# http://165.225.16.40:10011 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.16.40:10011連接失敗，還剩餘 8 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://51.195.76.214:3128連接失敗，還剩餘 48 個proxy
# http://165.225.210.152:10223 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.210.152:10223連接失敗，還剩餘 47 個proxy
# http://109.75.145.152:15392 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://149.28.120.8:59394連接失敗，還剩餘 7 個proxy
# http://27.72.147.22:40009 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://109.75.145.152:15392連接失敗，還剩餘 46 個proxy
# http://37.61.222.165:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://37.61.222.165:1080連接失敗，還剩餘 45 個proxy
# http://62.3.30.22:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://27.72.147.22:40009連接失敗，還剩餘 6 個proxy
# http://95.137.240.30:60030 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://62.3.30.22:8080連接失敗，還剩餘 44 個proxy
# http://77.79.182.191:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://95.137.240.30:60030連接失敗，還剩餘 5 個proxy
# http://165.225.12.251:10526 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.12.251:10526連接失敗，還剩餘 4 個proxy
# http://165.225.218.108:10605 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://165.225.218.108:10605連接失敗，還剩餘 3 個proxy
# http://147.161.169.25:10185 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://147.161.169.25:10185連接失敗，還剩餘 2 個proxy
# http://182.72.150.242:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://182.72.150.242:8080連接失敗，還剩餘 1 個proxy
# http://195.191.246.53:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://77.79.182.191:53281連接失敗，還剩餘 43 個proxy
# http://156.200.116.68:1976 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# proxy 不夠用了，重新獲取
# 失敗總次數：0，危險！
# time cost 0:00:00.275250 s
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://156.200.116.68:1976連接失敗，還剩餘 42 個proxy
# http://109.194.101.128:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# proxy 不夠用了，重新獲取
# 失敗總次數：1，危險！
# time cost 0:00:00.283257 s
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://109.194.101.128:3128連接失敗，還剩餘 41 個proxy
# http://185.88.37.107:8085 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://185.88.37.107:8085連接失敗，還剩餘 40 個proxy
# http://195.158.24.221:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://195.158.24.221:3128連接失敗，還剩餘 39 個proxy
# http://165.225.193.152:10013 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.193.152:10013連接失敗，還剩餘 38 個proxy
# http://165.225.12.110:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.12.110:10605連接失敗，還剩餘 37 個proxy
# http://147.161.167.7:10043 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://147.161.167.7:10043連接失敗，還剩餘 36 個proxy
# http://165.225.192.31:10007 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.192.31:10007連接失敗，還剩餘 35 個proxy
# http://195.191.246.53:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# proxy 不夠用了，重新獲取
# 失敗總次數：2，危險！
# time cost 0:00:00.247226 s
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://195.191.246.53:53281連接失敗，還剩餘 34 個proxy
# http://165.225.27.16:10576 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.27.16:10576連接失敗，還剩餘 33 個proxy
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# proxy 不夠用了，重新獲取
# 失敗總次數：3，危險！
# time cost 0:00:00.287261 s
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53719874
# http://170.155.5.235:8080連接失敗，還剩餘 32 個proxy
# http://27.72.147.22:40009 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# proxy 不夠用了，重新獲取
# 失敗總次數：4，危險！
# time cost 0:00:00.308281 s
# 失敗總次數：5，強制重抓proxy！！！！！！！！！！
# usproxy
# http://149.28.120.8:59394
# http://27.72.147.22:40009連接失敗，還剩餘 31 個proxy
# http://165.225.20.238:10062 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.20.238:10062連接失敗，還剩餘 30 個proxy
# http://64.235.204.107:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://12.218.209.130:53281
# http://64.235.204.107:3128連接失敗，還剩餘 29 個proxy
# http://165.225.196.84:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://20.47.108.204:8888
# http://165.225.196.84:10605連接失敗，還剩餘 28 個proxy
# http://198.255.17.202:3129 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# 200
# ---------------
# http://74.207.235.154:8082
# ---------------
# http://154.85.35.235:8888
# http://198.255.17.202:3129連接失敗，還剩餘 27 個proxy
# http://147.161.169.25:10185 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# freeproxylist
# http://27.72.147.22:40009
# http://147.161.169.25:10185連接失敗，還剩餘 26 個proxy
# http://121.146.167.17:4001 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://213.139.32.14:8080
# http://121.146.167.17:4001連接失敗，還剩餘 25 個proxy
# http://165.225.24.48:10012 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.24.48:10012連接失敗，還剩餘 24 個proxy
# http://154.236.179.226:1981 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://103.73.194.2:80
# 200
# ---------------
# http://170.155.5.235:8080
# http://154.236.179.226:1981連接失敗，還剩餘 23 個proxy
# http://115.79.198.18:55443 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://182.72.150.242:8080
# ---------------
# http://149.28.120.8:59394
# ---------------
# http://20.105.253.176:8080
# http://115.79.198.18:55443連接失敗，還剩餘 22 個proxy
# http://165.225.16.39:10029 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.16.39:10029連接失敗，還剩餘 21 個proxy
# http://85.114.112.22:8083 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://12.218.209.130:53281
# http://85.114.112.22:8083連接失敗，還剩餘 20 個proxy
# http://165.225.76.81:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://185.88.37.107:8085
# http://165.225.76.81:10605連接失敗，還剩餘 19 個proxy
# http://95.137.240.30:60030 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://37.61.222.165:1080
# http://95.137.240.30:60030連接失敗，還剩餘 18 個proxy
# http://165.225.194.150:10127 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.194.150:10127連接失敗，還剩餘 17 個proxy
# http://12.3.243.178:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://122.15.131.65:57873
# ---------------
# http://20.47.108.204:8888
# http://12.3.243.178:8080連接失敗，還剩餘 16 個proxy
# http://147.161.166.249:10308 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# ---------------
# http://195.158.24.221:3128
# ---------------
# http://101.32.186.80:60080
# http://147.161.166.249:10308連接失敗，還剩餘 15 個proxy
# http://165.225.218.108:10605 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53644618&tenderCaseNo=CIPAS1204
# http://165.225.218.108:10605連接失敗，還剩餘 14 個proxy
# ...
# http://189.199.106.202:999連接失敗，還剩餘 28 個proxy
# http://41.60.239.94:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://85.25.226.242:5566連接失敗，還剩餘 52 個proxy
# http://41.60.239.94:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://41.60.239.94:8080連接失敗，還剩餘 27 個proxy
# http://182.23.79.162:39902 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://41.60.239.94:8080連接失敗，還剩餘 51 個proxy
# http://37.57.38.133:44299 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://182.23.79.162:39902連接失敗，還剩餘 26 個proxy
# http://103.76.27.34:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://37.57.38.133:44299連接失敗，還剩餘 50 個proxy
# http://150.107.207.137:61954 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://103.76.27.34:8080連接失敗，還剩餘 25 個proxy
# http://8.214.41.50:80 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://150.107.207.137:61954連接失敗，還剩餘 49 個proxy
# http://76.118.227.8:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://8.214.41.50:80連接失敗，還剩餘 24 個proxy
# http://205.201.49.138:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://76.118.227.8:8080連接失敗，還剩餘 48 個proxy
# http://40.136.41.6:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://205.201.49.138:53281連接失敗，還剩餘 23 個proxy
# http://45.231.223.250:999 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://40.136.41.6:8080連接失敗，還剩餘 47 個proxy
# http://12.218.209.130:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://45.231.223.250:999連接失敗，還剩餘 22 個proxy
# http://205.201.49.138:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://12.218.209.130:53281連接失敗，還剩餘 46 個proxy
# http://45.167.95.184:8085 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://45.167.95.184:8085連接失敗，還剩餘 45 個proxy
# http://173.196.205.170:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://173.196.205.170:8080連接失敗，還剩餘 44 個proxy
# http://72.47.152.224:55443 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://205.201.49.138:53281連接失敗，還剩餘 21 個proxy
# http://121.156.109.108:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://72.47.152.224:55443連接失敗，還剩餘 43 個proxy
# http://158.101.98.204:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://121.156.109.108:8080連接失敗，還剩餘 20 個proxy
# http://50.236.203.15:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://158.101.98.204:3128連接失敗，還剩餘 42 個proxy
# http://201.150.116.129:999 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://50.236.203.15:8080連接失敗，還剩餘 19 個proxy
# http://134.119.217.108:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://201.150.116.129:999連接失敗，還剩餘 41 個proxy
# http://82.99.232.18:58689 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://134.119.217.108:1080連接失敗，還剩餘 18 個proxy
# http://109.75.145.152:15392 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://82.99.232.18:58689連接失敗，還剩餘 40 個proxy
# http://161.22.34.123:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://109.75.145.152:15392連接失敗，還剩餘 17 個proxy
# http://195.158.24.221:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://161.22.34.123:8080連接失敗，還剩餘 39 個proxy
# http://122.155.165.191:3128 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://195.158.24.221:3128連接失敗，還剩餘 16 個proxy
# http://203.189.142.168:53281 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://122.155.165.191:3128連接失敗，還剩餘 38 個proxy
# http://182.23.79.162:39902 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://203.189.142.168:53281連接失敗，還剩餘 15 個proxy
# http://176.241.89.244:53583 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://182.23.79.162:39902連接失敗，還剩餘 37 個proxy
# http://85.25.208.212:5566 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://176.241.89.244:53583連接失敗，還剩餘 14 個proxy
# http://177.234.196.187:999 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://85.25.208.212:5566連接失敗，還剩餘 36 個proxy
# http://185.230.4.233:55443 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://177.234.196.187:999連接失敗，還剩餘 13 個proxy
# http://196.216.65.57:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://185.230.4.233:55443連接失敗，還剩餘 35 個proxy
# http://107.178.9.186:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://196.216.65.57:8080連接失敗，還剩餘 12 個proxy
# http://203.189.141.183:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://107.178.9.186:8080連接失敗，還剩餘 34 個proxy
# http://107.178.9.186:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://203.189.141.183:8080連接失敗，還剩餘 11 個proxy
# http://176.36.20.67:61935 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://107.178.9.186:8080連接失敗，還剩餘 33 個proxy
# http://188.138.106.143:5566 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://176.36.20.67:61935連接失敗，還剩餘 10 個proxy
# http://46.99.146.232:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://188.138.106.143:5566連接失敗，還剩餘 32 個proxy
# http://186.208.81.214:3129 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://46.99.146.232:8080連接失敗，還剩餘 9 個proxy
# http://62.75.229.155:5566 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://186.208.81.214:3129連接失敗，還剩餘 31 個proxy
# http://194.44.172.254:23500 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://62.75.229.155:5566連接失敗，還剩餘 8 個proxy
# http://89.165.40.12:8080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://89.165.40.12:8080連接失敗，還剩餘 7 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://194.44.172.254:23500連接失敗，還剩餘 30 個proxy
# http://161.132.122.60:999 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://149.28.120.8:59394連接失敗，還剩餘 6 個proxy
# http://160.16.242.164:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://161.132.122.60:999連接失敗，還剩餘 29 個proxy
# http://31.42.57.1:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://160.16.242.164:3128連接失敗，還剩餘 5 個proxy
# http://85.195.123.196:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://85.195.123.196:1080連接失敗，還剩餘 4 個proxy
# http://85.25.226.242:5566 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://31.42.57.1:8080連接失敗，還剩餘 28 個proxy
# http://170.155.5.235:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://85.25.226.242:5566連接失敗，還剩餘 3 個proxy
# http://122.155.165.191:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://170.155.5.235:8080連接失敗，還剩餘 27 個proxy
# http://189.199.106.202:999 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://122.155.165.191:3128連接失敗，還剩餘 2 個proxy
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://189.199.106.202:999連接失敗，還剩餘 26 個proxy
# http://41.193.206.41:8080 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://51.195.188.28:9090連接失敗，還剩餘 1 個proxy
# http://143.248.55.62:8118 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://41.193.206.41:8080連接失敗，還剩餘 25 個proxy
# http://203.189.142.168:53281 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# proxy 不夠用了，重新獲取
# 失敗總次數：0，危險！
# time cost 0:00:00.792719 s
# http://85.195.123.196:1080 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# http://203.189.142.168:53281連接失敗，還剩餘 24 個proxy
# http://149.28.120.8:59394 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# http://85.195.123.196:1080連接失敗，還剩餘 2 個proxy
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53657013&tenderCaseNo=11103a0102
# 內頁取得點存活
# 準備執行驗證
# http://51.195.188.28:9090
# http://web.pcc.gov.tw/tps/tpam/validate.do?id=nWAOGPDOmcnbX2XnOWZI6bvUF7QZ7B
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&-0.44448001533333176', 'id': 'question'}]
# choose=58n3cp4&choose=3nog2ic&id=nWAOGPDOmcnbX2XnOWZI6bvUF7QZ7B
# 通過驗證
# 執行驗證完成
# 內頁連線數：2
# 3.15.83.3
# progress_final_detail 目前是第 340 項，抓取該細項內頁花費 0:06:38.125923 秒，進度：34.0%，總共有 1000 項
# --------------------
# http://160.16.242.164:3128 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53656342&tenderCaseNo=11104a0103
# http://160.16.242.164:3128連接失敗，還剩餘 1 個proxy
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53656342&tenderCaseNo=11104a0103
# 內頁取得點存活
# 準備執行驗證
# http://51.195.188.28:9090
# http://web.pcc.gov.tw/tps/tpam/validate.do?id=QUebwJnflZE6gzZWR2yvrW9wJPxpsV
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&-0.015705181298581707', 'id': 'question'}]
# http://149.28.120.8:59394連接失敗，還剩餘 23 個proxy
# http://121.146.167.17:4001 準備進入，https://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53741370
# choose=5k4i531&choose=312hfjp&id=QUebwJnflZE6gzZWR2yvrW9wJPxpsV
# 通過驗證
# 執行驗證完成
# 內頁連線數：2
# 3.15.83.3
# progress_final_detail 目前是第 341 項，抓取該細項內頁花費 0:00:06.015439 秒，進度：34.1%，總共有 1000 項
# --------------------
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53661187&tenderCaseNo=11107a0123
# 內頁取得點存活
# 準備執行驗證
# http://51.195.188.28:9090
# http://web.pcc.gov.tw/tps/tpam/validate.do?id=reJLPwzNXFMLmOC95oEtAFeDMU923s
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&0.31948644564764456', 'id': 'question'}]
# choose=4h70kpb&choose=3dhnial&id=reJLPwzNXFMLmOC95oEtAFeDMU923s
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.15.83.3
# progress_final_detail 目前是第 342 項，抓取該細項內頁花費 0:00:01.756595 秒，進度：34.2%，總共有 1000 項
# --------------------
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53640149&tenderCaseNo=11108a0129
# 內頁取得點存活
# 準備執行驗證
# http://51.195.188.28:9090
# http://web.pcc.gov.tw/tps/tpam/validate.do?id=0mbwH18sKE2ozXpmStN2MdDxCE87No
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&0.26876510963470374', 'id': 'question'}]
# choose=3k4ebdf&choose=2n94aco&id=0mbwH18sKE2ozXpmStN2MdDxCE87No
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.15.83.3
# progress_final_detail 目前是第 343 項，抓取該細項內頁花費 0:00:01.894720 秒，進度：34.3%，總共有 1000 項
# --------------------
# http://51.195.188.28:9090 準備進入，https://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=53648407&tenderCaseNo=11111a0164
# 內頁取得點存活
# 準備執行驗證
# http://51.195.188.28:9090
# http://web.pcc.gov.tw/tps/tpam/validate.do?id=ORjXi11C6z8842Pe9TFCKtnXVOSN2h
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&-0.18942709567446187', 'id': 'question'}]
# choose=3p94iio&choose=8m1mcd&id=ORjXi11C6z8842Pe9TFCKtnXVOSN2h
# 驗證失敗
# [{'img_src': 'http://web.pcc.gov.tw/tps/tpam/validate.do?poker=answer&0.0687796904898576', 'id': 'question'}]

# %%
# thread_list=[]
# thread_list_index=[0]
# thread = 4
# for i in range(1,thread):
#     thread_list_index.append(int(len(raw_datas)/thread*i))
# thread_list_index.append(len(raw_datas))
# print(thread_list_index)
# ind=0
# while ind<=thread:
#     ind=ind+1
#     thread_list.append(threading.Thread(target=do_work_detail, kwargs={'raw_datas':raw_datas[thread_list_index[ind]:thread_list_index[ind+1]],'diff_seconds_data':diff_seconds_data,'diff_seconds_conn':diff_seconds_conn,'headers':headers,'db_settings': db_settings},name=f"thread_tenderDeclaration_final_detail_{thread_list_index[ind]}"))

# %%
# import requests as rq
# import ssl
# s=rq.session()
# URKK = "https://web.pcc.gov.tw/pis/main/pis/client/index.do"
# URKK = "https://www.youtube.com/watch?v=HMPVdcU9ZKg"
# ssl._create_default_https_context = ssl._create_unverified_context
# headers = rq.utils.default_headers()
# r = s.get(URKK,verify=False,timeout=(10,20))
# r.close()
# r.request.headers

# %%
db_settings = {
    "host": "60.250.109.71",
    "port": 23306,
    "user": "xuan",
    "password": "Qaz123",
    "db": "tender",
    "charset": "utf8mb4",
    "autocommit":True
}

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "web.pcc.gov.tw",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
     #使用者代理
}
# global waitt
# waitt =False
# proxies = get_ip_from_db("yes",db_settings)
# x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers)
# send_db(x5,"final", db_settings)

# %%
# db_settings = {
#     "host": "60.250.109.71",
#     "port": 23306,
#     "user": "xuan",
#     "password": "Qaz123",
#     "db": "tender",
#     "charset": "utf8mb4",
#     "autocommit":True
# }

# headers = {
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
#     "Accept-Encoding": "gzip, deflate, br", 
#     "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
#     "Host": "web.pcc.gov.tw",  #目標網站 
#     "Sec-Fetch-Dest": "document", 
#     "Sec-Fetch-Mode": "navigate", 
#     "Sec-Fetch-Site": "same-origin", 
#     "Upgrade-Insecure-Requests": "?1", 
#      #使用者代理
# }

# time_start = time.time()
# proxies = get_ip_from_db("yes",db_settings)
# try:
#     x1 = gov_serach_crawler("tenderDeclaration",proxies,db_settings, headers = headers)
#     x2 = gov_serach_crawler("searchAppeal",proxies,db_settings, headers = headers)
#     x3 = gov_serach_crawler("publicRead",proxies,db_settings, headers = headers)
#     time_d = time.time()
# except Exception as ex:
#     print(ex)
#     time_d = time.time()
# time_c = time_d - time_start
# print(time_c)
# send_db(x1, db_settings)
# send_db(x2, db_settings)
# send_db(x3, db_settings)

# %%
# s = rq.session()
# ss = datetime.datetime(2020, 1, 28)
# e = datetime.datetime(2021, 6, 28)
# xx = search_by_date(s,ss, e,'no')
# xxx = date_serach_crawler(s,xx)

# db_settings = {
#     "host": "60.250.109.71",
#     "port": 23306,
#     "user": "xuan",
#     "password": "Qaz123",
#     "db": "tender",
#     "charset": "utf8mb4",
#     "autocommit":True
# }
# data_class="date_search_by_date"
# send_db_2(xxx,data_class, db_settings)
