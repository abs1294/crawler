# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import datetime
import pymysql
from flask import Flask
from flask import jsonify, request
from fake_useragent import UserAgent
import cv2
import numpy as np
import time
from urllib.parse import urlencode
from flask import Flask,request
import threading
import sys
import os
import json
import shutil
import traceback
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()

# %%
#lxml pyinstaller編不動，nuitka不行
#parser = "lxml"
parser = "html.parser"
parser_detail = 'html5lib'

# %%
#創建一個資料夾存放驗證用撲克牌圖片
path = './temp_validate_img'
if os.path.exists(path):
    shutil.rmtree (path)
    os.mkdir(path)
else:
    os.mkdir(path)

# %%
# 從免費代理網站取得代理ip
def get_proxy_ip(isHttps):
    r = rq.get("https://www.us-proxy.org/",verify=False)
    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser)
    trs = soup.select("table.table.table-striped.table-bordered tr")
    metas=[]
    for tr in trs:
        tds = tr.select("td")
        if len(tds) > 6:
            ifScheme = tds[6].text
            ip = tds[0].text
            port = tds[1].text
            anonymity = tds[4].text
            proxy = "%s:%s"%(ip, port)
            meta = {
                'proxyIp': proxy,
                'connect_times':0,
                'successful_connect_times':0,
                'qual_ratio':0,
                'isDelete':False,
              }
            if ifScheme == isHttps:
                if ifScheme == "yes":
                    meta['ishttps'] = True
                    meta['proxyIp'] = "https://" + meta['proxyIp']
                elif ifScheme == "no":
                    meta['ishttps'] = False
                    meta['proxyIp'] = "http://" + meta['proxyIp']
                meta = test_proxy(meta,timeout_sec=3)
                metas.append(meta)
                continue
    return metas

# %%
# 測試 proxy 可用性
def test_proxy(proxy,headers={},timeout_sec=3):
    url = "https://web.pcc.gov.tw/tps/pss/tender.do?method=goSearch&searchMode=common&searchType=basic"
    try:
        if proxy['ishttps'] == True:
            r = rq.get(url, headers = headers,proxies=proxy,verify=False, timeout=timeout_sec)
        elif proxy['ishttps'] == False:
            r = rq.get(url, headers = headers,proxies=proxy,verify=False, timeout=timeout_sec)
        proxy['isValidate']=True
        print(r.status_code)
    except Exception as ex:
        proxy['isValidate']=False
        print(ex)
    return proxy

# %%
# 將取得的代理ip寫入資料庫，此函數也可以更新已寫入資料庫的資料
def send_ip(proxies_pool_https, db_settings,typee="",send_log = True):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    wrong = 0
    try:
        # 建立Connection物件
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor() as cursor:
          #資料表相關操作
            get_max_log_id="select MAX(UID) FROM log"
            # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
            command = "INSERT INTO proxy_ip(log_UID, proxyIp, connect_times, successful_connect_times, qual_ratio, isValidate, ishttps,isDelete)VALUES(%s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),connect_times =values(connect_times),successful_connect_times=values(successful_connect_times),qual_ratio=values(qual_ratio),isValidate = values(isValidate),ishttps=values(ishttps),isDelete=values(isDelete)"
            command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
            # 紀錄開始
            if send_log:
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "start", typee, ""))
            # 取得 log 的 UID
            cursor.execute(get_max_log_id)
            log_UID = str(cursor.fetchone()[0])
            # 組合數據
            if type(proxies_pool_https) == list:
                for proxy in proxies_pool_https:
                    data_combine.append((log_UID, proxy["proxyIp"], proxy["connect_times"], proxy["successful_connect_times"], proxy["qual_ratio"], proxy["isValidate"], proxy["ishttps"], proxy["isDelete"]))  # 注意要用两个括号扩起来
            else:
                data_combine.append((log_UID, proxies_pool_https["proxyIp"], proxies_pool_https["connect_times"], proxies_pool_https["successful_connect_times"], proxies_pool_https["qual_ratio"], proxies_pool_https["isValidate"], proxies_pool_https["ishttps"], proxies_pool_https["isDelete"]))  # 注意要用两个括号扩起来
            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as err:
                print(err)
                wrong = wrong + 1
                print(wrong)
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "wrong" + str(wrong), "", str(err)))
            # 紀錄結束
            if wrong==0 and send_log:
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "finish", "well_completed", ""))
            elif wrong>0 and send_log:
                cursor.execute(command_log, (datetime.datetime.now(), "proxy_ip", "finish", wrong + " records are wrong", ""))
    except Exception as ex:
        print(ex)

    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('time cost', time_c, 's')

# %%
# 從資料庫取出ip，未來有自架proxy的話，可以把proxy放到資料庫內，並設定 mine = 1，這樣就會固定抓這個proxy來用，如果沒有自架proxy的話，就還需要多寫 proxy expire 的方式。
def get_ip_from_db(isHttps,db_settings,qual_ratio=0,connect_times=4):
    try:
        # 建立Connection物件
        data=[]
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor() as cursor:
          #資料表相關操作
            if isHttps=="yes":
                get_ip=f"select * FROM proxy_ip where isHttps = 1 and isDelete is False and ( qual_ratio > {qual_ratio} or ( connect_times < {connect_times} )) or mine = 1"
            elif isHttps=="no":
                get_ip=f"select * FROM proxy_ip where isHttps = 0 and isDelete is False and ( qual_ratio > {qual_ratio} or ( connect_times < {connect_times} )) or mine = 1"
            cursor.execute(get_ip)
            xx = cursor.fetchall()
            des = cursor.description
            
            for i in xx:
                d = {}
                x=0
                for j in des:
                    d[j[0]]=i[x]
                    x=x+1
                data.append(d)
    except Exception as ex:
        print(ex)
    return data

# %%
#撲克牌圖片驗證用算法
def pHash(img):
    # 感知哈希算法
    # 缩放32*32
    img = cv2.resize(img, (32, 32))   # , interpolation=cv2.INTER_CUBIC
 
    # 转换为灰度图
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # 将灰度图转为浮点型，再进行dct变换
    dct = cv2.dct(np.float32(gray))
    # opencv实现的掩码操作
    dct_roi = dct[0:8, 0:8]
 
    hash = []
    avreage = np.mean(dct_roi)
    for i in range(dct_roi.shape[0]):
        for j in range(dct_roi.shape[1]):
            if dct_roi[i, j] > avreage:
                hash.append(1)
            else:
                hash.append(0)
    return hash

# %%
#撲克牌圖片驗證用算法 - 比較
def cmpHash(hash1, hash2):
    # Hash值对比
    # 算法中1和0顺序组合起来的即是图片的指纹hash。顺序不固定，但是比较的时候必须是相同的顺序。
    # 对比两幅图的指纹，计算汉明距离，即两个64位的hash值有多少是不一样的，不同的位数越小，图片越相似
    # 汉明距离：一组二进制数据变成另一组数据所需要的步骤，可以衡量两图的差异，汉明距离越小，则相似度越高。汉明距离为0，即两张图片完全一样
    n = 0
    # hash长度不同则返回-1代表传参出错
    if len(hash1) != len(hash2):
        return -1
    # 遍历判断
    for i in range(len(hash1)):
        # 不相等则n计数+1，n最终为相似度
        if hash1[i] != hash2[i]:
            n = n + 1
    return n

# %%
#進行撲克牌驗證
def validate_ip(s,url,proxies):
    while True:
        #proxies={}
        response = s.get(url, proxies=proxies)
        html_doc = response.text
        soup = BeautifulSoup(html_doc, parser)
        img_url_d = soup.select('form#validateForm img')
        img_url_head = "http://web.pcc.gov.tw/tps/tpam/"
        img_data = []
        img_data.append({'img_src':img_url_head +img_url_d[0]['src'],'id':'question'})
        for j in img_url_d[2:]:
            d = {'img_src':img_url_head +j['src'],'id':j['alt']}
            img_data.append(d)
        right_hash_com =[]
        left_hash_com =[]
        
        path = './temp_validate_img'
        for k in img_data:
            response = s.get(k['img_src'])
            with open(path +'/'+ k['id']+'.jpg', 'wb') as file:
                file.write(response.content)
                file.close() 
            if k ==img_data[0]:
                img = cv2.imread(path +'/'+"question.jpg")
                crop_img = img[0:96, 6:77]
                ret,crop_img = cv2.threshold(crop_img,127,255,cv2.THRESH_BINARY)
                right_imageVar = pHash(crop_img)
                crop_img = img[0:96, 89:160]
                ret,crop_img = cv2.threshold(crop_img,127,255,cv2.THRESH_BINARY)
                left_imageVar = pHash(crop_img)
            image = cv2.imread(path +'/'+k['id']+'.jpg')
            ret,image = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
            right = cmpHash(pHash(image),right_imageVar)
            left = cmpHash(pHash(image),left_imageVar)
            right_hash_com.append(right)
            left_hash_com.append(left)

        right_idx = np.argmin(right_hash_com[1:])
        left_idx = np.argmin(left_hash_com[1:])
        data="choose=" +img_data[right_idx+1]['id']+"&choose="+img_data[left_idx+1]['id']+"&id="+re.match(r'.*id=(.*)', url, flags=0).group(1)
        response = s.post(url,headers = {'Content-Type':'application/x-www-form-urlencoded'}, proxies=proxies,data=data)
        if not re.search("為預防惡意程式針對本系統進行大量查詢致影響系統服務品質",response.text) and response.status_code == 200:
            print("通過驗證")
            break
        else:
            print("驗證失敗")

    return response

# %%
#取出字典某 key 值對應 value，若找無此 key 值，則回傳空字串 
def dicMemberCheck(key, dicObj):
    if key in dicObj:
        return dicObj[key]
    else:
        return ""
# dicMemberCheck('標案案號', {'標案案號':123,'ji3':456})

# %%
# 抓招標、決標內頁資料
def get_tenderDeclaration_detail(href,proxies,refresh_proxies,headers={},typee=""):
    s = rq.session()
    s.keep_alive = False
    user_agent = UserAgent()
    headers["User-Agent"] = user_agent.random
    url_detail = "https://web.pcc.gov.tw/tps/"
    breakdown = "no"
    x=0
    #測試proxy連線可用性
    while True:
        x=x+1
        print(proxies[0]['proxyIp'])
        try:
            proxies[0]['connect_times'] =  proxies[0]['connect_times'] + 1
            proxies[0]['qual_ratio'] = proxies[0]['successful_connect_times'] / proxies[0]['connect_times']
           
            r = s.get(url_detail + href, headers = headers,verify=False,proxies={'https':proxies[0]['proxyIp']}, timeout=10)
            if re.match(r'.*validate.*',r.url, flags=0):
                print("準備執行驗證")
                r = validate_ip(s,r.url,proxies={'https':proxies[0]['proxyIp']})
                print("執行驗證完成")
            if re.search(r'公告日',r.text):
                proxies[0]['successful_connect_times'] =  proxies[0]['successful_connect_times'] + 1
                proxies[0]['qual_ratio'] = proxies[0]['successful_connect_times'] / proxies[0]['connect_times']
                print("內頁連線數："+str(x))
                x = 0
                break
            else:
                pass
        except Exception as ex:
            print(ex)
            if len(proxies) == 1:
                detail_data_html=""
                breakdown = "yes"
                print("proxy 不夠用了")
                refresh_proxies.append(proxies.pop(0))
                break
            #print(proxies[0])
            refresh_proxies.append(proxies.pop(0))
            print("還剩餘 " + str(len(proxies)) +" 個proxy")
            #print(ex)
    detail_data={}
    if breakdown == "yes":
        return detail_data,detail_data_html,proxies,refresh_proxies
    
    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser_detail)
    if typee=="predict":
        #政府採購預告
        detail_data_html = soup.select('div#printRange')[0]
        for i in detail_data_html.select('table'):
            for j in i.select('tr'):
                try:
                    col = j.select('th')[-1].text.strip()
                except:
                    col = j.select('td')[-2].text.strip()
                val = j.select('td')[-1].text.strip()
                detail_data[col]=val

    elif typee =="final":
        detail_data_html = soup.select('div#printArea.main table')[0]
        # 決標公告：無法決標、撤銷公告
        if soup.select('div#printArea.main div#hidden_message_id'):
            detail_data['really_final']=0
            block_data = detail_data_html.select('tr')
            if not block_data[0].text.strip():
                del block_data[0]
            for j in block_data:
                try:
                    try:
                        col = j.select('th')[-1].text.strip()
                    except:
                        col = j.select('td')[-2].text.strip()
                    val = j.select('td')[-1].text.strip()
                except:
                    print("出錯了了了了了")
                    print(r.url)
                    print(j)
                    pass
                detail_data[col]=val
        else:
            #決標公告：正常決標公告
            detail_data['really_final']=1
            for i in range(1,10):
                block_data = detail_data_html.select('tr.award_table_tr_'+str(i))
                if i == 1 and re.search(r'紅色字體表示此次更正公',block_data[0].text):
                    del block_data[0]
                if len(block_data) == 0 :
                    continue
                else:
                    del block_data[0]

                for j in block_data:
                    try:
                        try:
                            col = j.select('th.T11b')[-1].text.strip()
                        except:
                            col = j.select('td.newstop')[-2].text.strip()
                        val = j.select('td')[-1].text.strip()
                    except:
                        print("出錯啦啦啦啦啦")
                        print(r.url)
                        print(j)
                        continue                    
                    detail_data[col]=val
    else:
        #招標公告
        detail_data_html = soup.select('div#print_area table.table_block.tender_table')[0]
        for i in range(1,10):
            block_data = detail_data_html.select('tr.tender_table_tr_'+str(i))
            if len(block_data) == 0 :
                continue
            for j in block_data:
                try:
                    col = j.select('th')[-1].text.strip()
                except:
                    col = j.select('td')[-2].text.strip()
                val = j.select('td')[-1].text.strip()
                detail_data[col]=val
    return detail_data,detail_data_html,proxies,refresh_proxies

# %%
# 抓公開徵求內頁資料
def get_searchAppeal_detail(headers,detail_connect):
    detail_data={}
    detail_data_html=""
    headers['Content-Type']='application/x-www-form-urlencoded'
    url = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/tp.do?method=initialAppealViewVendor&pMenu=common"
    while True
        try:
            r = rq.post(url,data = detail_connect, headers = headers)
            if r.status_code == 200
                break
        except Exception as ex:
            time.sleep(1201)
            print(ex)
            print("get_searchAppeal_detail出錯")

    html_doc = r.text
    if re.search(r'無符合此筆公開徵求廠商條件資料',html_doc):
        print("無符合此筆公開徵求廠商條件資料")
        return detail_data,detail_data_html
    soup = BeautifulSoup(html_doc, parser)
    detail_data_html = soup.select('div#printRange')[0]

    for i in detail_data_html.select('tr'):
        try:
            col = i.select('th')[-1].text.strip()
        except:
            col = i.select('td')[0].text.strip()
        val = i.select('td')[-1].text.strip()
        detail_data[col]=val
    return detail_data,detail_data_html

# %%
# 抓公開閱覽內頁資料
def get_publicRead_detail(detail_connect):
    url_head = "https://web.pcc.gov.tw"
    while True
        try:
            r = rq.get(url_head + detail_connect, headers = headers)
            if r.status_code == 200
                break
        except Exception as ex:
            time.sleep(1201)
            print(ex)
            print("get_publicRead_detail出錯")
    
    html_doc = r.text
    soup = BeautifulSoup(html_doc, parser)
    detail_data_html_1 = soup.select('div#printRange')[0]
    detail_data_html_2 = soup.select('td#page table table table table')[2]
    detail_data={}
    for i in detail_data_html_1.select('tr'):
        col = i.select('th')[-1].text.strip()
        val = i.select('td')[-1].text.strip()
        detail_data[col]=val
    return detail_data,str(detail_data_html_1) +str(detail_data_html_2)

# %%
# current_date = (datetime.date.today()- datetime.timedelta(days=30)).strftime("%Y/%m/%d")
# current_date = str(int(current_date[0:4])-1911) + current_date[4:]
# print(current_date)
# s = rq.session()

# url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance"
# data={'method':'search','searchMethod':'true','searchTarget':'ATM','hid_1':1,'hid_2':1,'hid_3':1,'tenderStatus':'5,6,20,28,8,21,22,29,33,9,23','btnQuery':'查詢','awardAnnounceStartDate':current_date,'awardAnnounceEndDate':current_date}
# r = s.post(url_first,data = data)

# url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex=1"
# r = s.get(url)
# soup = BeautifulSoup(r.text, parser)
# data = soup.select("div#print_area table tr")

# for i in data[1:3]:
#     #機關名稱
#     proposer_name=i.select('td')[1].text.strip()
#     print(proposer_name)
#     #標案案號
#     bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
#     print(bid_no)

# %%
#招標資料塞進DB
def send_db(raw_datas,data_class, db_settings):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    # 建立Connection物件
    conn = pymysql.connect(**db_settings)
    # 建立Cursor物件
    with conn.cursor() as cursor:
      #資料表相關操作
        get_max_log_id="select MAX(UID) FROM log"
        # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
        command = "INSERT INTO gov_purchase(log_UID, proposer_name, bid_no, bid_name, times, typ, clas, date, enddate, budget, ischange, detail_connect, detail_data, detail_data_html, get_data_date, tenderType)VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),get_data_date=values(get_data_date),times =values(times),typ=values(typ),clas=values(clas),date = values(date),enddate=values(enddate),budget=values(budget),ischange=values(ischange),detail_connect=values(detail_connect),detail_data=values(detail_data),detail_data_html=values(detail_data_html)"
        command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
        # 紀錄開始
        cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "start", data_class, ""))
        # 取得 log 的 UID
        cursor.execute(get_max_log_id)
        log_UID = str(cursor.fetchone()[0])
        # 空資料處理
        if len(raw_datas)==0:
            cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "wrong", data_class, "nodata"))
        # 組合數據
        else:
            for raw_data in raw_datas:
                data_combine.append((int(log_UID), raw_data["proposer_name"], raw_data["bid_no"], raw_data["bid_name"], raw_data["times"], raw_data["typ"], raw_data["clas"], raw_data["date"], raw_data["enddate"], raw_data["budget"], raw_data["ischange"], raw_data["detail_connect"], json.dumps(raw_data["detail_data"]), str(raw_data["detail_data_html"]),raw_data["get_data_date"], raw_data["tenderType"]))  # 注意要用两个括号扩起来

            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as ex:
                error_class = ex.__class__.__name__ #取得錯誤類型
                detail = ex.args[0] #取得詳細內容
                cl, exc, tb = sys.exc_info() #取得Call Stack
                lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
                fileName = lastCallStack[0] #取得發生的檔案名稱
                lineNum = lastCallStack[1] #取得發生的行號
                funcName = lastCallStack[2] #取得發生的函數名稱
                errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
                print(errMsg)
                cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "wrong", data_class, error_class + detail + errMsg))
        # 紀錄結束
        cursor.execute(command_log, (datetime.datetime.now(), "gov_purchase", "finish", data_class, str(len(raw_datas)) + " datas was completed"))


    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('time cost', time_c, 's')

# %%
def gov_serach_crawler(url_type,proxies,db_settings,headers={},cookies={},account="",password="",start_page=1):
    global waitt
    current_date = (datetime.date.today()- datetime.timedelta(days=0)).strftime("%Y/%m/%d")
    current_date = str(int(current_date[0:4])-1911) + current_date[4:]
    print("爬取日期："+current_date)
    s = rq.session()
    s.keep_alive = False
    user_agent = UserAgent()
    headers["User-Agent"] = user_agent.random
    if url_type == "tenderDeclaration":
        datarow_of_end = -1
        count_per_page = 100
        url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex="
        global progress_tenderDeclaration
    elif url_type == "searchAppeal":  
        datarow_of_end = -1
        count_per_page = 10
        url = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex="
        url_first = "https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchAppealVendor.do?pMenu=common"
        data={'method':'searchVendor','isVendor':'Y','startDateStr':current_date,'endDateStr':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_searchAppeal
    elif url_type == "publicRead":
        datarow_of_end = -2
        count_per_page = 10
        url = "https://web.pcc.gov.tw/tps/tps/tp/main/pms/tps/tp/commonPublicReadFormListPageControl.do?__PageBase=0&__PageIndex="
        url_first = "https://web.pcc.gov.tw/tps/tps/tp/main/pms/tps/tp/QueryPublicReadData.do?pMenu=common"
        data={'method':'queryPublicReadData','isVendor':'Y','startDateStr':current_date,'endDateStr':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_publicRead
    elif url_type == "predict":
        datarow_of_end = -1
        count_per_page = 10
        login_url = "https://web.pcc.gov.tw/pis/main/sso/login.jsp"
        login_data = {"VTI-GROUP":0,"id":account,"password":password}
        #login_data = urlencode(login_data)
        r = s.post(login_url, headers = headers, cookies = cookies ,data = login_data)
        print(r.text)
        url = ""
        url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic"
        data={'method':'searchPredict','searchMethod':'true','hid_1':1,'isSpdt':'N','btnQuery':'查詢','tenderType':'predict','tenderWay':'各式預定招標方式','tenderDateRadio':'on','tenderStartDateStr':current_date,'tenderEndDateStr':current_date,'tenderStartDate':current_date,'tenderEndDate':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_predict
    elif url_type == "final":  
        datarow_of_end = -1
        count_per_page = 100
        url = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex="
        url_first = "https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance"
        data={'method':'search','searchMethod':'true','searchTarget':'ATM','hid_1':1,'hid_2':1,'hid_3':1,'tenderStatus':'5,6,20,28,8,21,22,29,33,9,23','btnQuery':'查詢','awardAnnounceStartDate':current_date,'awardAnnounceEndDate':current_date}
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖")
                time.sleep(60)
        while True:
            try:
                r = s.post(url_first, headers = headers, cookies = cookies ,data = data)
                if r.status_code<300:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖")
                print(ex)
                waitt = True
                time.sleep(1200)
        global progress_final
    else:
        raise Exception("url_type is wrong") 
        
    refresh_proxies=[]
    raw_datas=[]
    for ii in range(start_page,2000):
        #s = rq.session()
        while waitt:
                print(url_type + "暫停休息 60秒 一下，有執行緒被鎖_phase2")
                time.sleep(60)
        while True:
            try:
                r = s.get(url + str(ii), headers = headers)
                if r.status_code == 200:
                    waitt = False
                    break
            except Exception as ex: 
                print(url_type + "暫停休息 1200秒 一下，本機 IP 被鎖_phase2")
                print(ex)
                waitt = True
                time.sleep(1200)
        print("頁面前往："+str(r.url))
        html_doc = r.text
        if re.search(r'無符合條件資料',html_doc):
            print("無符合條件資料")
            break
        soup = BeautifulSoup(html_doc, parser)
        
        time_start = datetime.datetime.now()
        if url_type == "tenderDeclaration":
            data = soup.select('div#print_area table tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxx = 0
            for i in data[1:datarow_of_end]:
                t_s = datetime.datetime.now()
                xxx = xxx + 1
                progress_tenderDeclaration = "這是第 " + str(ii) + " 頁，的第 "+ str(xxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxx)/all_data*100) + " %。"
                print(progress_tenderDeclaration)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[1].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
                # 是否更正
                if i.select('td')[2].select('font'):
                    ischange=1
                else:
                    ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[2].select('a')[0].text.strip()
                # 傳輸次數
                times=i.select('td')[3].text.strip()
                # 招標方式
                typ=i.select('td')[4].text.strip()
                # 採購性質
                clas=i.select('td')[5].text.strip()
                # 公告日期
                date=i.select('td')[6].text.strip()
                # 截止投標
                enddate=i.select('td')[7].text.strip()
                # 預算金額
                budget=i.select('td')[8].text.strip()
                # 內文連結
                detail_connect = i.select('td')[2].select('a')[0]['href'][3:]
                while True:
                    if proxies == []:
                        send_ip(refresh_proxies, db_settings,send_log=False)
                        refresh_proxies=[]
                        proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.1)
                        if proxies == []:
                            xx = get_proxy_ip("yes")
                            send_ip(xx, db_settings)
                            proxies = get_ip_from_db("yes",db_settings)
                        #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
                    (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
                    str_detail_data_html=str(detail_data_html)
                    if len(detail_data)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
                        print(detail_data['機關代碼'])
                        break
                t_e = datetime.datetime.now()
                time_se= t_e - t_s
                print('此細項已抓取完成，總耗時：', time_se, 's')
                print("------------------------------------")
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"tenderDeclaration"})
        elif url_type == "searchAppeal":
            data = soup.select('center table:nth-child(1) tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxx = 0
            for i in data[17:datarow_of_end]:
                xxxx = xxxx + 1
                progress_searchAppeal = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxx)/all_data*100) + " %。"
                print(progress_searchAppeal)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=i.select('td')[2].text.strip()
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[3].text.strip()
                # 傳輸次數 (公告次數)
                times=i.select('td')[4].text.strip()
                # 招標方式
                typ=""
                # 採購性質
                clas=""
                # 公告日期
                date=re.match(r'(.*)\s*－\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(1).strip()
                # 截止投標
                enddate=re.match(r'(.*)\s*－\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(2).strip()
                # 預算金額
                budget=""
                # 內文連結
                detail_connect = {}
                detail_connects = i.select('td.T12 input')
                for ij in detail_connects:
                    try:
                        detail_connect[ij['id']]=ij['value']
                    except:
                        break
                detail_connect=urlencode(detail_connect)
                (detail_data,detail_data_html) = get_searchAppeal_detail(headers,detail_connect)
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_data':detail_data, 'detail_connect':detail_connect,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"searchAppeal"})
        elif url_type == "publicRead":
            data = soup.select('td#page table:nth-child(3) tr')
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxx=0
            for i in data[15:datarow_of_end]:
                xxxxx = xxxxx + 1
                progress_publicRead = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " +str(((ii-1)*count_per_page+xxxxx)/all_data*100) + " %。"
                print(progress_publicRead)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                # 項次
                no=i.select('td')[0].text.strip()
                # 機關名稱
                proposer_name=i.select('td')[1].text.strip()
                # 標案案號
                bid_no=i.select('td')[2].text.strip()
                # 內文連結
                detail_connect = i.select('td')[2].select('a')[0]['href']
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[3].text.strip()
                # 傳輸次數 (公告次數)
                times=i.select('td')[4].text.strip()
                # 招標方式
                typ=""
                # 採購性質
                clas=""
                # 公告日期
                date=re.match(r'(.*)\s*─\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(1).strip()
                # 截止投標
                enddate=re.match(r'(.*)\s*─\s*(.*)', i.select('td')[5].text.strip(), flags=0).group(2).strip()
                # 預算金額
                budget=""
                (detail_data,detail_data_html)=get_publicRead_detail(detail_connect)
                detail_data=""
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"publicRead"})
        elif url_type == "predict" : 
            data = soup.select("div#print_area table tr")
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxx = 0
            for i in data[1:datarow_of_end]:
                xxxxx = xxxxx + 1
                progress_predict = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxxx)/all_data*100) + " %。"
                print(progress_predict)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[3].text.strip()
                #標案案號
                bid_no=i.select('td')[1].text.strip()
                # 是否更正
                ischange=0  
                # 標案名稱    
                bid_name=i.select('td')[2].select('a')[0].text.strip()
                # 傳輸次數
                times=""
                # 招標方式
                typ=i.select('td')[4].text.strip()
                # 採購性質
                clas=""
                # 公告日期
                date=i.select('td')[5].text.strip()
                # 截止投標
                enddate=""
                # 預算金額
                budget=""
                # 內文連結
                detail_connect = i.select('td')[6].select('a')[0]['href'][5:]
                print(detail_connect)
                while True:
                    if proxies == []:
                        send_ip(refresh_proxies, db_settings,send_log=False)
                        refresh_proxies=[]
                        proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.1)
                        if proxies == []:
                            xx = get_proxy_ip("yes")
                            send_ip(xx, db_settings)
                            proxies = get_ip_from_db("yes",db_settings)
                        #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
                    (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers,typee="predict") 
                    str_detail_data_html=str(detail_data_html)
                    if len(proxies)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
                        print("predict detail 通過")
                        if re.search(r'勞務類',str_detail_data_html):
                            clas=clas+'勞務類'
                        if re.search(r'工程類',str_detail_data_html):
                            clas=clas+'工程類'
                        if re.search(r'財物類',str_detail_data_html):
                            clas=clas+'財物類'
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"predict"})
        elif url_type == "final" : 
            print(soup)
            data = soup.select("div#print_area table tr")
            print(data)
            all_data = int(data[datarow_of_end].select('span')[-1].text)
            xxxxxx = 0
            for i in data[1:datarow_of_end]:
                t_s = datetime.datetime.now()
                xxxxxx = xxxxxx + 1
                progress_final = "這是第 " + str(ii) +" 頁，的第 "+ str(xxxxxx) + " 項，總共有 " + str(all_data) + " 項，目前進度是 " + str(((ii-1)*count_per_page+xxxxxx)/all_data*100) + " %。"
                print(progress_final)
                # 取得資料日期
                get_data_date = datetime.datetime.now().date()
                #項次
                no=i.select('td')[0].text.strip()
                #機關名稱
                proposer_name=i.select('td')[1].text.strip()
                #標案案號
                bid_no=re.match(r'(.*)\r\n\t', i.select('td')[2].text.strip(), flags=0).group(1)
                # 是否更正
                if i.select('td')[2].select('font'):
                    ischange=1
                else:
                    ischange=0   
                # 標案名稱    
                bid_name=i.select('td')[2].select('u')[0].text.strip()
                # 傳輸次數
                times=""
                # 這樣可以從內頁資料抓傳輸次數： 上面有定義 dicMemberCheck 可以吐出字典裡對應key的value
#                 if detail_data['ischange'] ==0 and not re.search(r'限制性招標',detail_data['招標方式']) and not re.search(r'選擇性招標',detail_data['招標方式']):
#                     print(detail_data['新增公告傳輸次數'])
                
                # 招標方式
                typ=i.select('td')[3].text.strip()
                # 採購性質
                clas=i.select('td')[4].text.strip()
                # 公告日期
                date=i.select('td')[5].text.strip()
                # 截止投標
                enddate=""
                # 預算金額
                budget=i.select('td')[6].text.strip()
                # 內文連結
                detail_connect = i.select('td')[2].select('a')[0]['href'][3:]
                print(detail_connect)
                while True:
                    if proxies == []:
                        send_ip(refresh_proxies, db_settings,send_log=False)
                        refresh_proxies=[]
                        proxies = get_ip_from_db("yes",db_settings,qual_ratio=0.1)
                        if proxies == []:
                            xx = get_proxy_ip("yes")
                            send_ip(xx, db_settings)
                            proxies = get_ip_from_db("yes",db_settings)
                        #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers) 
                    (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers,typee="final") 
                    str_detail_data_html=str(detail_data_html)
                    if len(detail_data)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
                        print(detail_data['機關代碼'])
                        break
                t_e = datetime.datetime.now()
                time_se= t_e - t_s
                print('此細項已抓取完成，總耗時：', time_se, 's')
                print("------------------------------------")
                raw_datas.append({'no': no,'proposer_name': proposer_name,'bid_no': bid_no,'bid_name': bid_name,'times': times,'typ': typ,'clas': clas,'date': date,'enddate': enddate,'budget': budget,'ischange': ischange,'detail_connect':detail_connect,'detail_data':detail_data,'detail_data_html':detail_data_html,'get_data_date':get_data_date,'tenderType':"final"})

        time_end = datetime.datetime.now()
        time_c= time_end - time_start
        print('此分頁抓取總耗時：', time_c, 's')
        #all_data = int(data[datarow_of_end].select('span')[-1].text)
        print(all_data)
        print(ii*count_per_page)
        if ii*count_per_page >= all_data:
            if url_type == "tenderDeclaration":
                del progress_tenderDeclaration
            elif url_type == "searchAppeal":
                del progress_searchAppeal
            elif url_type == "publicRead":    
                del progress_publicRead
            elif url_type == "predict":    
                del progress_predict
            elif url_type == "final":    
                del progress_final
            break
    return raw_datas

# %%
# s=rq.session()
# user_agent = UserAgent()
# headers={}
# headers["User-Agent"] = user_agent.random
# r=s.get("https://web.pcc.gov.tw/pis/main/pis/client/index.do", headers = headers)
# r = s.get("https://web.pcc.gov.tw/prkms/prms-viewDailyTenderListClient.do?root=tps", headers = headers)
# html_doc = r.text
# if r.status_code == 500 or re.search(r'The server encountered an internal error or misconfiguration and was unable to complete your request',html_doc):
#     print("打不進去header頁")

# %%
def search_by_date(s,start_date, end_date,if_publish,headers):
    r = s.get("https://web.pcc.gov.tw/prkms/prms-viewDailyTenderListClient.do?root=tps",headers=headers)
    html_doc = r.text
    if r.status_code == 500 or re.search(r'The server encountered an internal error or misconfiguration and was unable to complete your request',html_doc):
        raise Exception("打不進去header頁") 
        return ""
    soup = BeautifulSoup(html_doc, parser)
    publishs_href=[]
    publishs_date=[]
    not_publishs_href=[]
    not_publishs_date=[]
    left = soup.select('td#page table tr td:nth-child(2) li a')
    right = soup.select('td#page table tr td:nth-child(4) li a')
    for i in left:
        publishs_href.append(i['href'])
        y=str(int(re.match(r'(.*)年(.*)月(.*)日',i['title']).group(1))+1911)
        m=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(2)
        d=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(3)
        ymd = datetime.datetime.strptime("-".join([y,m,d]), "%Y-%m-%d")
        publishs_date.append(ymd)
    for i in right:
        not_publishs_href.append(i['href'])
        y=str(int(re.match(r'(.*)年(.*)月(.*)日',i['title']).group(1))+1911)
        m=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(2)
        d=re.match(r'(.*)年(.*)月(.*)日',i['title']).group(3)
        ymd = datetime.datetime.strptime("-".join([y,m,d]), "%Y-%m-%d")
        not_publishs_date.append(ymd)
    for i in publishs_date:
        publishs_start_date_index = publishs_date.index(i)
        if i < start_date:
            break
    for i in not_publishs_date:
        not_publishs_start_date_index = not_publishs_date.index(i)
        if i < start_date:
            break
    for i in publishs_date:
        publishs_end_date_index = publishs_date.index(i)
        if i <= end_date:
            break
    for i in not_publishs_date:
        not_publishs_end_date_index = not_publishs_date.index(i)
        if i <= end_date:
            break

    if not_publishs_start_date_index<not_publishs_end_date_index:
        raise Exception("開始日期不可大於結束日期")
    if publishs_start_date_index<publishs_end_date_index:
        raise Exception("開始日期不可大於結束日期")
    if start_date > not_publishs_date[0] or start_date > publishs_date[0]:
        raise Exception("無資料可爬，初始日期大於網站最新日期")
    
    total_hrefs=[]
    if if_publish=="all" or if_publish=="yes":
        for i in range(0,len(publishs_href[publishs_end_date_index:publishs_start_date_index])):
            total_href={'href':publishs_href[publishs_end_date_index+i],'date':publishs_date[publishs_end_date_index+i],'ispublish':1}
            total_hrefs.append(total_href)
    if if_publish=="all" or if_publish=="no":
        for i in range(0,len(not_publishs_href[not_publishs_end_date_index:not_publishs_start_date_index])):
            total_href={'href':not_publishs_href[not_publishs_end_date_index+i],'date':not_publishs_date[not_publishs_end_date_index+i],'ispublish':0}
            total_hrefs.append(total_href)
    return total_hrefs

# %%
def date_serach_crawler(s,search_date,headers):
    url_head = "https://web.pcc.gov.tw/prkms/"
    len_search_date=len(search_date)
    global progress_date_serach
    if len_search_date==0:
        return
    xxxxxx = 0
    for i in search_date:
        xxxxxx = xxxxxx + 1
        progress_date_serach = "這是第 " + str(xxxxxx) + " 個，總共有 " + str(len_search_date) + " 個要爬"
        print(search_date.index(i))
        r = s.get(url_head + i['href'], headers=headers, timeout=10)
        html_doc = r.text
        soup = BeautifulSoup(html_doc, parser)
        i['detail_data'] = soup.select('td#page table table table table tr td')[0]
    del progress_date_serach
    return search_date

# %%
def send_db_2(raw_datas,data_class, db_settings):
    time_start = datetime.datetime.now() #開始計時
    data_combine=[]
    try:
        # 建立Connection物件
        conn = pymysql.connect(**db_settings)
        # 建立Cursor物件
        with conn.cursor() as cursor:
          #資料表相關操作
            get_max_log_id="select MAX(UID) FROM log"
            # % 操作符只能直接用於字串(‘123’)，列表([1,2,3])、元組
            command = "INSERT INTO date_search_by_date(log_UID, date, ispublish, upper, lower, href)VALUES(%s, %s, %s, %s, %s, %s) on DUPLICATE KEY UPDATE log_UID = values(log_UID),date=values(date),ispublish =values(ispublish),upper=values(upper),lower=values(lower),href = values(href)"
            command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"
            # 紀錄開始
            cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "start", data_class, ""))
            # 取得 log 的 UID
            cursor.execute(get_max_log_id)
            log_UID = str(cursor.fetchone()[0])
            # 組合數據
            for raw_data in raw_datas:
                data_combine.append((int(log_UID), raw_data["date"], raw_data["ispublish"], "", raw_data["detail_data"], raw_data["href"]))  # 注意要用两个括号扩起来

            # 執行
            try:
                cursor.executemany(command, data_combine)
            except Exception as ex:
                print(ex)
                error_class = ex.__class__.__name__ #取得錯誤類型
                detail = ex.args[0] #取得詳細內容
                cl, exc, tb = sys.exc_info() #取得Call Stack
                lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
                fileName = lastCallStack[0] #取得發生的檔案名稱
                lineNum = lastCallStack[1] #取得發生的行號
                funcName = lastCallStack[2] #取得發生的函數名稱
                errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
                print(errMsg)
                cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "wrong", data_class, error_class + detail + errMsg))
            # 紀錄結束
            cursor.execute(command_log, (datetime.datetime.now(), "date_search_by_date", "finish", data_class, str(len(raw_datas)) + " datas was completed"))

    except Exception as ex:
        print(ex)

    time_end = datetime.datetime.now()    #結束計時
    time_c= time_end - time_start   #執行所花時間
    print('time cost', time_c, 's')

# %%
db_settings = {
    "host": "60.250.109.71",
    "port": 23306,
    "user": "xuan",
    "password": "Qaz123",
    "db": "tender",
    "charset": "utf8mb4",
    "autocommit":True
}
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "web.pcc.gov.tw",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
     #使用者代理
}

# %%
# proxies = get_ip_from_db("yes",db_settings)
# # x4 = gov_serach_crawler("predict",proxies,db_settings, headers = headers)
# # send_db(x4,"predict", db_settings)
# x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers)
# send_db(x5,"final", db_settings)

# %%
# global waitt
# waitt = False
# proxies = get_ip_from_db("yes",db_settings)
# x3 = gov_serach_crawler("final",proxies,db_settings, headers = headers)

# %%
#雙重 thread
my_host=input("請輸入主機ip ( 若要從本機啟動，可輸入127.0.0.1 )：")
#account=input("請輸入政府採購網帳號，目前請隨便輸入我還沒做：")
#password=input("請輸入政府採購網密碼，目前請隨便輸入我還沒做：")
my_host=str(my_host)
app = Flask(__name__)
# db_settings = {
#     "host": "127.0.0.1",
#     "port": 3306,
#     "user": "root",
#     "password": "As123459362",
#     "db": "pttcrawler",
#     "charset": "utf8",
#     "autocommit":True
# }
db_settings = {
    "host": "60.250.109.71",
    "port": 23306,
    "user": "xuan",
    "password": "Qaz123",
    "db": "tender",
    "charset": "utf8mb4",
    "autocommit":True
}
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "Host": "web.pcc.gov.tw",  #目標網站 
    "Sec-Fetch-Dest": "document", 
    "Sec-Fetch-Mode": "navigate", 
    "Sec-Fetch-Site": "same-origin", 
    "Upgrade-Insecure-Requests": "?1", 
     #使用者代理
}
command_log = "INSERT INTO log(datetime, task, status, record_des, errmsg) VALUES(%s, %s, %s, %s, %s)"

@app.route('/', methods=['GET'])
def test():
#     ip = request.remote_addr
#     print(ip)
#     conn = pymysql.connect(**db_settings)
#     # 建立Cursor物件
#     with conn.cursor() as cursor:
#         if_finish_command="SELECT status FROM log where task ='api_process_basic' order by UID DESC"
#         cursor.execute(if_finish_command)
#         if cursor.fetchone() is None:
#             cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "initial", "", ""))
#         cursor.execute(if_finish_command)
#         if_finish = str(cursor.fetchone()[0])
#     if re.search(r'finish', if_finish, flags=0) or if_finish == "initial":
#         wording ='<p>恭喜!網站建置成功!</p><p>api說明：</p><p>1.&nbsp;/thread：查看當前執行緒狀態，無須參數 (get請求)</p><p>2.&nbsp;/start_task_all：開始執行爬蟲，若要強制重啟，參數帶 restart = 1 (get請求)</p><p>3.&nbsp;/date_serach_crawler：公告日期執行爬蟲，參數帶 start_date、end_date、if_publish (get請求)<br />start_date、end_date =&gt; 以字串型態帶日期，ex:20210125，if_publish =&gt; 以字串形式帶 all | yes | no </p><p>http://127.0.0.1:5000/date_serach_crawler?start_date=20210128&end_date=20210204&if_publish=yes</p><p>4.&nbsp;/progress：查看當前執行緒進度，無須參數 (get請求)</p><p>5. /proxy : 從免費代理網站抓取proxy進資料庫，無須參數 (get請求)'
#         status_code = 200
#     else:
#         wording ="I am busy now, please wait"
#         status_code = 500
        
    wording ='<p>恭喜!網站建置成功!</p><p>api說明：</p><p>1.&nbsp;/thread：查看當前執行緒狀態，無須參數 (get請求)</p><p>2.&nbsp;/start_task_all：開始執行爬蟲，若要強制重啟，參數帶 restart = 1；若要設定爬取的初始頁面，參數帶 start_page=[x,x,x,x] (get請求)</p><p>http://127.0.0.1:5000/start_task_all?restart=1&start_page=[1,1,1,1]</p><p>3.&nbsp;/date_serach_crawler：公告日期執行爬蟲，參數帶 start_date、end_date、if_publish (get請求)<br />start_date、end_date =&gt; 以字串型態帶日期，ex:20210125，if_publish =&gt; 以字串形式帶 all | yes | no </p><p>http://127.0.0.1:5000/date_serach_crawler?start_date=20210128&end_date=20210204&if_publish=yes</p><p>4.&nbsp;/progress：查看當前執行緒進度，無須參數 (get請求)</p><p>5. /proxy : 從免費代理網站抓取proxy進資料庫，無須參數 (get請求)'
    status_code = 200

    return wording,status_code

@app.route('/thread', methods=['GET'])
def thread_status():
    wording =""
    wording2 =""
    wording3 =""
    wording4 =""
    code =200
    print(str(threading.enumerate()))
    try:
        if str(threading.enumerate()).find("thread_tenderDeclaration_searchAppeal_publicRead") >=0:
            wording = "當前正在執行 thread_tenderDeclaration_searchAppeal_publicRead 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_date_serach_crawler") >=0:
            wording2 = "當前正在執行 thread_date_serach_crawler 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_proxy_crawler") >=0:
            wording3 = "當前正在執行 thread_proxy_crawler 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_final_datesearch") >=0:
            wording4 = "當前正在執行 thread_final_datesearch 執行緒"
            code = 500
    except Exception as ex:
        print(ex)
        pass
    return wording + " " + wording2 + " " + wording3 + " " + wording4,code
        
@app.route('/proxy', methods=['GET'])
def proxy():
    def proxyy():
        p_yes=get_proxy_ip("yes")
        p_no=get_proxy_ip("no")
        send_ip(p_yes, db_settings ,"only https")
        send_ip(p_no, db_settings,"only http")
        
    try:
        if str(threading.enumerate()).find("thread_proxy_crawler") >=0:
            return "已經在爬 proxy 了，別吵",500
    except Exception as ex:
        print(ex)
        pass    
    
    thread_proxy_crawler = threading.Thread(target=proxyy, kwargs={},name="thread_proxy_crawler")
    thread_proxy_crawler.start()
    return "started",200
    
@app.route('/start_task_all', methods=['GET'])
def start_task_all():
    if request.args:
        dd= request.args.to_dict()
        if set(['start_page','restart']) >= set(dd.keys()):
            print("傳參成功")
        else:
            return "傳參失敗，參數只允許"+' start_page '+'restart ',500
    def do_work(start_page,db_settings,headers):
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", str(ip) + " start", "tenderDeclaration_searchAppeal_publicRead", f"tenderDeclaration 從第 {start_page[0]} 頁開始爬，searchAppeal 從第 {start_page[1]} 頁開始爬，publicRead 從第 {start_page[2]} 頁開始爬"))
        time_start = time.time()
        proxies = get_ip_from_db("yes",db_settings)
        
        try:
            x1 = gov_serach_crawler("tenderDeclaration",proxies,db_settings, headers = headers,start_page = int(start_page[0]))
            send_db(x1,"tenderDeclaration", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "wrong", "tenderDeclaration", errMsg))
        
        try:
            x2 = gov_serach_crawler("searchAppeal",proxies,db_settings, headers = headers,start_page = int(start_page[1]))
            send_db(x2,"searchAppeal", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "wrong", "searchAppeal", errMsg))
        
        try:
            x3 = gov_serach_crawler("publicRead",proxies,db_settings, headers = headers,start_page = int(start_page[3]))
            send_db(x3,"publicRead", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "wrong", "publicRead", errMsg))
        
#         try:
#             x4 = gov_serach_crawler("predict",proxies,db_settings, headers = headers, account=account,password=password)
#             send_db(x4,"predict", db_settings)
#         except Exception as ex:
#             print(ex)
#             error_class = ex.__class__.__name__ #取得錯誤類型
#             detail = ex.args[0] #取得詳細內容
#             cl, exc, tb = sys.exc_info() #取得Call Stack
#             lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
#             fileName = lastCallStack[0] #取得發生的檔案名稱
#             lineNum = lastCallStack[1] #取得發生的行號
#             funcName = lastCallStack[2] #取得發生的函數名稱
#             errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
#             print(errMsg)
#             conn = pymysql.connect(**db_settings)
#             with conn.cursor() as cursor:
#                 cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "wrong", "predict", errMsg))
        time_d = time.time()
        time_c = time_d - time_start
        print(time_c)
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", str(ip) + " finish", "tenderDeclaration_searchAppeal_publicRead", ""))
            
    def do_work_final(start_page,db_settings,headers):
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", str(ip) + " start", "final_datesearch", f"final 從第 {start_page[3]} 頁開始爬，datesearch爬當日"))
        time_start = time.time()
        proxies = get_ip_from_db("yes",db_settings)
        try:
            x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers,start_page = int(start_page[3]))
            send_db(x5,"final", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "wrong", "final", errMsg))

        try:
            s = rq.session()
            xx = search_by_date(s,datetime.datetime.today()- datetime.timedelta(days=1), datetime.datetime.today(),"all", headers = headers)
            print(xx)
            xxx = date_serach_crawler(s,xx,headers)
            send_db_2(xxx,"date_search_by_date", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "wrong", "date_serach_crawler", error_class + detail + errMsg))
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "finish", "date_serach_crawler", ""))
      
        time_d = time.time()
        time_c = time_d - time_start
        print(time_c)
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", str(ip) + " finish", "final_datesearch", ""))
    
    #驗證用圖片資料夾
    path = './temp_validate_img'
    if os.path.exists(path):
        shutil.rmtree (path)
        os.mkdir(path)
    else:
        os.mkdir(path)
    #資料庫log檢查
    ip = request.remote_addr
    conn = pymysql.connect(**db_settings)
    if_finish_command="SELECT status FROM log where task ='api_process_basic' order by UID DESC"
    with conn.cursor() as cursor:
        cursor.execute(if_finish_command)
        if cursor.fetchone() is None:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_basic", "initial", "", ""))
        cursor.execute(if_finish_command)
        if_finish = str(cursor.fetchone()[0])
    
    # 不判斷資料庫log強制重啟
    if re.search(r'finish', if_finish, flags=0) or re.search(r'wrong', if_finish, flags=0) or if_finish == "initial":
        pass
    elif "restart" in request.args:
        try:
            if request.args.get("restart")==1:
                pass
        except:
            return "若想要重啟爬蟲，參數要帶restart，值請放 1 "
    else:
        return "資料庫未收到結束log，可帶參數 restart=1 忽略資料庫log判斷",500
    #執行序之間任一ip被鎖block全部
    global waitt
    waitt = False
    
    #設定起始頁面
    start_page=[1,1,1,1]
    if 'start_page' in request.args:
        try:
            start_page = eval(request.args.get("start_page"))
            if len(start_page) !=4:
                return "start_page 參數長度不足 4，無須爬取的項目可輸入1999！"
            else:
                print("頁數參數接收成功")
        except:
            return "若想要設定爬取的初始頁數，參數要帶 start_page，以 list 的方式放值=>[招標公告頁數,公開徵求頁數,公開閱覽頁數,決標公告頁數]，ex: start_page=[1,1,1,1] "
    print(f"tenderDeclaration 從第 {start_page[0]} 頁開始爬取")
    print(f"searchAppeal 從第 {start_page[1]} 頁開始爬取")
    print(f"publicRead 從第 {start_page[2]} 頁開始爬取")
    print(f"final 從第 {start_page[3]} 頁開始爬取")
    
    try:
        if str(threading.enumerate()).find("thread_tenderDeclaration_searchAppeal_publicRead") >= 0 :
            wording0="thread_tenderDeclaration_searchAppeal_publicRead 執行緒正在執行；"
        else:
            thread_tenderDeclaration_searchAppeal_publicRead = threading.Thread(target=do_work, kwargs={'start_page':start_page,'db_settings': db_settings,'headers': headers},name="thread_tenderDeclaration_searchAppeal_publicRead")
            thread_tenderDeclaration_searchAppeal_publicRead.start()
            wording0="啟動 thread_tenderDeclaration_searchAppeal_publicRead 執行緒；"
    except Exception as ex:
        print(ex)
        pass
    
    try:
        if str(threading.enumerate()).find("thread_final_datesearch") >= 0 :
            wording1="thread_final_datesearch 執行緒正在執行"
        else:
            thread_final_datesearch = threading.Thread(target=do_work_final, kwargs={'start_page':start_page,'db_settings': db_settings,'headers': headers},name="thread_final_datesearch")
            thread_final_datesearch.start()
            wording1="啟動 thread_final_datesearch 執行緒"
    except Exception as ex:
        print(ex)
        pass

    return wording0+wording1,200

@app.route('/progress', methods=['GET'])
def get_progress():
    wording={}
    try:
        wording['tenderDeclaration'] = progress_tenderDeclaration
    except:
        wording['tenderDeclaration'] = "tenderDeclaration 任務未啟動"
        
    try:
        wording['searchAppeal'] = progress_searchAppeal
    except:
        wording['searchAppeal'] = "searchAppeal 任務未啟動"
        
    try:
        wording['publicRead'] = progress_publicRead
    except:
        wording['publicRead'] = "publicRead 任務未啟動"
        
    try:
        wording['predict'] = progress_predict
    except:
        wording['predict'] = "predict 任務未啟動"
    
    try:
        wording['final'] = progress_final
    except:
        wording['final'] = "final 任務未啟動"
        
    try:
        wording['date_serach'] = progress_date_serach
    except:
        wording['date_serach'] = "date_serach 任務未啟動"
        
    return wording,200

# @app.route('/test', methods=['GET'])
# def tesddt():
#     if request.args:
#         dd= request.args.to_dict()
#         if set(['start_date','end_date','']) >= set(dd.keys()):
#             return "傳參成功",200
#         else:
#             return "傳參失敗",200


@app.route('/date_serach_crawler', methods=['GET'])
def date_serach():
    if request.args:
        dd= request.args.to_dict()
        if set(['start_date','end_date','if_publish']) >= set(dd.keys()):
            print("傳參成功")
        else:
            return "傳參失敗，參數只允許"+' start_date '+'end_date '+'if_publish',500
    user_agent = UserAgent()
    headers["User-Agent"] = user_agent.random
    def do_work_2(start_date,end_date,if_publish,db_settings,headers):
        s = rq.session()
        try:
            xx = search_by_date(s,start_date, end_date,if_publish,headers)
            print(xx)
            xxx = date_serach_crawler(s,xx,headers)
            send_db_2(xxx,"date_search_by_date", db_settings)
        except Exception as ex:
            print(ex)
            error_class = ex.__class__.__name__ #取得錯誤類型
            detail = ex.args[0] #取得詳細內容
            cl, exc, tb = sys.exc_info() #取得Call Stack
            lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
            fileName = lastCallStack[0] #取得發生的檔案名稱
            lineNum = lastCallStack[1] #取得發生的行號
            funcName = lastCallStack[2] #取得發生的函數名稱
            errMsg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
            print(errMsg)
            conn = pymysql.connect(**db_settings)
            with conn.cursor() as cursor:
                cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "wrong", "date_serach_crawler", error_class + detail + errMsg))
        conn = pymysql.connect(**db_settings)
        with conn.cursor() as cursor:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", str(ip) + "finish", "date_serach_crawler", ""))
        
        
    try:
        if str(threading.enumerate()).find("thread_start_date_serach_crawler") >=0:
            return "當前執行緒正在執行",500
    except Exception as ex:
        print(ex)
        pass
    
    try:
        start_date = str(request.args.get("start_date"))
        start_date = datetime.datetime.strptime(start_date, "%Y%m%d")
    except Exception as ex:    
        return "start_date 參數格式錯誤",500
    
    try:
        end_date = str(request.args.get("end_date"))
        end_date = datetime.datetime.strptime(end_date, "%Y%m%d")
    except Exception as ex:    
        return "end_date 參數格式錯誤",500
    
    try:
        if_publish = str(request.args.get("if_publish"))
        if not (if_publish == "yes" or if_publish == "no" or if_publish == "all"):
            return "if_publish 參數格式錯誤",500
    except Exception as ex:
        return "if_publish 參數沒帶",500
        
    
    ip = request.remote_addr
    conn = pymysql.connect(**db_settings)
    with conn.cursor() as cursor:
        if_finish_command="SELECT status FROM log where task ='api_process_date_serach' order by UID DESC"
        cursor.execute(if_finish_command)
        if cursor.fetchone() is None:
            cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", "initial", "", ""))
        cursor.execute(if_finish_command)
        if_finish = str(cursor.fetchone()[0])
    
    print(if_finish)    
    if re.search(r'finish', if_finish, flags=0) or re.search(r'wrong', if_finish, flags=0) or if_finish == "initial":
        pass
    else:
        wording ="資料庫未收到結束log"
        status_code = 500
        return wording,status_code
    
    conn = pymysql.connect(**db_settings)
    with conn.cursor() as cursor:
        cursor.execute(command_log, (datetime.datetime.now(), "api_process_date_serach", str(ip) + " start", "date_serach_crawler", ""))
    
    thread_date_serach_crawler = threading.Thread(target=do_work_2, kwargs={'start_date': start_date,'end_date': end_date,'if_publish':if_publish,'db_settings':db_settings,'headers':headers},name="thread_date_serach_crawler")
    thread_date_serach_crawler.start()    
    return "started",200


if __name__ == '__main__':
    app.debug = False
    app.config['JSON_AS_ASCII'] = False
    app.run(host=my_host, port=5000)
    #serve(app, host=my_host, port=5000)
# Out:
# 請輸入主機ip ( 若要從本機啟動，可輸入127.0.0.1 )：
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Feb/2022 19:25:11] "GET /start_task_all HTTP/1.1" 200 -
# tenderDeclaration 從第 1 頁開始爬取
# searchAppeal 從第 1 頁開始爬取
# publicRead 從第 1 頁開始爬取
# final 從第 1 頁開始爬取
# 爬取日期：111/02/14
# 頁面前往：https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1
# 這是第 1 頁，的第 1 項，總共有 926 項，目前進度是 0.10799136069114472 %。
# https://149.19.224.35:3128
# 爬取日期：111/02/14
# 頁面前往：https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex=1
#
# <link href="../styles/base.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="../styles/confirm.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# a:visited {
# 	text-decoration: none;
# 	color: #444444;
# }
#
# a:hover {
# 	text-decoration: none;
# 	color: #0066CC;
# }
#
# a:link {
# 	text-decoration: none;
# 	color: #444444;
# }
# </style>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="zh-Hant">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="0" http-equiv="Expires"/>
# <title>政府電子採購網</title>
# <link href="/pis/styles/css_m.css" rel="stylesheet" type="text/css"/>
# <script src="/pis/scripts/jquery-1.3.2.js" type="text/javascript"></script>
# <script src="/pis/scripts/jquery.blockUI.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
#
# var $jq = jQuery.noConflict();
#
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# function MM_swapImage() { //v3.0
#   var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)
#    if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}
# }
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# jQuery(document).ready(function(){
#   jQuery("tr.csubmenu").hide();
#   jQuery("tr.cmainmenu").click(function(){
#      var elem = jQuery(this).next();
#      if (elem.hasClass("csubmenu")) {
#        elem.toggle();
#      }
#      return false;
#   });
# });
#
# //-->
# </script>
# </head>
# <body onload="MM_preloadImages('/pis/images/more01over.jpg','/pis/images/system01over.jpg','/pis/images/system02over.jpg','/pis/images/mainmenu07over.jpg','/pis/images/system04over.jpg','/pis/images/system05over.jpg');">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr>
# <script type="text/javascript">
#
#   jQuery(document).ready(function(){
# //   	lihsuan 20191029加入判定是否為上端導盲磚，若是則不導頁 start
#     jQuery('td.homeevent').click(function(clickEvent) {
#     	var obj = clickEvent.target.nodeName;
#     	if(obj!="A"){
# 	  		location.href = "/pis/index.jsp";
#     	}
# //     	lihsuan 20191029加入判定是否為上端導盲磚，若是則不導頁 End
# 	});
#
#     if(document.getElementById("netTrack") != null){
#     	document.title = "政府電子採購網_" + document.getElementById("netTrack").innerText;
#     }
#
#   });
#
# function goToContentOnFocus(){
# // 	document.getElementById("goToContent").innerText = "跳到主要內容區塊";
#     document.getElementById("goToContent").style.color = "black";
# }
#
# function goToContentOnBlur(){
# // 	document.getElementById("goToContent").innerText = ":";
#     document.getElementById("goToContent").style.color = "white";
#
# }
#
# function goToContentOnKeyUp(event){
# 	if (event.stopPropagation != undefined ) {//非IE
# 		event.stopPropagation();
# 	}else {//IE
# 		window.event.cancelBubble = true;
# 	}
# }
#
# </script>
# <noscript>您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態<a href="/pis/index.jsp" title="回到首頁">回到首頁</a></noscript>
# <td align="right" background="/pis/main/pis/client/pssa/logo_image.do?logo_id=50003000" class="homeevent" colspan="3" height="132" style="cursor: pointer;" title="政府電子採購網" valign="top">
# <a href="#goContent" id="goToContent" onblur="goToContentOnBlur();" onclick="goToContentOnKeyUp(event);" onfocus="goToContentOnFocus();" style="text-decoration:none; position:relative; top:5px; left:-950px; color:white; font-size:13px;" title="跳到主要內容區塊">跳到主要內容區塊</a>
# <a class="ctopfont" href="/pis/index.jsp" style="position: relative; top: 5px; left: -900px" title="回到首頁">回首頁</a>
# <div class="cmap010 ctopfont" style="font-size: 75%; position: relative; top: -14px; left: -40px; width:250px; height:40px;"><a accesskey="U" href="#top_area" id="top_area" name="top_area" title="上方選單連結區，此區塊列有[英文版頁面]、[網站導覽]等連結">:::</a>  <a href="/tps/pss/tender.do?method=goNews" title="Go To English Page">English</a> ｜ <a href="/pis/main/pis/client/pssa/sitemap.do" title="前往 網站導覽">網站導覽</a> ｜ <a href="/pis/main/pis/client/pssa/mail_form.do" title="前往 意見信箱">意見信箱</a> ｜ <a href="http://mgeps.pcc.gov.tw/" title="前往 行動版">行動版</a></div>
# <h1 style="margin:0;" title="政府電子採購網"><span style="font-size:0;">政府電子採購網</span></h1>
# </td>
# </tr>
# <tr>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td rowspan="2"><img alt="" height="5" src="/pis/images/space.gif" width="20"/></td>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr><th id="addThId_a" style="display: none;"></th>
# <td headers="addThId_a">
# <a accesskey="L" href="#left_area" name="left_area" style="color: #999999; text-decoration: none;" title="左方選單連結區，此區塊列有本網站主要連結">:::</a>
# </td>
# </tr>
# <tr>
# <td><img alt="" height="25" src="/pis/images/mainimage.jpg" width="190"/></td>
# </tr>
# <tr>
# <td><a href="/pis/main/pis/client/howto.jsp" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu09','','/pis/images/mainmenu09over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu09','','/pis/images/mainmenu09over.jpg',1);" title="前往 如何使用"><img alt="如何使用" border="0" height="30" name="mainmenu09" src="/pis/images/mainmenu09.jpg" width="190"/></a></td>
# </tr>
# <tr>
# <td><a href="/prkms/frontForumClient.do?action=list" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu11','','/pis/images/mainmenu11over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu11','','/pis/images/mainmenu11over.jpg',1);" title="前往 客戶論壇"><img alt="客戶論壇" border="0" height="40" name="mainmenu11" src="/pis/images/mainmenu11.jpg" width="190"/></a></td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu02','','/pis/images/mainmenu02over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu02','','/pis/images/mainmenu02over.jpg',1);" title="開啟 服務專區"><img alt="服務專區" border="0" height="40" name="mainmenu02" src="/pis/images/mainmenu02.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/ens/main2.jsp" title="前往 電子公報">電子公報</a><br/>
# <a href="/csci/main/faqSearchAction.do?method=list" title="前往 問題檢索">問題檢索</a><br/>
# <a href="/csci/main/hotFaqAction.do?method=list" title="前往 熱門問答集">熱門問答集</a><br/>
# <a href="http://papads.gp.gov.tw/event/feedback.html" title="前往 請求協助">請求協助</a><br/>
# <a href="http://71899.pcc.gov.tw/EgpWeb" target="_blank" title="前往 訂閱電子報(另開視窗)">訂閱電子報</a><br/>
# <a href="/tps/tps/tom/main/tps/tom/verifyToken.do?method=verifyToken&amp;searchMode=common" title="前往 列印領標憑據">列印領標憑據</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu07','','/pis/images/mainmenu07over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu07','','/pis/images/mainmenu07over.jpg',1);" title="開啟 常用查詢"><img alt="常用查詢" border="0" height="40" name="mainmenu07" src="/pis/images/mainmenu07.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=common&amp;searchType=basic" title="前往 標案查詢">標案查詢</a><br/>
# <!-- 2012.04.30 刪除民眾端之「廠商資格查詢」功能 fix by Emma -->
# <!-- <a href="/tps/tps/tbm/main/tps/tbm/queryOdiServiceClient.do?method=init" title="廠商資格查詢">廠商資格查詢</a><br> -->
# <a href="/tps/client/main/cscps/ciom/medicineSearch.do?method=init" title="前往 衛材藥品查詢">衛材藥品查詢</a><br/>
# <a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=priority&amp;searchType=advance" title="前往 優先採購查詢">優先採購查詢</a><br/>
# <a href="/oms/proc_trg_query_init.do" title="前往 採購標的分類">採購標的分類</a><br/>
# <a href="/tps/tps/tp/main/pms/tps/tp/StartProcurementPredict.do?pMenu=common&amp;method=searchProcurementPredict&amp;target=ven" title="前往 採購預告查詢">採購預告查詢</a><br/>
# <a href="/tps/tps/tp/main/pms/tps/tp/NoFormPageLink.do?pMenu=common&amp;method=queryReadFormalData" title="前往 公開閱覽查詢">公開閱覽查詢</a><br/>
# <a href="/tps/tps/tp/main/tps/tp/tp.do?method=initialAppealSearchVendor&amp;pMenu=common" title="前往 公開徵求查詢">公開徵求查詢</a><br/>
# <a href="/opas/pspad/intoSearchForPublic.do" title="前往 公示送達查詢">公示送達查詢</a><br/>
# <a href="/opas/arpam/intoSearchForPublic.do" title="前往 財物出租查詢">財物出租查詢</a><br/>
# <a href="/opas/aspam/intoSearchForPublic.do" title="前往 財物變賣查詢">財物變賣查詢</a><br/>
# <a href="/tps/main/pms/tps/pia/piaQueryActionForPublic.do?method=queryPrice" title="前往 物調公告查詢">物調公告查詢</a><br/>
# <a href="/oms/foreSupp_query_init.do" title="前往 外國廠商代碼">外國廠商代碼</a><br/>
# <a href="/vms/main/stiem/searchPublicStiem.do" title="前往 科技研究機構">科技研究機構</a><br/>
# <a href="/vms/lapeem/generalQuery.do?method=qryReviewPage" title="前往 效益評估查詢">效益評估查詢</a><br/>
# <a href="/vms/jgvm/generalQuery.do?method=queryPage" title="前往 連帶保證廠商">連帶保證廠商</a><br/>
# <a href="/vms/evlm/ViewDisabilitiesQueryEM.do" title="前往 優良廠商名單">優良廠商名單</a><br/>
# <a href="/vms/rvlmd/ViewDisabilitiesQueryRV.do" title="前往 拒絕往來廠商">拒絕往來廠商</a><br/>
# <a href="/vms/rvlmd/ViewDisabilitiesQueryVoidRV.do" title="前往 註銷拒絕往來廠商">註銷拒絕往來廠商</a><br/>
# <a href="/vms/gblm.do?method=gblmList" title="前往 全球化廠商名單">全球化廠商名單</a><br/>
# <a href="/vms/gblmComm/integrated.do?method=search" title="前往 廠商綜合查詢">廠商綜合查詢</a><br/>
# <a href="/tps/pss/tender.do?searchMode=common&amp;searchType=basic&amp;method=goReconstruct" title="前往 災區重建工程案件查詢">災區重建工程案件查詢</a><br/>
# <a href="/vms/lapeem/generalQueryPoli.do?method=qryPoliticsPage" title="前往 政治獻金法第七條查詢">政治獻金法第七條查詢</a><br/>
# <a href="/tpsreport/main/atmAbroad/atmAbroad.do?method=atmAbroadQry4Public&amp;funcType=4" title="前往 得標外國政府採購案件查詢">得標外國政府採購案件查詢</a><br/>
# <a href="http://www.bot.com.tw/Procurement/Procure_supply/Supply_qna/Pages/default.aspx" target="_blank" title="前往 臺灣銀行集中採購簡介(另開視窗)">臺灣銀行集中採購簡介</a><br/>
# <a href="/tps/thd/thdAction.do?menuMode=common&amp;method=search" title="前往 歷史文件瀏覽">歷史文件瀏覽</a><br/>
# <a href="/tps/pur/PurQueryPeople.do?method=toPurQueryPeople" title="前往 採購評選委員名單">採購評選委員名單</a><br/>
# <a href="/pis/main/pis/client/bsmizone.do" title="前往 商品檢驗查詢">商品檢驗查詢</a><br/>
# <a href="/piat_piahm/dispute/public/oneOone.do?method=index" title="政府採購法第101條停權案例">政府採購法第101條停權案例</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu08','','/pis/images/mainmenu08over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu08','','/pis/images/mainmenu08over.jpg',1);" title="開啟 國外採購"><img alt="國外採購" border="0" height="40" name="mainmenu08" src="/pis/images/mainmenu08.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="http://gpa.taiwantrade.com.tw/" target="_blank" title="前往 全球政府採購商機(另開視窗)">全球政府採購商機</a><br/>
# <a href="https://www.pcc.gov.tw/cp.aspx?n=49F759CB03E9FCFF" target="_blank" title="前往 外國政府採購網站(另開視窗)">外國政府採購網站</a><br/>
# <a href="/tps/fd/fd.do?method=goSearch" title="前往 外國政府採購商情">外國政府採購商情</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu03','','/pis/images/mainmenu03over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu03','','/pis/images/mainmenu03over.jpg',1);" title="開啟 教育訓練"><img alt="教育訓練" border="0" height="40" name="mainmenu03" src="/pis/images/mainmenu03.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/psms/pptom/searchTrainingOrgForPublic.do" title="前往 代訓機構名單">代訓機構名單</a><br/>
# <a href="/psms/trainingclass/searchForPublicTrainingClass.do" title="前往 代訓機構開課">代訓機構開課</a><br/>
# <a href="/psms/question/searchQuestionForPublic.do" title="前往 採購法規題庫">採購法規題庫</a><br/>
# <a href="/training/signUp.do?method=init" title="前往 廠商課程線上報名">廠商課程線上報名</a><br/>
# <a href="/psms/plrtm/certificate.do" title="前往 採購專業人員及格證書查詢">採購專業人員及格證書查詢</a><br/>
# <a href="/psms/plrtm/certificateReissue.do" title="前往 採購專業人員及格證書補發申請">採購專業人員及格證書補發申請</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu04','','/pis/images/mainmenu04over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu04','','/pis/images/mainmenu04over.jpg',1);" title="開啟 知識管理"><img alt="知識管理" border="0" height="40" name="mainmenu04" src="/pis/images/mainmenu04.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <!--
#       <a href="/prkms/tenderdocClient.do?action=list" title="招標文件">招標文件</a><br>
#       -->
# <a href="/prkms/largeprocureClient.do?action=list" title="前往 巨額效益">巨額效益</a><br/>
# <!--
#       <a href="http://epm.gp.gov.tw/default.aspx" title="旗艦計畫" target="_blank">旗艦計畫</a>
#       -->
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu05','','/pis/images/mainmenu05over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu05','','/pis/images/mainmenu05over.jpg',1);" title="開啟 下載專區"><img alt="下載專區" border="0" height="40" name="mainmenu05" src="/pis/images/mainmenu05.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="https://www.pcc.gov.tw/cp.aspx?n=99E24DAAC84279E4" target="_blank" title="前往 招標文件範本(另開視窗)">招標文件範本</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003004" title="前往 拒絕往來名單">拒絕往來名單</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000003" title="前往 系統使用手冊">系統使用手冊</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000005" title="前往 2 代採購教材">2 代採購教材</a><br/>
# <a href="https://web.pcc.gov.tw/pis/main/pis/client/b_wait.html" target="_blank" title="前往 等標期(另開視窗)">等標期</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=42000000" title="前往 共同供應契約">共同供應契約</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000004" title="前往 常用工具下載">常用工具下載</a><br/>
# <a href="https://web.pcc.gov.tw/tpsreport/transfer/dataTransfer.do?method=getOkfnOpenDataXml" target="_blank" title="前往 資料集下載(另開視窗)">資料集下載</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003000" title="前往 重要訊息通告">重要訊息通告</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003002" title="前往 ５都改制文件">５都改制文件</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003006" title="前往 中央組改文件 ">中央組改文件 </a><br/>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu06','','/pis/images/mainmenu06over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu06','','/pis/images/mainmenu06over.jpg',1);" title="開啟 相關連結"><img alt="相關連結" border="0" height="40" name="mainmenu06" src="/pis/images/mainmenu06.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="http://gca.nat.gov.tw/" target="_blank" title="前往 政府憑證管理中心(另開視窗)">政府憑證管理中心</a><br/>
# <a href="https://xca.nat.gov.tw/" target="_blank" title="前往 組織及團體憑證管理中心(另開視窗)">組織及團體憑證管理中心</a><br/>
# <a href="http://moeaca.nat.gov.tw/" target="_blank" title="前往 工商憑證管理中心(另開視窗)">工商憑證管理中心</a><br/>
# <a href="http://moica.nat.gov.tw/" target="_blank" title="前往 自然人憑證管理中心(另開視窗)">自然人憑證管理中心</a><br/>
# <a href="http://cmdweb.pcc.gov.tw/pccms/owa/cmdmang.userin" target="_blank" title="前往 工程標案管理系統(另開視窗)">工程標案管理系統</a><br/>
# <a href="http://cmdweb.pcc.gov.tw/pccms/owa/pwksafe3.userin" target="_blank" title="前往 工程不當延遲付款通報(另開視窗)">工程不當延遲付款通報</a><br/>
# <a href="https://ppp.mof.gov.tw/WWW/inv_ann.aspx" target="_blank" title="前往 促進民間參與公共建設公告(另開視窗)">促進民間參與公共建設公告</a><br/>
# <a href="https://pe2sys.pcc.gov.tw/Public/index.aspx" target="_blank" title="前往 技師與工程技術顧問公司管理資訊系統(另開視窗)">技師與工程技術顧問公司管理資訊系統</a><br/>
# <a href="http://cpabm.cpami.gov.tw/index.jsp" target="_blank" title="前往 營建署全國建築管理資訊入口網(另開視窗)">營建署全國建築管理資訊入口網</a><br/>
# <a href="https://gcis.nat.gov.tw/mainNew/" target="_blank" title="前往 經濟部商工行政服務入口網(另開視窗)">經濟部商工行政服務入口網</a><br/>
# <a href="http://www.etax.nat.gov.tw" target="_blank" title="前往 財政部稅務入口網(另開視窗)">財政部稅務入口網</a><br/>
# <a href="http://www.energylabel.org.tw/purchasing/govgreen/list.asp" target="_blank" title="前往 環保署節能標章綠色採購網(另開視窗)">環保署節能標章綠色採購網</a><br/>
# <a href="http://dpws.sfaa.gov.tw/commonch/index.jsp" target="_blank" title="前往 衛生福利部社會及家庭署身心障礙服務入口網(另開視窗)">衛生福利部社會及家庭署身心障礙服務入口網</a><br/>
# <a href="http://cpabm.cpami.gov.tw/wor-inx/" target="_blank" title="前往 營建署工程重機械編管及運用管理系統(另開視窗)">營建署工程重機械編管及運用管理系統</a><br/>
# <a href="/pis/main/pis/client/lrs/links.do?id=50003006" title="前往 經濟部投審會公告陸資資訊">經濟部投審會公告陸資資訊</a><br/>
# <a href="http://www.mine.gov.tw/" target="_blank" title="前往 經濟部礦務局(另開視窗)">經濟部礦務局</a><br/>
# <a href="https://cmdweb.pcc.gov.tw/pccms/owa/pwksafe.statmenu" target="_blank" title="前往 承攬廠商公共工程履歷資料(另開視窗)">承攬廠商公共工程履歷資料</a><br/>
# <a href="https://pe2sys.pcc.gov.tw/Public/EGR/Report1.aspx?progid=EGR_2_2_1&amp;rn=1096301101" target="_blank" title="前往 技師懲戒資料(另開視窗)">技師懲戒資料</a><br/>
# <a href="http://cpabm.cpami.gov.tw/SearchPage2.jsp?url=/search/clis/queryClscogn.jsp" target="_blank" title="前往 內政部營建署營造業評鑑結果查詢(另開視窗)">內政部營建署營造業評鑑結果查詢</a><br/>
# <a href="/pis/main/pis/client/lrs/links.do?id=50003007" title="前往 行政法人相關採購資訊">行政法人相關採購資訊</a><br/>
# </td>
# </tr>
# <tr>
# <td><a href="/ars/wr/wrclient.do" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu12','','/pis/images/mainmenu12over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu12','','/pis/images/mainmenu12over.jpg',1);" title="前往 採購統計"><img alt="採購統計" border="0" height="40" name="mainmenu12" src="/pis/images/mainmenu12.jpg" width="190"/></a></td>
# </tr>
# <tr>
# <td><img alt="" height="10" src="/pis/images/mainmenudown.jpg" width="190"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr>
# <td align="center"><a href="https://web.pcc.gov.tw/pis/main/pis/client/lrs/links.do?id=50003007" title="前往 行政法人相關採購資訊"><img alt="行政法人相關採購資訊" border="0" src="/pis/images/banner07.jpg" style="margin-bottom:2px" width="170"/></a></td>
# </tr>
# <tr>
# <td>
# <a href="http://71899.pcc.gov.tw/EgpWeb/" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('Image12','','/pis/images/serviceover.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('Image12','','/pis/images/serviceover.jpg',1);" target="_blank" title="前往 訂閱加值服務(另開視窗)">
# <img alt="訂閱加值服務(另開視窗)" border="0" height="63" name="Image12" src="/pis/images/service.jpg" width="190"/>
# </a>
# </td>
# </tr>
# <tr>
# <td align="center"><a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=priority&amp;searchType=advance" title="前往 優先採購"><img alt="優先採購" border="0" height="55" src="/pis/images/index_buy.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="/pis/main/pis/client/aborigineszone.do?method=goInit" title="前往 「購買原住民及身心障礙者所提供之產品或勞務」採購專區平台"><img alt="「購買原住民及身心障礙者所提供之產品或勞務」採購專區平台" border="0" src="/pis/images/banner05.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="https://web.pcc.gov.tw/raam/registerCorp.do?method=goRegisterCorp" title="前往 法人團體帳號申請"><img alt="法人團體帳號申請" border="0" height="53" src="/pis/images/banner01.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="/applet/env_test.html" style="font-size: 110%; color: #FF6600;" target="_blank" title="前往 安裝程式環境檢測(另開視窗)"><img alt="安裝程式環境檢測(另開視窗)" border="0" height="59" src="/pis/images/index7_73.jpg" width="179"/></a></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# <td align="center" colspan="2" id="page" valign="top" width="772">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td valign="top"><img alt="" height="4" src="/pis/images/space.gif" width="7"/></td>
# <td valign="top">
# <img alt="" height="4" src="/pis/images/space.gif" width="772"/>
# <div id="goContent"></div>
# <script src="../scripts/tenderSearch.js" type="text/javascript"></script>
# <div id="confirm_box" style="display: none; cursor: default"><span id="confirm_message" style="font-weight: bold;"></span> <br>
# <br>
# <input class="titlefont80" id="yes" type="button" value="確認"/> <input class="titlefont80" id="no" onclick="$jq.unblockUI()" type="button" value="關閉"/></br></br></div>
# <form action="./tender.do?searchMode=common" method="post" name="TenderActionForm"><input name="method" type="hidden" value="search"/><input name="searchMethod" type="hidden" value="true"/><input name="searchType" type="hidden" value="advance"/><input name="tenderName" type="hidden" value=""/><input name="searchTarget" type="hidden" value="ATM"/></form>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <caption style="display:none">標案查詢</caption>
# <tr>
# <td colspan="2" valign="top"><img alt="" height="5" src="../images/space.gif" width="758"/></td>
# </tr>
# <tr>
# <td align="left" colspan="2">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td><span class="croot"><a accesskey="C" href="#center_area" name="center_area" title="網頁內容資料呈現區">:::</a></span><img alt="" height="13" src="../images/root01.gif" width="14"/> <span class="croot" id="netTrack"><a href="/pis/main/pis/client/index.do" title="首頁">首頁</a>&gt;標案查詢<h2 class="croot" style="display: inline-flex;margin:0px;"><img alt="標案查詢" height="0" src="../images/space.gif" width="0"/></h2></span></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td background="../images/home_title.jpg" colspan="2" style="background-repeat: no-repeat;">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td width="1%"><img alt="*" height="55" src="../images/space.gif" width="80"/></td>
# <td align="left" class="ctitlefont80" style="padding-left: 10px;">標案查詢</td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td colspan="2" valign="middle">
# <table align="left">
# <tr><td>註：</td><td><font color="red">◎</font> 檢視決標公告，請點選決標公告欄位下方之序號，如決標公告001<br/></td></tr>
# <tr><td></td><td><font color="red">◎</font> 查詢結果依決標公告日期遞減排序,即最新公告之標案在最上方</td></tr>
# </table>
# </td>
# </tr>
# <tr>
# <td colspan="2" valign="middle">
# <table border="0" cellpadding="4" cellspacing="0" width="95%">
# <tr>
# <td align="left" valign="top"></td>
# </tr>
# <tr>
# <td align="right">
# <!-- <img src="/tps/images/print.jpg" alt="友善列印" width="16" height="16"><input name="button5" type="button" class="T11c" id="button5" value="友善列印" onClick="popWatermark2();print_doc();popWatermark();"> -->
# <script>
# 							document.write("<img src='/tps/images/print.jpg' alt='友善列印' width='16' height='16'><input name='button5' type='button' class='T11c' id='button5' value='友善列印' onClick='popWatermark2();print_doc();popWatermark();'>");
# 							</script>
# </td>
# </tr>
# <tr>
# <td bgcolor="#98BADC">
# <table align="center" bgcolor="#FFFFFF" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr>
# <td>
# <div id="print_area">
# <table border="0" cellpadding="0" cellspacing="0" style="word-break:break-all" width="100%">
# <tr>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">項次 </th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="15%">機關 <br>名稱 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="30%">標案案號 <br>標案名稱 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="10%">招標 <br>方式 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="8%">標的 <br>分類 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="9%">公告 <br>日期 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="13%">決標 <br>金額 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">決標 <br>公告 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">無法 <br>決標 </br></th>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">1 </td>
# <!-- 機關名稱 -->
# <td align="left">南臺學校財團法人南臺科技大學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												11K000006
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648629" title="數位式HDMI數位影音傳遞系統">
# <u>數位式HDMI數位影音傳遞系統</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648629" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">2 </td>
# <!-- 機關名稱 -->
# <td align="left">交通部航港局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												MPB111C0207A
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648620" title="高雄市1筆不動產委託估價專業服務採購案">
# <u>高雄市1筆不動產委託估價專業服務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648620" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">3 </td>
# <!-- 機關名稱 -->
# <td align="left">衛生福利部南投醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												MED111-04
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648615" title="111年Ozempic藥品採購案">
# <u>111年Ozempic藥品採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648615" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">4 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市政府衛生局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												S11111
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648554" title="111年度自殺防治宣導活動">
# <u>111年度自殺防治宣導活動</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648554" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">5 </td>
# <!-- 機關名稱 -->
# <td align="left">國軍退除役官兵輔導委員會臺東農場</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111TF02
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648545" title="花蓮縣吉安鄉廣榮段3646、3647、3648地號3筆土地上設備拆卸工程">
# <u>花蓮縣吉安鄉廣榮段3646、3647、3648地號3筆土地上設備拆卸工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648545" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">6 </td>
# <!-- 機關名稱 -->
# <td align="left">苗栗縣三義鄉公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1110D0000304
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648521" title="111年度三義鄉標誌標線反射鏡改善工程(開口契約)">
# <u>111年度三義鄉標誌標線反射鏡改善工程(開口契約)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648521" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">7 </td>
# <!-- 機關名稱 -->
# <td align="left">嘉義縣朴子市朴子國民小學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1110207
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648520" title="嘉義縣朴子市朴子國民小學111年度保全替代人力委外勞務承攬採購案">
# <u>嘉義縣朴子市朴子國民小學111年度保全替代人力委外勞務承攬採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648520" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">8 </td>
# <!-- 機關名稱 -->
# <td align="left">新北市立溪崑國民中學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												F11101
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648505" title="111年度增購體育訓練設備設施">
# <u>111年度增購體育訓練設備設施</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648505" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">9 </td>
# <!-- 機關名稱 -->
# <td align="left">苗栗縣政府</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												110324d
#
# 												<font color="red">(更正公告)</font>
# <br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53609737" title="西湖鄉119線11K+600道路擋土牆及護欄工程">
# <u>西湖鄉119線11K+600道路擋土牆及護欄工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53609737" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">10 </td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1112B001
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648476" title="冷凍切片機一台">
# <u>冷凍切片機一台</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648476" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">11 </td>
# <!-- 機關名稱 -->
# <td align="left">高雄榮民總醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LP-11183
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648415" title="三人座沙發及單人座沙發5組">
# <u>三人座沙發及單人座沙發5組</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648415" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">12 </td>
# <!-- 機關名稱 -->
# <td align="left">高雄榮民總醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LP-11317
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648414" title="煮飯箱1台">
# <u>煮飯箱1台</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648414" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">13 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市立聯合醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												S111010
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648410" title="電針機一批採購案">
# <u>電針機一批採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648410" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">14 </td>
# <!-- 機關名稱 -->
# <td align="left">中華郵政股份有限公司屏東郵局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111020101
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648338" title="屏東郵局111年硬幣棉布袋採購案">
# <u>屏東郵局111年硬幣棉布袋採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648338" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">15 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市信義區健康服務中心</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111C01
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648321" title="111年信義區防疫工時人員勞務採購案">
# <u>111年信義區防疫工時人員勞務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648321" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">16 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A013
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648288" title="玉山里田洋(第四鄰)AC路面改善工程">
# <u>玉山里田洋(第四鄰)AC路面改善工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648288" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">17 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A005
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648287" title="110年度0605豪雨南化區北平里過嶺農路災後復建工程">
# <u>110年度0605豪雨南化區北平里過嶺農路災後復建工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648287" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">18 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市政府警察局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111SA0119-3
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648285" title="111年度警報器系統設備維修保養採購案">
# <u>111年度警報器系統設備維修保養採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648285" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">19 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A006
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648283" title="北平里芭拉湖農路(尖山高分19左12)路面改善工程等二件">
# <u>北平里芭拉湖農路(尖山高分19左12)路面改善工程等二件</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648283" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">20 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市政府警察局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111SA0119-1
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648276" title="20馬力交流警報器採購案">
# <u>20馬力交流警報器採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648276" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">21 </td>
# <!-- 機關名稱 -->
# <td align="left">衛生福利部樂生療養院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												lslp-2542-11103
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648264" title="生物醫療廢棄物再利用處理一式">
# <u>生物醫療廢棄物再利用處理一式</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648264" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">22 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市南港區南港國民小學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												11103
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648263" title="行動學習智慧教學計畫平板電腦採購案">
# <u>行動學習智慧教學計畫平板電腦採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648263" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">23 </td>
# <!-- 機關名稱 -->
# <td align="left">嘉義縣中埔鄉公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1100098
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648253" title="社口村內灣橋上方護岸復建工程等2件工程">
# <u>社口村內灣橋上方護岸復建工程等2件工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648253" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">24 </td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學生物資源暨農學院實驗林管理處</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LCJ11102
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648243" title="111年本處臺北林業教學研究中心大樓管理及清潔維護勞務承攬工作">
# <u>111年本處臺北林業教學研究中心大樓管理及清潔維護勞務承攬工作</u>
# </a>
# </td>
# <!-- 招標方式 -->
# ...
# 還剩餘 7 個proxy
# https://45.42.177.71:3128
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))
# 還剩餘 6 個proxy
# https://45.42.177.72:3128
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))
# 還剩餘 5 個proxy
# https://64.17.30.238:63141
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001640CF76D60>, 'Connection to 64.17.30.238 timed out. (connect timeout=10)'))
# 還剩餘 4 個proxy
# https://66.94.97.238:443
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out')))
# 還剩餘 3 個proxy
# https://72.47.152.224:55443
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out')))
# 還剩餘 2 個proxy
# https://96.36.8.51:8080
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=53724120 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001640CF808B0>, 'Connection to 96.36.8.51 timed out. (connect timeout=10)'))
# 還剩餘 1 個proxy
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：10
# 3.79.14.14
# 此細項已抓取完成，總耗時： 0:01:26.793348 s
# ------------------------------------
# 這是第 1 頁，的第 79 項，總共有 926 項，目前進度是 8.531317494600433 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.1.100.1
# 此細項已抓取完成，總耗時： 0:00:04.081651 s
# ------------------------------------
# 這是第 1 頁，的第 80 項，總共有 926 項，目前進度是 8.639308855291576 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# A.9.6M
# 此細項已抓取完成，總耗時： 0:00:04.325136 s
# ------------------------------------
# 這是第 1 頁，的第 81 項，總共有 926 項，目前進度是 8.74730021598272 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.55.61
# 此細項已抓取完成，總耗時： 0:00:04.662386 s
# ------------------------------------
# 這是第 1 頁，的第 82 項，總共有 926 項，目前進度是 8.855291576673865 %。
# https://98.12.195.129:443
# 準備執行驗證
# 驗證失敗
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# A.25
# 此細項已抓取完成，總耗時： 0:00:04.648867 s
# ------------------------------------
# 這是第 1 頁，的第 83 項，總共有 926 項，目前進度是 8.96328293736501 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.82.27.4
# 此細項已抓取完成，總耗時： 0:00:04.494392 s
# ------------------------------------
# 這是第 1 頁，的第 84 項，總共有 926 項，目前進度是 9.071274298056156 %。
# https://98.12.195.129:443
# 準備執行驗證
# 驗證失敗
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.82.55
# 此細項已抓取完成，總耗時： 0:00:04.911178 s
# ------------------------------------
# 這是第 1 頁，的第 85 項，總共有 926 項，目前進度是 9.1792656587473 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.97.32
# 此細項已抓取完成，總耗時： 0:00:04.805063 s
# ------------------------------------
# 這是第 1 頁，的第 86 項，總共有 926 項，目前進度是 9.287257019438446 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.57.86
# 此細項已抓取完成，總耗時： 0:00:04.180697 s
# ------------------------------------
# 這是第 1 頁，的第 87 項，總共有 926 項，目前進度是 9.395248380129589 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.47.97.28
# 此細項已抓取完成，總耗時： 0:00:03.950595 s
# ------------------------------------
# 這是第 1 頁，的第 88 項，總共有 926 項，目前進度是 9.503239740820735 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.79.15.3
# 此細項已抓取完成，總耗時： 0:00:03.894064 s
# ------------------------------------
# 這是第 1 頁，的第 89 項，總共有 926 項，目前進度是 9.611231101511878 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.45.24.2
# 此細項已抓取完成，總耗時： 0:00:05.257614 s
# ------------------------------------
# 這是第 1 頁，的第 90 項，總共有 926 項，目前進度是 9.719222462203025 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.7.74.36
# 此細項已抓取完成，總耗時： 0:00:04.873585 s
# ------------------------------------
# 這是第 1 頁，的第 91 項，總共有 926 項，目前進度是 9.827213822894167 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.13.30.53
# 此細項已抓取完成，總耗時： 0:00:10.927416 s
# ------------------------------------
# 這是第 1 頁，的第 92 項，總共有 926 項，目前進度是 9.935205183585314 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.48.58
# 此細項已抓取完成，總耗時： 0:00:04.345287 s
# ------------------------------------
# 這是第 1 頁，的第 93 項，總共有 926 項，目前進度是 10.043196544276457 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.82.8.58
# 此細項已抓取完成，總耗時： 0:00:03.853222 s
# ------------------------------------
# 這是第 1 頁，的第 94 項，總共有 926 項，目前進度是 10.151187904967603 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.48.58
# 此細項已抓取完成，總耗時： 0:00:04.818332 s
# ------------------------------------
# 這是第 1 頁，的第 95 項，總共有 926 項，目前進度是 10.259179265658748 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.53.97.33
# 此細項已抓取完成，總耗時： 0:00:04.157133 s
# ------------------------------------
# 這是第 1 頁，的第 96 項，總共有 926 項，目前進度是 10.367170626349893 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.76.45.98.44
# 此細項已抓取完成，總耗時： 0:00:03.928289 s
# ------------------------------------
# 這是第 1 頁，的第 97 項，總共有 926 項，目前進度是 10.475161987041037 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.87.20
# 此細項已抓取完成，總耗時： 0:00:04.075707 s
# ------------------------------------
# 這是第 1 頁，的第 98 項，總共有 926 項，目前進度是 10.583153347732182 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.95.81
# 此細項已抓取完成，總耗時： 0:00:04.141847 s
# ------------------------------------
# 這是第 1 頁，的第 99 項，總共有 926 項，目前進度是 10.691144708423327 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.15.6.4
# 此細項已抓取完成，總耗時： 0:00:04.174434 s
# ------------------------------------
# 這是第 1 頁，的第 100 項，總共有 926 項，目前進度是 10.799136069114471 %。
# https://98.12.195.129:443
# 準備執行驗證
# 通過驗證
# 執行驗證完成
# 內頁連線數：1
# 3.13.30.53
# 此細項已抓取完成，總耗時： 0:00:03.729029 s
# ------------------------------------
# 此分頁抓取總耗時： 0:16:40.391376 s
# 926
# 100
# time cost 0:00:12.999864 s
# 爬取日期：111/02/14
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/tps/tp/searchListAppealVendorCommon.do?__PageBase=0&__PageIndex=1
# 這是第 1 頁，的第 1 項，總共有 564 項，目前進度是 0.1773049645390071 %。
# {'機關代碼': '3.79.62', '機關名稱': '臺北大眾捷運股份有限公司', '機關地址': '104臺北市中山區中山北路2段48巷7號4樓', '公告次數': '01', '標案案號': 'B11C01984', '標案名稱': '捷運板南線忠孝復興站月台區域旅客引導設備增設安裝工作', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    一、本案尚屬【詢價階段】，相關報價工作內容請洽本公司電機處趙家笙，電話02-\r25505600#6602、傳真02-27218684、電子郵件信箱e25216@metro.taipei，並於公開徵求日期間將相關報價參考資料(註明廠商名稱、統一編號、電話、傳真、聯絡人)以彩色掃描成電子檔後，E-MAIL方式傳至本公司電機處水電廠趙家笙、電子郵件信箱：e25216@metro.taipei。\r二、本案規範、數量如下：\r捷運板南線忠孝復興站兩月台區域增加字幕機4組、LED燈條48組，另須配置字幕機訊號轉換單元、DMX控制器(含訊號轉換單元)及配置管線。\r三、本案之詳細規格及規範如有疑問請電洽本公司需求單位\r[電機處水電廠水電二場趙家笙]電話02-25505600#6602', '公開徵求日期': '111/02/14 ─ 111/02/21', '聯絡人': '趙家笙(電機處水電廠)', '聯絡電話': '(02)25505600分機6602', '電子郵件信箱': 'e25216@metro.taipei', '內容摘要': '捷運板南線忠孝復興站月台區域旅客引導設備增設安裝工作', '是否提供公開徵求說明文件': '是'}
# 這是第 1 頁，的第 2 項，總共有 564 項，目前進度是 0.3546099290780142 %。
# {'機關代碼': '3.37.1', '機關名稱': '行政院原子能委員會核能研究所', '機關地址': '325桃園市龍潭區佳安里文化路1000號', '公告次數': '01', '標案案號': '11103', '標案名稱': '細胞培養基與化學藥品採購', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    1. SI-R8005-10X1L RPMI 1640培養基 (Sigma或同級品)\rRPMI-1640 Medium Hybri-Max(TM), Modified, with L-glutamine, 4500 mg/L glucose and 15mM HEPES, without sodium bicarbonate, powder, suitable for hybrid\r2. SI-S8636-100ML 丙酮酸鈉 (cas.113-24-6) (Sigma或同級品)\rSodium pyruvate solution 100 mM, sterile-filtered, BioReagent, suitable for cell culture\r3.  SI-S2889-1KG 無水醋酸鈉 (cas.127-09-3) (Merck或同級品)\rSodium acetate anhydrous, for molecular biology, >=99%', '公開徵求日期': '111/02/14 ─ 111/02/18', '聯絡人': '陳俊堂', '聯絡電話': '(03)4711400分機7283', '電子郵件信箱': 'ctchen@iner.gov.tw', '內容摘要': '細胞培養基與化學藥品採購', '是否提供公開徵求說明文件': '否'}
# 這是第 1 頁，的第 3 項，總共有 564 項，目前進度是 0.5319148936170213 %。
# {'機關代碼': '3.79.62', '機關名稱': '臺北大眾捷運股份有限公司', '機關地址': '104臺北市中山區中山北路2段48巷7號2樓', '公告次數': '01', '標案案號': 'C11A01807', '標案名稱': '加速度感測探頭等3項採購', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    一、徵求報價參考資料：本案尚屬【詢價階段】，請於公開徵求截止日17時前將相關報價參考資料(註明廠商名稱、統一編號、電話、傳真、聯絡人、交貨天數)以【傳真】或【E-Mail】或【郵寄】方式逕送本公司供應處。 \r二、本案規範訂定若有缪誤、異動、未詳盡或其他待確認事項時，請於報價時一併提出並立即與本公司詢價人員聯絡，以避免影響招標程序或造成雙方履約、驗收及請領價款等困擾。\r三、廠商如需相關資料，請於「下載公開徵求說明文件」下載或聯繫採購承辦人：陳孟渟【TEL：02-2536-3001轉8442 或 FAX：02-2525-5371】，或 E-Mail來信索取【caren@metro.taipei】。\r四、報價廠商不得為行政院公共工程委員會之拒絕往來廠商。\r五、實際交貨期以招標公告或通知之交貨期限日數為準。\r六、本案詳細規格及數量請參閱公開徵求說明文件，如有疑問請電洽本公司需求單位：【工務處軌道廠 梁耀中 02-2893-0105#7032】\r七、本案無指定廠牌\r八、交貨或驗收時需檢附文件(詳規格說明書)：\r１、廠商應於交貨時提供交貨日前[1]年內製造或出廠之切結書(內容至少應包含品名、規格或型號及製造或出廠日期)。\r２、廠商交貨如為國外進口品(國產品則免附)，應於驗收時提供進口證明文件(如為進口報單須蓋有海關進口證明文件簽證專用章，若進口報單之納稅義務人非廠商，則廠商應出具切結書證明進口報單之貨物係用於本案之貨物)。\r３、廠商應於交貨時提供項次1、2每組(件)符合CNS 17025（ISO/IEC 17025）規定或TAF認證之實驗室校驗報告（內容須含品名、廠牌、型號；校正點或校正範圍:項次1包含50Hz、100Hz、200Hz，項次2包含10Hz、15Hz、30Hz）。', '公開徵求日期': '111/02/14 ─ 111/02/18', '聯絡人': '陳孟渟', '聯絡電話': '(02)25363001分機8442', '電子郵件信箱': 'caren@metro.taipei', '內容摘要': '加速度感測探頭等3項採購', '是否提供公開徵求說明文件': '是'}
# 這是第 1 頁，的第 4 項，總共有 564 項，目前進度是 0.7092198581560284 %。
# {'機關代碼': '3.79.62', '機關名稱': '臺北大眾捷運股份有限公司', '機關地址': '104臺北市中山區中山北路2段48巷7號2樓', '公告次數': '01', '標案案號': 'C11A01726', '標案名稱': '半永久聯結器連結座螺栓組等2項採購', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    一、徵求報價參考資料：本案尚屬【詢價階段】，請於公開徵求截止日17時前將相關報價參考資料(註明廠商名稱、統一編號、電話、傳真、聯絡人、交貨天數)以【傳真】或【E-Mail】或【郵寄】方式逕送本公司供應處。 \r二、本案規範訂定若有缪誤、異動、未詳盡或其他待確認事項時，請於報價時一併提出並立即與本公司詢價人員聯絡，以避免影響招標程序或造成雙方履約、驗收及請領價款等困擾。\r三、廠商如需相關資料，請於「下載公開徵求說明文件」下載或聯繫採購承辦人：陳孟渟【TEL：02-2536-3001轉8442 或 FAX：02-2525-5371】，或 E-Mail來信索取【caren@metro.taipei】。\r四、報價廠商不得為行政院公共工程委員會之拒絕往來廠商。\r五、實際交貨期以招標公告或通知之交貨期限日數為準。\r六、本案詳細規格及數量請參閱公開徵求說明文件，如有疑問請電洽本公司需求單位：【車輛處車輛四廠 呂紹煒02-27828660#8339】\r七、本案指定廠牌【DELLNER】\r八、交貨或驗收時需檢附文件(詳規格說明書)：\r１、廠商應於交貨時提供交貨日前[1]年內之原廠DELLNER製造或出廠證明文件 (內容至少包含但不限於品名、規格或型號及製造或出廠日期)或原產地證明文件(內容至少包含但不限於品名、規格或型號及INVOICE商業發票日期)及中譯本。(前述製造或出廠證明文件係包含原廠各地之分公司或在我國境內投資設立之子公司所出具之文件)\r２、廠商交貨如為國外進口品(國產品則免附)，應於驗收時提供進口證明文件(如為進口報單須蓋有海關進口證明文件簽證專用章，若進口報單之納稅義務人非廠商，則廠商應出具切結書證明進口報單之貨物係用於本案之貨物)。', '公開徵求日期': '111/02/14 ─ 111/02/18', '聯絡人': '陳孟渟', '聯絡電話': '(02)25363001分機8442', '電子郵件信箱': 'caren@metro.taipei', '內容摘要': '半永久聯結器連結座螺栓組等2項採購', '是否提供公開徵求說明文件': '是'}
# 這是第 1 頁，的第 5 項，總共有 564 項，目前進度是 0.8865248226950355 %。
# {'機關代碼': '3.5.49', '機關名稱': '國防部空軍司令部', '機關地址': '900屏東縣屏東市屏東郵政90325-5號信箱', '公告次數': '01', '標案案號': 'DAMA11024', '標案名稱': '頭盔袋326個', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    頭盔袋：長44.5cm、寬45cm、底邊7cm\r數量:326個\r若有報價需求請洽承辦人李先生(手機：0977249649)', '公開徵求日期': '111/02/14 ─ 111/02/21', '聯絡人': '李秉樺', '聯絡電話': '(0977)249649', '電子郵件信箱': 'Purchase006@mail.mil.tw', '內容摘要': '頭盔袋326個', '是否提供公開徵求說明文件': '否'}
# 這是第 1 頁，的第 6 項，總共有 564 項，目前進度是 1.0638297872340425 %。
# {'機關代碼': '3.79.62', '機關名稱': '臺北大眾捷運股份有限公司', '機關地址': '104臺北市中山區中山北路2段48巷7號2樓', '公告次數': '01', '標案案號': 'C11A02002', '標案名稱': '乾燥器閥門密封修理包等6項採購', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    1.徵求報價參考資料：\r本案尚屬【詢價階段】，請於公開徵求截止日17時前將相關報價參考資料(註明廠商名稱、統一編號、電話、傳真、聯絡人、交貨天數)以【傳真】或【E-Mail】或【郵寄】方式逕送本公司供應處。 \r2.本案規範訂定若有缪誤、異動、未詳盡或其他待確認事項時，請於報價時一併提出並立即與本公司詢價人員聯絡，以避免影響招標程序或造成雙方履約、驗收及請領價款等困擾。\r3.廠商如需相關資料，請於「下載公開徵求說明文件」下載或聯繫採購承辦人：陳怡心【TEL：02-2536-3001轉8447 或 FAX：02-2525-5371】，或 E-Mail來信索取【e01312@metro.taipei】。\r4.報價廠商不得為行政院公共工程委員會之拒絕往來廠商。\r5.實際交貨期以招標公告或通知之交貨期限日數為準。\r6.本案詳細規格及數量請參閱公開徵求說明文件，如有疑問請電洽本公司需求單位：【車輛處車輛四廠 李則奇 電話：2782-8660轉8332】', '公開徵求日期': '111/02/14 ─ 111/02/18', '聯絡人': '陳怡心', '聯絡電話': '(02)25363001分機8447', '電子郵件信箱': 'e01312@metro.taipei', '內容摘要': '乾燥器閥門密封修理包等6項採購', '是否提供公開徵求說明文件': '是'}
# 這是第 1 頁，的第 7 項，總共有 564 項，目前進度是 1.2411347517730498 %。
# {'機關代碼': 'A.7.32', '機關名稱': '臺灣土地銀行股份有限公司', '機關地址': '100臺北市中正區館前路46號', '公告次數': '01', '更正序號': '01', '標案案號': 'A111-039-00E', '標案名稱': '分行服務中心管理系統擴充', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\n\r\n\t    \r\n\t     \r\n\t    一、本案尚屬「詢價階段」，相關報價工作請洽本公司資訊處林真亦，電話(02)27547676轉3003，傳真(02)27084179電子郵件081341@landbank.com.tw；並請於111年2月15日17:00前將相關報價參考資料加蓋公司戳章(註明廠商名稱、統一編號、電話、傳真、聯絡人)，以傳真、電子郵件或郵遞方式，逕送本公司資訊處林真亦，地址：臺北市大安區和平東路3段15號10樓。\r二、本案採購分行服務中心管理系統擴充功能。', '公開徵求日期': '111/02/10 ─ 111/02/15', '聯絡人': '林真亦', '聯絡電話': '(02)27547676分機3003', '電子郵件信箱': '081341@landbank.com.tw', '內容摘要': '分行服務中心管理系統擴充', '是否提供公開徵求說明文件': '否'}
# 這是第 1 頁，的第 8 項，總共有 564 項，目前進度是 1.4184397163120568 %。
# {'機關代碼': '3.76.55.97.2', '機關名稱': '花蓮縣花蓮市明義國民小學', '機關地址': '970花蓮縣花蓮市明義街107號', '公告次數': '01', '標案案號': '1110209', '標案名稱': '明義國小110學年度學生宿營活動', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效', '公開徵求日期': '111/02/14 ─ 111/02/16', '聯絡人': '呂秋香', '聯絡電話': '(03)8326686分機812', '電子郵件信箱': 'ghot4528@gamil.com', '內容摘要': '學生宿營活動', '是否提供公開徵求說明文件': '否'}
# 這是第 1 頁，的第 9 項，總共有 564 項，目前進度是 1.5957446808510638 %。
# {'機關代碼': '3.87.40', '機關名稱': '臺中捷運股份有限公司', '機關地址': '406臺中市北屯區松竹路一段1000號', '公告次數': '01', '標案案號': 'B11100013', '標案名稱': '作業環境監測工作（開口契約）', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    一、 本案尚屬【詢價階段】，請將相關報價參考資料（註明廠商名稱、統一編號、連絡電話、傳真號碼、聯絡人）以電子郵件方式寄予本公司聯絡人。\r 二、請廠商提供相關資訊及報價以供參考。\r 三、針對本案規格如有相關疑義或建議敬請聯絡本公司承辦人。', '公開徵求日期': '111/02/14 ─ 111/02/21', '聯絡人': '張志源', '聯絡電話': '(04)24375537分機770311', '電子郵件信箱': 'chihyuan.chang@tmrt.com.tw', '內容摘要': '勞工作業環境監測工作', '是否提供公開徵求說明文件': '是'}
# 這是第 1 頁，的第 10 項，總共有 564 項，目前進度是 1.773049645390071 %。
# {'機關代碼': '3.5.49', '機關名稱': '國防部空軍司令部', '機關地址': '104臺北市中山區北安路387號', '公告次數': '01', '標案案號': '1110214-J001', '標案名稱': '1號軸承等12項', '是否刊登公報': '否', '公告日期': '111/02/14', '附加說明': '公開徵求並非招標公告，如將公開徵求作為招標公告，無效\r\n\t    \n\r\n\t    \r\n\t     \r\n\t    一、品項清單\r1.料號3110012782945、件號5020T26P01、名稱：1號軸承、廠代A99207、數量5EA。\r2.料號3110010538959、件號5040T17P01、名稱：2號軸承、廠代A99207、數量5EA。\r3.料號3110012533236、件號5014T13P06、名稱：3號軸承、廠代A99207、數量5EA。\r4.料號2840010488907、件號5011T74G02、名稱：扭力環、廠代A99207、數量10EA。\r5.料號3110006185880、件號327B430P1、名稱：軸承、廠代A99207、數量25EA。\r6.料號6685012002284、件號5017T99P02、名稱：左熱電偶、廠代A99207、數量10EA。\r7.料號6685012002283、件號5018T01P02、名稱：右熱電偶、廠代A99207、數量10EA。\r8.料號3110008256048、件號841B585P1、名稱：A軸承、廠代A99207、數量10EA。\r9.料號3040004619808、件號5001T56P02、名稱：F軸承、廠代A99207、數量10EA。\r10.料號3040004619862、件號6005T95P04、名稱：B軸齒輪、廠代A99207、數量10EA。\r11.料號2840012459464、件號6041T18G02、名稱：AB一段式內筒、廠代A99207、數量10EA。\r12.料號2840014801741、件號6051T27G03、名稱：AB一段式外機匣、廠代A99207、數量10EA。\r二、上述12項請以信件或傳真提供新品報價(免稅)、交貨期、報價有效期限及能提供之證明文件。\r三、案內品項如可提供適用替代料、件號，亦請於報價時一併說明。\r四、單位名稱：空軍保修指揮部、承辦人：吳佳和；傳真電話：02-25325070(傳真前請先電話告知)。', '公開徵求日期': '111/02/14 ─ 111/03/01', '聯絡人': '吳佳和', '聯絡電話': '(02)25321610分機675316', '電子郵件信箱': 'agar19860303@gmail.com', '內容摘要': '1號軸承等12項新品訪商', '是否提供公開徵求說明文件': '否'}
# 此分頁抓取總耗時： 0:00:04.830351 s
# 564
# 10
# time cost 0:00:01.235980 s
# 爬取日期：111/02/14
# 頁面前往：https://web.pcc.gov.tw/tps/tps/tp/main/pms/tps/tp/commonPublicReadFormListPageControl.do?__PageBase=0&__PageIndex=1
# 這是第 1 頁，的第 1 項，總共有 49 項，目前進度是 2.0408163265306123 %。
# 這是第 1 頁，的第 2 項，總共有 49 項，目前進度是 4.081632653061225 %。
# 這是第 1 頁，的第 3 項，總共有 49 項，目前進度是 6.122448979591836 %。
# 這是第 1 頁，的第 4 項，總共有 49 項，目前進度是 8.16326530612245 %。
# 這是第 1 頁，的第 5 項，總共有 49 項，目前進度是 10.204081632653061 %。
# 這是第 1 頁，的第 6 項，總共有 49 項，目前進度是 12.244897959183673 %。
# 這是第 1 頁，的第 7 項，總共有 49 項，目前進度是 14.285714285714285 %。
# 這是第 1 頁，的第 8 項，總共有 49 項，目前進度是 16.3265306122449 %。
# 這是第 1 頁，的第 9 項，總共有 49 項，目前進度是 18.367346938775512 %。
# 這是第 1 頁，的第 10 項，總共有 49 項，目前進度是 20.408163265306122 %。
# 此分頁抓取總耗時： 0:00:03.995811 s
# 49
# 10
# time cost 0:00:00.716338 s
# 1031.1602647304535

# %%
# global waitt
# waitt =False
# proxies = get_ip_from_db("yes",db_settings)
# x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers)
# send_db(x5,"final", db_settings)
# Out:
# 爬取日期：111/02/14
# 頁面前往：https://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&execLocationArea=&pageIndex=1
#
# <link href="../styles/base.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="../styles/confirm.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# a:visited {
# 	text-decoration: none;
# 	color: #444444;
# }
#
# a:hover {
# 	text-decoration: none;
# 	color: #0066CC;
# }
#
# a:link {
# 	text-decoration: none;
# 	color: #444444;
# }
# </style>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="zh-Hant">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="0" http-equiv="Expires"/>
# <title>政府電子採購網</title>
# <link href="/pis/styles/css_m.css" rel="stylesheet" type="text/css"/>
# <script src="/pis/scripts/jquery-1.3.2.js" type="text/javascript"></script>
# <script src="/pis/scripts/jquery.blockUI.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
#
# var $jq = jQuery.noConflict();
#
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# function MM_swapImage() { //v3.0
#   var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)
#    if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}
# }
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# jQuery(document).ready(function(){
#   jQuery("tr.csubmenu").hide();
#   jQuery("tr.cmainmenu").click(function(){
#      var elem = jQuery(this).next();
#      if (elem.hasClass("csubmenu")) {
#        elem.toggle();
#      }
#      return false;
#   });
# });
#
# //-->
# </script>
# </head>
# <body onload="MM_preloadImages('/pis/images/more01over.jpg','/pis/images/system01over.jpg','/pis/images/system02over.jpg','/pis/images/mainmenu07over.jpg','/pis/images/system04over.jpg','/pis/images/system05over.jpg');">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr>
# <script type="text/javascript">
#
#   jQuery(document).ready(function(){
# //   	lihsuan 20191029加入判定是否為上端導盲磚，若是則不導頁 start
#     jQuery('td.homeevent').click(function(clickEvent) {
#     	var obj = clickEvent.target.nodeName;
#     	if(obj!="A"){
# 	  		location.href = "/pis/index.jsp";
#     	}
# //     	lihsuan 20191029加入判定是否為上端導盲磚，若是則不導頁 End
# 	});
#
#     if(document.getElementById("netTrack") != null){
#     	document.title = "政府電子採購網_" + document.getElementById("netTrack").innerText;
#     }
#
#   });
#
# function goToContentOnFocus(){
# // 	document.getElementById("goToContent").innerText = "跳到主要內容區塊";
#     document.getElementById("goToContent").style.color = "black";
# }
#
# function goToContentOnBlur(){
# // 	document.getElementById("goToContent").innerText = ":";
#     document.getElementById("goToContent").style.color = "white";
#
# }
#
# function goToContentOnKeyUp(event){
# 	if (event.stopPropagation != undefined ) {//非IE
# 		event.stopPropagation();
# 	}else {//IE
# 		window.event.cancelBubble = true;
# 	}
# }
#
# </script>
# <noscript>您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態<a href="/pis/index.jsp" title="回到首頁">回到首頁</a></noscript>
# <td align="right" background="/pis/main/pis/client/pssa/logo_image.do?logo_id=50003000" class="homeevent" colspan="3" height="132" style="cursor: pointer;" title="政府電子採購網" valign="top">
# <a href="#goContent" id="goToContent" onblur="goToContentOnBlur();" onclick="goToContentOnKeyUp(event);" onfocus="goToContentOnFocus();" style="text-decoration:none; position:relative; top:5px; left:-950px; color:white; font-size:13px;" title="跳到主要內容區塊">跳到主要內容區塊</a>
# <a class="ctopfont" href="/pis/index.jsp" style="position: relative; top: 5px; left: -900px" title="回到首頁">回首頁</a>
# <div class="cmap010 ctopfont" style="font-size: 75%; position: relative; top: -14px; left: -40px; width:250px; height:40px;"><a accesskey="U" href="#top_area" id="top_area" name="top_area" title="上方選單連結區，此區塊列有[英文版頁面]、[網站導覽]等連結">:::</a>  <a href="/tps/pss/tender.do?method=goNews" title="Go To English Page">English</a> ｜ <a href="/pis/main/pis/client/pssa/sitemap.do" title="前往 網站導覽">網站導覽</a> ｜ <a href="/pis/main/pis/client/pssa/mail_form.do" title="前往 意見信箱">意見信箱</a> ｜ <a href="http://mgeps.pcc.gov.tw/" title="前往 行動版">行動版</a></div>
# <h1 style="margin:0;" title="政府電子採購網"><span style="font-size:0;">政府電子採購網</span></h1>
# </td>
# </tr>
# <tr>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td rowspan="2"><img alt="" height="5" src="/pis/images/space.gif" width="20"/></td>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr><th id="addThId_a" style="display: none;"></th>
# <td headers="addThId_a">
# <a accesskey="L" href="#left_area" name="left_area" style="color: #999999; text-decoration: none;" title="左方選單連結區，此區塊列有本網站主要連結">:::</a>
# </td>
# </tr>
# <tr>
# <td><img alt="" height="25" src="/pis/images/mainimage.jpg" width="190"/></td>
# </tr>
# <tr>
# <td><a href="/pis/main/pis/client/howto.jsp" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu09','','/pis/images/mainmenu09over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu09','','/pis/images/mainmenu09over.jpg',1);" title="前往 如何使用"><img alt="如何使用" border="0" height="30" name="mainmenu09" src="/pis/images/mainmenu09.jpg" width="190"/></a></td>
# </tr>
# <tr>
# <td><a href="/prkms/frontForumClient.do?action=list" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu11','','/pis/images/mainmenu11over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu11','','/pis/images/mainmenu11over.jpg',1);" title="前往 客戶論壇"><img alt="客戶論壇" border="0" height="40" name="mainmenu11" src="/pis/images/mainmenu11.jpg" width="190"/></a></td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu02','','/pis/images/mainmenu02over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu02','','/pis/images/mainmenu02over.jpg',1);" title="開啟 服務專區"><img alt="服務專區" border="0" height="40" name="mainmenu02" src="/pis/images/mainmenu02.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/ens/main2.jsp" title="前往 電子公報">電子公報</a><br/>
# <a href="/csci/main/faqSearchAction.do?method=list" title="前往 問題檢索">問題檢索</a><br/>
# <a href="/csci/main/hotFaqAction.do?method=list" title="前往 熱門問答集">熱門問答集</a><br/>
# <a href="http://papads.gp.gov.tw/event/feedback.html" title="前往 請求協助">請求協助</a><br/>
# <a href="http://71899.pcc.gov.tw/EgpWeb" target="_blank" title="前往 訂閱電子報(另開視窗)">訂閱電子報</a><br/>
# <a href="/tps/tps/tom/main/tps/tom/verifyToken.do?method=verifyToken&amp;searchMode=common" title="前往 列印領標憑據">列印領標憑據</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu07','','/pis/images/mainmenu07over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu07','','/pis/images/mainmenu07over.jpg',1);" title="開啟 常用查詢"><img alt="常用查詢" border="0" height="40" name="mainmenu07" src="/pis/images/mainmenu07.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=common&amp;searchType=basic" title="前往 標案查詢">標案查詢</a><br/>
# <!-- 2012.04.30 刪除民眾端之「廠商資格查詢」功能 fix by Emma -->
# <!-- <a href="/tps/tps/tbm/main/tps/tbm/queryOdiServiceClient.do?method=init" title="廠商資格查詢">廠商資格查詢</a><br> -->
# <a href="/tps/client/main/cscps/ciom/medicineSearch.do?method=init" title="前往 衛材藥品查詢">衛材藥品查詢</a><br/>
# <a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=priority&amp;searchType=advance" title="前往 優先採購查詢">優先採購查詢</a><br/>
# <a href="/oms/proc_trg_query_init.do" title="前往 採購標的分類">採購標的分類</a><br/>
# <a href="/tps/tps/tp/main/pms/tps/tp/StartProcurementPredict.do?pMenu=common&amp;method=searchProcurementPredict&amp;target=ven" title="前往 採購預告查詢">採購預告查詢</a><br/>
# <a href="/tps/tps/tp/main/pms/tps/tp/NoFormPageLink.do?pMenu=common&amp;method=queryReadFormalData" title="前往 公開閱覽查詢">公開閱覽查詢</a><br/>
# <a href="/tps/tps/tp/main/tps/tp/tp.do?method=initialAppealSearchVendor&amp;pMenu=common" title="前往 公開徵求查詢">公開徵求查詢</a><br/>
# <a href="/opas/pspad/intoSearchForPublic.do" title="前往 公示送達查詢">公示送達查詢</a><br/>
# <a href="/opas/arpam/intoSearchForPublic.do" title="前往 財物出租查詢">財物出租查詢</a><br/>
# <a href="/opas/aspam/intoSearchForPublic.do" title="前往 財物變賣查詢">財物變賣查詢</a><br/>
# <a href="/tps/main/pms/tps/pia/piaQueryActionForPublic.do?method=queryPrice" title="前往 物調公告查詢">物調公告查詢</a><br/>
# <a href="/oms/foreSupp_query_init.do" title="前往 外國廠商代碼">外國廠商代碼</a><br/>
# <a href="/vms/main/stiem/searchPublicStiem.do" title="前往 科技研究機構">科技研究機構</a><br/>
# <a href="/vms/lapeem/generalQuery.do?method=qryReviewPage" title="前往 效益評估查詢">效益評估查詢</a><br/>
# <a href="/vms/jgvm/generalQuery.do?method=queryPage" title="前往 連帶保證廠商">連帶保證廠商</a><br/>
# <a href="/vms/evlm/ViewDisabilitiesQueryEM.do" title="前往 優良廠商名單">優良廠商名單</a><br/>
# <a href="/vms/rvlmd/ViewDisabilitiesQueryRV.do" title="前往 拒絕往來廠商">拒絕往來廠商</a><br/>
# <a href="/vms/rvlmd/ViewDisabilitiesQueryVoidRV.do" title="前往 註銷拒絕往來廠商">註銷拒絕往來廠商</a><br/>
# <a href="/vms/gblm.do?method=gblmList" title="前往 全球化廠商名單">全球化廠商名單</a><br/>
# <a href="/vms/gblmComm/integrated.do?method=search" title="前往 廠商綜合查詢">廠商綜合查詢</a><br/>
# <a href="/tps/pss/tender.do?searchMode=common&amp;searchType=basic&amp;method=goReconstruct" title="前往 災區重建工程案件查詢">災區重建工程案件查詢</a><br/>
# <a href="/vms/lapeem/generalQueryPoli.do?method=qryPoliticsPage" title="前往 政治獻金法第七條查詢">政治獻金法第七條查詢</a><br/>
# <a href="/tpsreport/main/atmAbroad/atmAbroad.do?method=atmAbroadQry4Public&amp;funcType=4" title="前往 得標外國政府採購案件查詢">得標外國政府採購案件查詢</a><br/>
# <a href="http://www.bot.com.tw/Procurement/Procure_supply/Supply_qna/Pages/default.aspx" target="_blank" title="前往 臺灣銀行集中採購簡介(另開視窗)">臺灣銀行集中採購簡介</a><br/>
# <a href="/tps/thd/thdAction.do?menuMode=common&amp;method=search" title="前往 歷史文件瀏覽">歷史文件瀏覽</a><br/>
# <a href="/tps/pur/PurQueryPeople.do?method=toPurQueryPeople" title="前往 採購評選委員名單">採購評選委員名單</a><br/>
# <a href="/pis/main/pis/client/bsmizone.do" title="前往 商品檢驗查詢">商品檢驗查詢</a><br/>
# <a href="/piat_piahm/dispute/public/oneOone.do?method=index" title="政府採購法第101條停權案例">政府採購法第101條停權案例</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu08','','/pis/images/mainmenu08over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu08','','/pis/images/mainmenu08over.jpg',1);" title="開啟 國外採購"><img alt="國外採購" border="0" height="40" name="mainmenu08" src="/pis/images/mainmenu08.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="http://gpa.taiwantrade.com.tw/" target="_blank" title="前往 全球政府採購商機(另開視窗)">全球政府採購商機</a><br/>
# <a href="https://www.pcc.gov.tw/cp.aspx?n=49F759CB03E9FCFF" target="_blank" title="前往 外國政府採購網站(另開視窗)">外國政府採購網站</a><br/>
# <a href="/tps/fd/fd.do?method=goSearch" title="前往 外國政府採購商情">外國政府採購商情</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu03','','/pis/images/mainmenu03over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu03','','/pis/images/mainmenu03over.jpg',1);" title="開啟 教育訓練"><img alt="教育訓練" border="0" height="40" name="mainmenu03" src="/pis/images/mainmenu03.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="/psms/pptom/searchTrainingOrgForPublic.do" title="前往 代訓機構名單">代訓機構名單</a><br/>
# <a href="/psms/trainingclass/searchForPublicTrainingClass.do" title="前往 代訓機構開課">代訓機構開課</a><br/>
# <a href="/psms/question/searchQuestionForPublic.do" title="前往 採購法規題庫">採購法規題庫</a><br/>
# <a href="/training/signUp.do?method=init" title="前往 廠商課程線上報名">廠商課程線上報名</a><br/>
# <a href="/psms/plrtm/certificate.do" title="前往 採購專業人員及格證書查詢">採購專業人員及格證書查詢</a><br/>
# <a href="/psms/plrtm/certificateReissue.do" title="前往 採購專業人員及格證書補發申請">採購專業人員及格證書補發申請</a>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu04','','/pis/images/mainmenu04over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu04','','/pis/images/mainmenu04over.jpg',1);" title="開啟 知識管理"><img alt="知識管理" border="0" height="40" name="mainmenu04" src="/pis/images/mainmenu04.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <!--
#       <a href="/prkms/tenderdocClient.do?action=list" title="招標文件">招標文件</a><br>
#       -->
# <a href="/prkms/largeprocureClient.do?action=list" title="前往 巨額效益">巨額效益</a><br/>
# <!--
#       <a href="http://epm.gp.gov.tw/default.aspx" title="旗艦計畫" target="_blank">旗艦計畫</a>
#       -->
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu05','','/pis/images/mainmenu05over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu05','','/pis/images/mainmenu05over.jpg',1);" title="開啟 下載專區"><img alt="下載專區" border="0" height="40" name="mainmenu05" src="/pis/images/mainmenu05.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="https://www.pcc.gov.tw/cp.aspx?n=99E24DAAC84279E4" target="_blank" title="前往 招標文件範本(另開視窗)">招標文件範本</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003004" title="前往 拒絕往來名單">拒絕往來名單</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000003" title="前往 系統使用手冊">系統使用手冊</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000005" title="前往 2 代採購教材">2 代採購教材</a><br/>
# <a href="https://web.pcc.gov.tw/pis/main/pis/client/b_wait.html" target="_blank" title="前往 等標期(另開視窗)">等標期</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=42000000" title="前往 共同供應契約">共同供應契約</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=20000004" title="前往 常用工具下載">常用工具下載</a><br/>
# <a href="https://web.pcc.gov.tw/tpsreport/transfer/dataTransfer.do?method=getOkfnOpenDataXml" target="_blank" title="前往 資料集下載(另開視窗)">資料集下載</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003000" title="前往 重要訊息通告">重要訊息通告</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003002" title="前往 ５都改制文件">５都改制文件</a><br/>
# <a href="/pis/main/pis/client/pssa/downloadFiles.do?id=50003006" title="前往 中央組改文件 ">中央組改文件 </a><br/>
# </td>
# </tr>
# <tr class="cmainmenu">
# <td><a href="#" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu06','','/pis/images/mainmenu06over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu06','','/pis/images/mainmenu06over.jpg',1);" title="開啟 相關連結"><img alt="相關連結" border="0" height="40" name="mainmenu06" src="/pis/images/mainmenu06.jpg" width="190"/></a></td>
# </tr>
# <tr class="csubmenu">
# <td>
# <a href="http://gca.nat.gov.tw/" target="_blank" title="前往 政府憑證管理中心(另開視窗)">政府憑證管理中心</a><br/>
# <a href="https://xca.nat.gov.tw/" target="_blank" title="前往 組織及團體憑證管理中心(另開視窗)">組織及團體憑證管理中心</a><br/>
# <a href="http://moeaca.nat.gov.tw/" target="_blank" title="前往 工商憑證管理中心(另開視窗)">工商憑證管理中心</a><br/>
# <a href="http://moica.nat.gov.tw/" target="_blank" title="前往 自然人憑證管理中心(另開視窗)">自然人憑證管理中心</a><br/>
# <a href="http://cmdweb.pcc.gov.tw/pccms/owa/cmdmang.userin" target="_blank" title="前往 工程標案管理系統(另開視窗)">工程標案管理系統</a><br/>
# <a href="http://cmdweb.pcc.gov.tw/pccms/owa/pwksafe3.userin" target="_blank" title="前往 工程不當延遲付款通報(另開視窗)">工程不當延遲付款通報</a><br/>
# <a href="https://ppp.mof.gov.tw/WWW/inv_ann.aspx" target="_blank" title="前往 促進民間參與公共建設公告(另開視窗)">促進民間參與公共建設公告</a><br/>
# <a href="https://pe2sys.pcc.gov.tw/Public/index.aspx" target="_blank" title="前往 技師與工程技術顧問公司管理資訊系統(另開視窗)">技師與工程技術顧問公司管理資訊系統</a><br/>
# <a href="http://cpabm.cpami.gov.tw/index.jsp" target="_blank" title="前往 營建署全國建築管理資訊入口網(另開視窗)">營建署全國建築管理資訊入口網</a><br/>
# <a href="https://gcis.nat.gov.tw/mainNew/" target="_blank" title="前往 經濟部商工行政服務入口網(另開視窗)">經濟部商工行政服務入口網</a><br/>
# <a href="http://www.etax.nat.gov.tw" target="_blank" title="前往 財政部稅務入口網(另開視窗)">財政部稅務入口網</a><br/>
# <a href="http://www.energylabel.org.tw/purchasing/govgreen/list.asp" target="_blank" title="前往 環保署節能標章綠色採購網(另開視窗)">環保署節能標章綠色採購網</a><br/>
# <a href="http://dpws.sfaa.gov.tw/commonch/index.jsp" target="_blank" title="前往 衛生福利部社會及家庭署身心障礙服務入口網(另開視窗)">衛生福利部社會及家庭署身心障礙服務入口網</a><br/>
# <a href="http://cpabm.cpami.gov.tw/wor-inx/" target="_blank" title="前往 營建署工程重機械編管及運用管理系統(另開視窗)">營建署工程重機械編管及運用管理系統</a><br/>
# <a href="/pis/main/pis/client/lrs/links.do?id=50003006" title="前往 經濟部投審會公告陸資資訊">經濟部投審會公告陸資資訊</a><br/>
# <a href="http://www.mine.gov.tw/" target="_blank" title="前往 經濟部礦務局(另開視窗)">經濟部礦務局</a><br/>
# <a href="https://cmdweb.pcc.gov.tw/pccms/owa/pwksafe.statmenu" target="_blank" title="前往 承攬廠商公共工程履歷資料(另開視窗)">承攬廠商公共工程履歷資料</a><br/>
# <a href="https://pe2sys.pcc.gov.tw/Public/EGR/Report1.aspx?progid=EGR_2_2_1&amp;rn=1096301101" target="_blank" title="前往 技師懲戒資料(另開視窗)">技師懲戒資料</a><br/>
# <a href="http://cpabm.cpami.gov.tw/SearchPage2.jsp?url=/search/clis/queryClscogn.jsp" target="_blank" title="前往 內政部營建署營造業評鑑結果查詢(另開視窗)">內政部營建署營造業評鑑結果查詢</a><br/>
# <a href="/pis/main/pis/client/lrs/links.do?id=50003007" title="前往 行政法人相關採購資訊">行政法人相關採購資訊</a><br/>
# </td>
# </tr>
# <tr>
# <td><a href="/ars/wr/wrclient.do" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('mainmenu12','','/pis/images/mainmenu12over.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('mainmenu12','','/pis/images/mainmenu12over.jpg',1);" title="前往 採購統計"><img alt="採購統計" border="0" height="40" name="mainmenu12" src="/pis/images/mainmenu12.jpg" width="190"/></a></td>
# </tr>
# <tr>
# <td><img alt="" height="10" src="/pis/images/mainmenudown.jpg" width="190"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="10%">
# <tr>
# <td align="center"><a href="https://web.pcc.gov.tw/pis/main/pis/client/lrs/links.do?id=50003007" title="前往 行政法人相關採購資訊"><img alt="行政法人相關採購資訊" border="0" src="/pis/images/banner07.jpg" style="margin-bottom:2px" width="170"/></a></td>
# </tr>
# <tr>
# <td>
# <a href="http://71899.pcc.gov.tw/EgpWeb/" onblur="MM_swapImgRestore();" onfocus="MM_swapImage('Image12','','/pis/images/serviceover.jpg',1);" onmouseout="MM_swapImgRestore();" onmouseover="MM_swapImage('Image12','','/pis/images/serviceover.jpg',1);" target="_blank" title="前往 訂閱加值服務(另開視窗)">
# <img alt="訂閱加值服務(另開視窗)" border="0" height="63" name="Image12" src="/pis/images/service.jpg" width="190"/>
# </a>
# </td>
# </tr>
# <tr>
# <td align="center"><a href="/tps/pss/tender.do?method=goSearch&amp;searchMode=priority&amp;searchType=advance" title="前往 優先採購"><img alt="優先採購" border="0" height="55" src="/pis/images/index_buy.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="/pis/main/pis/client/aborigineszone.do?method=goInit" title="前往 「購買原住民及身心障礙者所提供之產品或勞務」採購專區平台"><img alt="「購買原住民及身心障礙者所提供之產品或勞務」採購專區平台" border="0" src="/pis/images/banner05.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="https://web.pcc.gov.tw/raam/registerCorp.do?method=goRegisterCorp" title="前往 法人團體帳號申請"><img alt="法人團體帳號申請" border="0" height="53" src="/pis/images/banner01.jpg" width="170"/></a></td>
# </tr>
# <tr>
# <td align="center"><a href="/applet/env_test.html" style="font-size: 110%; color: #FF6600;" target="_blank" title="前往 安裝程式環境檢測(另開視窗)"><img alt="安裝程式環境檢測(另開視窗)" border="0" height="59" src="/pis/images/index7_73.jpg" width="179"/></a></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# <td align="center" colspan="2" id="page" valign="top" width="772">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td valign="top"><img alt="" height="4" src="/pis/images/space.gif" width="7"/></td>
# <td valign="top">
# <img alt="" height="4" src="/pis/images/space.gif" width="772"/>
# <div id="goContent"></div>
# <script src="../scripts/tenderSearch.js" type="text/javascript"></script>
# <div id="confirm_box" style="display: none; cursor: default"><span id="confirm_message" style="font-weight: bold;"></span> <br>
# <br>
# <input class="titlefont80" id="yes" type="button" value="確認"/> <input class="titlefont80" id="no" onclick="$jq.unblockUI()" type="button" value="關閉"/></br></br></div>
# <form action="./tender.do?searchMode=common" method="post" name="TenderActionForm"><input name="method" type="hidden" value="search"/><input name="searchMethod" type="hidden" value="true"/><input name="searchType" type="hidden" value="advance"/><input name="tenderName" type="hidden" value=""/><input name="searchTarget" type="hidden" value="ATM"/></form>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <caption style="display:none">標案查詢</caption>
# <tr>
# <td colspan="2" valign="top"><img alt="" height="5" src="../images/space.gif" width="758"/></td>
# </tr>
# <tr>
# <td align="left" colspan="2">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td><span class="croot"><a accesskey="C" href="#center_area" name="center_area" title="網頁內容資料呈現區">:::</a></span><img alt="" height="13" src="../images/root01.gif" width="14"/> <span class="croot" id="netTrack"><a href="/pis/main/pis/client/index.do" title="首頁">首頁</a>&gt;標案查詢<h2 class="croot" style="display: inline-flex;margin:0px;"><img alt="標案查詢" height="0" src="../images/space.gif" width="0"/></h2></span></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td background="../images/home_title.jpg" colspan="2" style="background-repeat: no-repeat;">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td width="1%"><img alt="*" height="55" src="../images/space.gif" width="80"/></td>
# <td align="left" class="ctitlefont80" style="padding-left: 10px;">標案查詢</td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td colspan="2" valign="middle">
# <table align="left">
# <tr><td>註：</td><td><font color="red">◎</font> 檢視決標公告，請點選決標公告欄位下方之序號，如決標公告001<br/></td></tr>
# <tr><td></td><td><font color="red">◎</font> 查詢結果依決標公告日期遞減排序,即最新公告之標案在最上方</td></tr>
# </table>
# </td>
# </tr>
# <tr>
# <td colspan="2" valign="middle">
# <table border="0" cellpadding="4" cellspacing="0" width="95%">
# <tr>
# <td align="left" valign="top"></td>
# </tr>
# <tr>
# <td align="right">
# <!-- <img src="/tps/images/print.jpg" alt="友善列印" width="16" height="16"><input name="button5" type="button" class="T11c" id="button5" value="友善列印" onClick="popWatermark2();print_doc();popWatermark();"> -->
# <script>
# 							document.write("<img src='/tps/images/print.jpg' alt='友善列印' width='16' height='16'><input name='button5' type='button' class='T11c' id='button5' value='友善列印' onClick='popWatermark2();print_doc();popWatermark();'>");
# 							</script>
# </td>
# </tr>
# <tr>
# <td bgcolor="#98BADC">
# <table align="center" bgcolor="#FFFFFF" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr>
# <td>
# <div id="print_area">
# <table border="0" cellpadding="0" cellspacing="0" style="word-break:break-all" width="100%">
# <tr>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">項次 </th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="15%">機關 <br>名稱 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="30%">標案案號 <br>標案名稱 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="10%">招標 <br>方式 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="8%">標的 <br>分類 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="9%">公告 <br>日期 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="13%">決標 <br>金額 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">決標 <br>公告 </br></th>
# <th align="center" bgcolor="#E0EDF1" class="T12b" nowrap="" width="5%">無法 <br>決標 </br></th>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">1 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市政府警察局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												11152
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648648" title="111年度刑案勘察用燈具及配件採購案">
# <u>111年度刑案勘察用燈具及配件採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648648" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">2 </td>
# <!-- 機關名稱 -->
# <td align="left">南臺學校財團法人南臺科技大學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												11K000006
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648629" title="數位式HDMI數位影音傳遞系統">
# <u>數位式HDMI數位影音傳遞系統</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648629" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">3 </td>
# <!-- 機關名稱 -->
# <td align="left">交通部航港局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												MPB111C0207A
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648620" title="高雄市1筆不動產委託估價專業服務採購案">
# <u>高雄市1筆不動產委託估價專業服務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648620" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">4 </td>
# <!-- 機關名稱 -->
# <td align="left">衛生福利部南投醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												MED111-04
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648615" title="111年Ozempic藥品採購案">
# <u>111年Ozempic藥品採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648615" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">5 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市政府衛生局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												S11111
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648554" title="111年度自殺防治宣導活動">
# <u>111年度自殺防治宣導活動</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648554" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">6 </td>
# <!-- 機關名稱 -->
# <td align="left">國軍退除役官兵輔導委員會臺東農場</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111TF02
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648545" title="花蓮縣吉安鄉廣榮段3646、3647、3648地號3筆土地上設備拆卸工程">
# <u>花蓮縣吉安鄉廣榮段3646、3647、3648地號3筆土地上設備拆卸工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648545" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">7 </td>
# <!-- 機關名稱 -->
# <td align="left">苗栗縣三義鄉公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1110D0000304
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648521" title="111年度三義鄉標誌標線反射鏡改善工程(開口契約)">
# <u>111年度三義鄉標誌標線反射鏡改善工程(開口契約)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648521" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">8 </td>
# <!-- 機關名稱 -->
# <td align="left">嘉義縣朴子市朴子國民小學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1110207
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648520" title="嘉義縣朴子市朴子國民小學111年度保全替代人力委外勞務承攬採購案">
# <u>嘉義縣朴子市朴子國民小學111年度保全替代人力委外勞務承攬採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648520" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">9 </td>
# <!-- 機關名稱 -->
# <td align="left">新北市立溪崑國民中學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												F11101
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648505" title="111年度增購體育訓練設備設施">
# <u>111年度增購體育訓練設備設施</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648505" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">10 </td>
# <!-- 機關名稱 -->
# <td align="left">苗栗縣政府</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												110324d
#
# 												<font color="red">(更正公告)</font>
# <br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53609737" title="西湖鄉119線11K+600道路擋土牆及護欄工程">
# <u>西湖鄉119線11K+600道路擋土牆及護欄工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53609737" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">11 </td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1112B001
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648476" title="冷凍切片機一台">
# <u>冷凍切片機一台</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648476" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">12 </td>
# <!-- 機關名稱 -->
# <td align="left">高雄榮民總醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LP-11183
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648415" title="三人座沙發及單人座沙發5組">
# <u>三人座沙發及單人座沙發5組</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648415" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">13 </td>
# <!-- 機關名稱 -->
# <td align="left">高雄榮民總醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LP-11317
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648414" title="煮飯箱1台">
# <u>煮飯箱1台</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648414" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">14 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市立聯合醫院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												S111010
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648410" title="電針機一批採購案">
# <u>電針機一批採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648410" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">15 </td>
# <!-- 機關名稱 -->
# <td align="left">中華郵政股份有限公司屏東郵局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111020101
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648338" title="屏東郵局111年硬幣棉布袋採購案">
# <u>屏東郵局111年硬幣棉布袋採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648338" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">16 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市信義區健康服務中心</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111C01
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648321" title="111年信義區防疫工時人員勞務採購案">
# <u>111年信義區防疫工時人員勞務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648321" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">17 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A013
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648288" title="玉山里田洋(第四鄰)AC路面改善工程">
# <u>玉山里田洋(第四鄰)AC路面改善工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648288" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">18 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A005
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648287" title="110年度0605豪雨南化區北平里過嶺農路災後復建工程">
# <u>110年度0605豪雨南化區北平里過嶺農路災後復建工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648287" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">19 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市政府警察局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111SA0119-3
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648285" title="111年度警報器系統設備維修保養採購案">
# <u>111年度警報器系統設備維修保養採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648285" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">20 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市南化區公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111A006
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648283" title="北平里芭拉湖農路(尖山高分19左12)路面改善工程等二件">
# <u>北平里芭拉湖農路(尖山高分19左12)路面改善工程等二件</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648283" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">21 </td>
# <!-- 機關名稱 -->
# <td align="left">臺南市政府警察局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												111SA0119-1
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648276" title="20馬力交流警報器採購案">
# <u>20馬力交流警報器採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得電子報價單</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648276" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">22 </td>
# <!-- 機關名稱 -->
# <td align="left">衛生福利部樂生療養院</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												lslp-2542-11103
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648264" title="生物醫療廢棄物再利用處理一式">
# <u>生物醫療廢棄物再利用處理一式</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648264" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">23 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市南港區南港國民小學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												11103
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648263" title="行動學習智慧教學計畫平板電腦採購案">
# <u>行動學習智慧教學計畫平板電腦採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648263" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">24 </td>
# <!-- 機關名稱 -->
# <td align="left">嘉義縣中埔鄉公所</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1100098
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648253" title="社口村內灣橋上方護岸復建工程等2件工程">
# <u>社口村內灣橋上方護岸復建工程等2件工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53648253" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">25 </td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學生物資源暨農學院實驗林管理處</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												LCJ11102
#
# 												<br/>
# ...
# <u>111年度鍋爐暨密閉式冷卻水質處理技術材料採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													905,000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647669&amp;tenderCaseNo=F11101" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
#
# 												</td>
# </tr>, <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">96 </td>
# <!-- 機關名稱 -->
# <td align="left">臺北市政府消防局</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												651911102
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647727&amp;tenderCaseNo=651911102" title="111年度應勤用品採購案">
# <u>111年度應勤用品採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													786,950
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647727&amp;tenderCaseNo=651911102" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
#
# 												</td>
# </tr>, <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">97 </td>
# <!-- 機關名稱 -->
# <td align="left">新北市政府採購處</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												1101229A
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647162&amp;tenderCaseNo=1101229A" title="111年度新北市政府新建工程處辦理用地取得市價評估委託專業服務(A、B區)">
# <u>111年度新北市政府新建工程處辦理用地取得市價評估委託專業服務(A、B區)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">經公開評選或公開徵求之限制性招標</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													6,139,000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647162&amp;tenderCaseNo=1101229A" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
#
# 												</td>
# </tr>, <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">98 </td>
# <!-- 機關名稱 -->
# <td align="left">行政院農業委員會農田水利署</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												HC1101202
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647716&amp;tenderCaseNo=HC1101202" title="油羅圳幹線改善工程">
# <u>油羅圳幹線改善工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2,028,900
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647716&amp;tenderCaseNo=HC1101202" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
#
# 												</td>
# </tr>, <tr bgcolor="#FFFFFF" onmouseout="outcss(this,'#FFFFFF');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">99 </td>
# <!-- 機關名稱 -->
# <td align="left">國立中央大學</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												SJ1100908003
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647277&amp;tenderCaseNo=SJ1100908003" title="環校道路AC路面改善工程">
# <u>環校道路AC路面改善工程</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">工程類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													28,568,000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=53647277&amp;tenderCaseNo=SJ1100908003" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
#
# 												</td>
# </tr>, <tr bgcolor="#D6FAC5" onmouseout="outcss(this,'#D6FAC5');" onmouseover="overcss(this);">
# <!-- 項次 -->
# <td align="center">100 </td>
# <!-- 機關名稱 -->
# <td align="left">交通部民用航空局飛航服務總臺</td>
# <!-- 標案案號&標案名稱 -->
# <td align="left">
# 												A1100845KH195CW
#
# 												<br/>
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53647010" title="汰換高雄機場及壽山機房數位微波系統採購案">
# <u>汰換高雄機場及壽山機房數位微波系統採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">財物類</td>
# <!-- 公告日期 -->
# <td align="center">111/02/14
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
#
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&amp;method=nonAwardContentForPublic&amp;pkAtmMain=53647010" title="001">
# <u>001</u>
# </a>
#
#
# 												</td>
# </tr>, <tr>
# <td align="center" bgcolor="#E0EDF1" class="T11" colspan="11">
# 											[第一頁/上一頁]
#
# 												&lt;<b>1</b>&gt;
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=2&amp;execLocationArea=" style="color: #444444;"><b>2</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=3&amp;execLocationArea=" style="color: #444444;"><b>3</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=4&amp;execLocationArea=" style="color: #444444;"><b>4</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=5&amp;execLocationArea=" style="color: #444444;"><b>5</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=6&amp;execLocationArea=" style="color: #444444;"><b>6</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=7&amp;execLocationArea=" style="color: #444444;"><b>7</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=8&amp;execLocationArea=" style="color: #444444;"><b>8</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=9&amp;execLocationArea=" style="color: #444444;"><b>9</b></a>
#
#
#
# 												,
#
#
# 													<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=10&amp;execLocationArea=" style="color: #444444;"><b>10</b></a>
#
#
# 											 [
# 												<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=2&amp;execLocationArea=" style="color: #444444;">下一頁</a>
# 											/
# 												<a href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=11&amp;execLocationArea=" style="color: #444444;">最後一頁</a>
# 											] 共有<span class="T11b" style="color: red;">1067</span>筆資料</td>
# </tr>]
# 這是第 1 頁，的第 1 項，總共有 1067 項，目前進度是 0.09372071227741331 %。
# main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648648
# https://149.19.224.35:3128
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648648 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))
# 還剩餘 22 個proxy
# https://149.19.224.38:3128
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648648 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))
# 還剩餘 21 個proxy
# https://159.65.69.186:9300
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648648 (Caused by ProxyError('Cannot connect to proxy.', timeout('timed out')))
# 還剩餘 20 個proxy
# https://186.233.186.60:8080
# 內頁連線數：4
# 3.79.13
# 此細項已抓取完成，總耗時： 0:00:15.342273 s
# ------------------------------------
# 這是第 1 頁，的第 2 項，總共有 1067 項，目前進度是 0.18744142455482662 %。
# main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648629
# https://186.233.186.60:8080
# 內頁連線數：1
# 3.10.90.19
# 此細項已抓取完成，總耗時： 0:00:03.099464 s
# ------------------------------------
# 這是第 1 頁，的第 3 項，總共有 1067 項，目前進度是 0.28116213683223995 %。
# main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648620
# https://186.233.186.60:8080
# HTTPSConnectionPool(host='web.pcc.gov.tw', port=443): Max retries exceeded with url: /tps/main/pms/tps/atm/atmNonAwardAction.do?searchMode=common&method=nonAwardContentForPublic&pkAtmMain=53648620 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001647EA2DE50>, 'Connection to 186.233.186.60 timed out. (connect timeout=10)'))
# 還剩餘 19 個proxy
# https://192.3.116.131:6689
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# D:\Program Files\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-92f837779172> in <module>
#       2 waitt =False
#       3 proxies = get_ip_from_db("yes",db_settings)
# ----> 4 x5 = gov_serach_crawler("final",proxies,db_settings, headers = headers)
#       5 send_db(x5,"final", db_settings)
#
# <ipython-input-50-0a0e7b718d9c> in gov_serach_crawler(url_type, proxies, db_settings, headers, cookies, account, password, start_page)
#     380                             proxies = get_ip_from_db("yes",db_settings)
#     381                         #(detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers)
# --> 382                     (detail_data,detail_data_html,proxies,refresh_proxies) = get_tenderDeclaration_detail(detail_connect,proxies,refresh_proxies,headers,typee="final")
#     383                     str_detail_data_html=str(detail_data_html)
#     384                     if len(detail_data)>0 and (re.search(bid_no,str_detail_data_html) or re.search(proposer_name,str_detail_data_html)):
#
# <ipython-input-45-e56970fe404e> in get_tenderDeclaration_detail(href, proxies, refresh_proxies, headers, typee)
#      16             proxies[0]['qual_ratio'] = proxies[0]['successful_connect_times'] / proxies[0]['connect_times']
#      17
# ---> 18             r = s.get(url_detail + href, headers = headers,verify=False,proxies={'https':proxies[0]['proxyIp']}, timeout=10)
#      19             if re.match(r'.*validate.*',r.url, flags=0):
#      20                 print("準備執行驗證")
#
# D:\Program Files\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# D:\Program Files\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\Program Files\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# D:\Program Files\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# D:\Program Files\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     660             )
#     661             if is_new_proxy_conn:
# --> 662                 self._prepare_proxy(conn)
#     663
#     664             # Make the request on the httplib connection object.
#
# D:\Program Files\anaconda3\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     946         """
#     947         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 948         conn.connect()
#     949
#     950     def _new_conn(self):
#
# D:\Program Files\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     332     def connect(self):
#     333         # Add certificate verification
# --> 334         conn = self._new_conn()
#     335         hostname = self.host
#     336
#
# D:\Program Files\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     154
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# D:\Program Files\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %%
# db_settings = {
#     "host": "60.250.109.71",
#     "port": 23306,
#     "user": "xuan",
#     "password": "Qaz123",
#     "db": "tender",
#     "charset": "utf8mb4",
#     "autocommit":True
# }

# headers = {
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
#     "Accept-Encoding": "gzip, deflate, br", 
#     "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
#     "Host": "web.pcc.gov.tw",  #目標網站 
#     "Sec-Fetch-Dest": "document", 
#     "Sec-Fetch-Mode": "navigate", 
#     "Sec-Fetch-Site": "same-origin", 
#     "Upgrade-Insecure-Requests": "?1", 
#      #使用者代理
# }

# time_start = time.time()
# proxies = get_ip_from_db("yes",db_settings)
# try:
#     x1 = gov_serach_crawler("tenderDeclaration",proxies,db_settings, headers = headers)
#     x2 = gov_serach_crawler("searchAppeal",proxies,db_settings, headers = headers)
#     x3 = gov_serach_crawler("publicRead",proxies,db_settings, headers = headers)
#     time_d = time.time()
# except Exception as ex:
#     print(ex)
#     time_d = time.time()
# time_c = time_d - time_start
# print(time_c)
# send_db(x1, db_settings)
# send_db(x2, db_settings)
# send_db(x3, db_settings)

# %%
# s = rq.session()
# ss = datetime.datetime(2020, 1, 28)
# e = datetime.datetime(2021, 6, 28)
# xx = search_by_date(s,ss, e,'no')
# xxx = date_serach_crawler(s,xx)

# db_settings = {
#     "host": "60.250.109.71",
#     "port": 23306,
#     "user": "xuan",
#     "password": "Qaz123",
#     "db": "tender",
#     "charset": "utf8mb4",
#     "autocommit":True
# }
# data_class="date_search_by_date"
# send_db_2(xxx,data_class, db_settings)
