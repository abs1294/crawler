# %%
from lxml import parser
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-53abf3e2331f> in <module>
# ----> 1 from lxml import parser
#
# ImportError: cannot import name 'parser' from 'lxml' (D:\Program Files\anaconda3\lib\site-packages\lxml\__init__.py)

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""

# %%
import requests as rq
from bs4 import BeautifulSoup

# %%
url = "https://www.ptt.cc/bbs/sex/index.html" # PTT sex 板
response = rq.get(url,cookies={'over18': '1'}) # 用 requests 的 get 方法把網頁抓下來，西斯版規定18歲才准進入，你要告訴他(發送 cookie)，滿18了
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器('html.parser'是python內置的)，另外還有"html5lib"
print(soup.prettify()) # 把排版後的 html 印出來
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 sex 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script async="" src="/cdn-cgi/bm/cv/2172558837/api.js">
#   </script>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
# ...

# %%
# 一些屬性或方法  取標籤
print(soup.head)
print("---")
print(soup.head.title)
print("---")
print(soup.title) # 把 <tag>這個標籤取出來 抓出來
print("---")
print(soup.title.name) # 把 title 的 tag 名稱抓出來
print("---")
print(soup.title.string) # 把 title tag 的內容抓出來
print("---")
print(soup.title.parent.parent.name) # title tag 的上一層 tag
print("---")
print(soup.a) # 把第一個 <a></a> 抓出來
print("---")
print(soup.find_all('a')) # 把所有的 <a></a> 抓出來
print("---")
print(type(soup.a))
print("---")
print(soup.a.name) # 抓標籤名 a
print("---")
print(soup.a['id']) # 抓<a></a>的 id 名稱
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 sex 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# ---
# <title>看板 sex 文章列表 - 批踢踢實業坊</title>
# ---
# <title>看板 sex 文章列表 - 批踢踢實業坊</title>
# ---
# title
# ---
# 看板 sex 文章列表 - 批踢踢實業坊
# ---
# html
# ---
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# ---
# ...

# %%
print(soup.a.name) # 抓標籤名 a
print("---")
print(soup.a['id']) # 抓<a></a>的 id 名稱
dfh= 'https://www.ptt.cc'+soup.a["href"]
dfh
type(soup.a["href"])
# Out:
# a
# ---
# logo
# str

# %%
type(soup.find_all('a'))
# Out:
# bs4.element.ResultSet

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.body.a.contents)
print(list(soup.body.a.children))
print(soup.body.a.string)
# Out:
# ['批踢踢實業坊']
# ['批踢踢實業坊']
# 批踢踢實業坊

# %%
soup.body
# Out:
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/sex/index.html"><span class="board-label">看板 </span>sex</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/sex/index.html">看板</a>
# <a class="btn" href="/man/sex/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/sex/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/sex/index4004.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/sex/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# ...

# %%
print(soup.title.string) 
print(soup.a.string) 
print(soup.find_all('a')[5].string) 
print(soup.body.a.contents)
print(list(soup.body.a.children))
print(soup.body.a.string)
# Out:
# 看板 sex 文章列表 - 批踢踢實業坊
# 批踢踢實業坊
# 精華區
# ['批踢踢實業坊']
# ['批踢踢實業坊']
# 批踢踢實業坊

# %%
asd=soup.find_all("div", class_= "r-ent")[3]
asd
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">25</span></div>
# <div class="title">
# <a href="/bbs/sex/M.1583489767.A.EC3.html">[閒聊] 女友是jojo粉怎麼辦</a>
# </div>
# <div class="meta">
# <div class="author">Gazooli</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/sex/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E5%A5%B3%E5%8F%8B%E6%98%AFjojo%E7%B2%89%E6%80%8E%E9%BA%BC%E8%BE%A6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/sex/search?q=author%3AGazooli">搜尋看板內 Gazooli 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>

# %% [markdown]
# [Python初學重點 (04) – 聊聊print()](https://extenshu.com/2017/09/24/python%E5%88%9D%E5%AD%B8%E9%87%8D%E9%BB%9E-04-%E8%81%8A%E8%81%8Aprint/)

# %%
import requests as rq
from bs4 import BeautifulSoup
#想要知道ptt板上的推文、推文數、日期

def pttcrawler(url):
    response = rq.get(url,cookies={'over18': '1'})
    html_doc = response.text
    soups = BeautifulSoup(html_doc, 'lxml')
    
    articles = []
    #i=0

    for s in soups.find_all("div", class_= "r-ent"):
        if (s.find('a')):
            #requests.get() 的結果是 request.Response 物件, 我們可以先透過該物件的 statu_code 屬性取得 server 回覆的狀態碼
            #(例如 200 表示正常, 404 表示找不到網頁等), 若狀態碼為 200, 代表正常回應
            date=s.find("div",class_= "date").string
            name=s.find('a').string
            push=s.find("div",class_= "nrec").string
            articles.append({'title': name,'push': push,'date': date})       
    return articles
# and (response.status_code == 200)

# %%
url=input("請輸入網址>>")
#pages=input()
aj=pttcrawler(str(url))
# Out:
# 請輸入網址>>https://www.ptt.cc/bbs/sex/index.html

# %%
import pandas as pd
ajj=pd.DataFrame(aj)
ajj.to_excel("1.xls")

# %%
cd
# Out:
# C:\Users\USER

# %%
#我要翻頁!!!!!!更改url
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
#想要知道ptt板上的推文、推文數、日期

def pttcrawler(url,pages,want_excel=False):
    response = rq.get(url,cookies={'over18': '1'})
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'lxml')
    
    articles = []
    
    for s in soup.find_all("div", class_= "r-ent"):
        if (s.find('a')) and (response.status_code == 200):
            #requests.get() 的結果是 request.Response 物件, 我們可以先透過該物件的 statu_code 屬性取得 server 回覆的狀態碼
            #(例如 200 表示正常, 404 表示找不到網頁等), 若狀態碼為 200, 代表正常回應
            date=s.find("div",class_= "date").string
            name=s.find('a').string
            push=s.find("div",class_= "nrec").string
            author=s.find("div",class_= "author").string
            url=s.find("div",class_= "title").a["href"]
            articles.append({'title': name,'push': push,'date': date,'author': author,'url': "https://www.ptt.cc"+url}) 
            
    soup2="https://www.ptt.cc"+soup.find_all(class_="btn wide")[1]["href"]#第二個([1])class是"btn wide"之下的href值
    
    try:
        int(soup2[-9:-5])
    except:
        try:
            int(soup2[-8:-5])
        except:
            last_num=-7
        else:
            last_num=-8
    else:
        last_num=-9
    print( last_num)
    
    for p in range(0,pages):
        new_soup=soup2.replace(soup2[ last_num:-5],str(int(soup2[ last_num:-5])-p))#也可使用序列切片的方式。
        #string = 'abcdafg'  newstr = string[:4] + 'e' + string[5:]         [-9:-5]=str(int(soup2[-9:-5])-p)
        response2 = rq.get(new_soup,cookies={'over18': '1'})
        html_doc2 = response2.text
        soups = BeautifulSoup(html_doc2, 'lxml')
        
        for ns in soups.find_all("div", class_= "r-ent"):
            if (ns.find('a')) and (response.status_code == 200):
                date=s.find("div",class_= "date").string
                name=s.find('a').string
                push=s.find("div",class_= "nrec").string
                author=s.find("div",class_= "author").string
                url=s.find("div",class_= "title").a["href"]
                articles.append({'title': name,'push': push,'date': date,'author': author,'url': "https://www.ptt.cc"+url}) 
    articles_pd=pd.DataFrame(articles)
    
    if want_excel:
        articles_pd.to_excel("pttcrawler.xlsx")
    return articles

# %%
a

# %%
cdcd=pttcrawler("https://www.ptt.cc/bbs/PttEsports/index.html",1)
cdcd
# Out:
# -7
# [{'title': '[LOL.] 去吧綠巨人 勝',
#   'push': None,
#   'date': ' 9/09',
#   'author': 'HiBon',
#   'url': 'https://www.ptt.cc/bbs/PttEsports/M.1473425316.A.C6E.html'},
#  {'title': '[LOL.] 上路最狂 勝',
#   'push': None,
#   'date': ' 9/09',
#   'author': 'stwkc88',
#   'url': 'https://www.ptt.cc/bbs/PttEsports/M.1473425599.A.32D.html'},
#  {'title': '[LOL.] 哈囉你好嗎 勝',
#   'push': None,
#   'date': ' 9/09',
#   'author': 'fishpill',
#   'url': 'https://www.ptt.cc/bbs/PttEsports/M.1473426425.A.613.html'},
#  {'title': '[LOL.] 添志絕不遲到 勝',
#   'push': None,
#   'date': ' 9/11',
#   'author': 'vic199835',
#   'url': 'https://www.ptt.cc/bbs/PttEsports/M.1473569205.A.AB3.html'},
#  {'title': '[LOL.] 土龍這一家 勝',
#   'push': None,
#   'date': ' 9/12',
#   'author': 'blsy4300145',
#   'url': 'https://www.ptt.cc/bbs/PttEsports/M.1473681917.A.83F.html'},
#  {'title': '[LOL.] MLT 勝',
#   'push': None,
#   'date': ' 9/12',
#   'author': 'aa155186',
# ...

# %%
import requests as rq
from bs4 import BeautifulSoup
#想要知道Quantic Foundary公司blog的貼文資訊
def QFcrawler(url):
    response = rq.get(url)
    html_doc = response.text
    soups = BeautifulSoup(html_doc, 'lxml')
    
    articles = []
    i=0
    
    for s in soups.find_all("div", class_="fusion-post-content post-content"):
        if s.find('a'):#如果存在超連結的情況，才進行下一步動作
            #date=s.find("div",class_= "date").string
            name=s.find('a').string
            author=s.find('p').a.string
            #push=s.find("div",class_= "nrec").string
            #articles.append({'title': name,'push': push,'date': date})
            articles.append({'title': name,'author': author}) 
    return articles

# %%
QFcrawler("https://quanticfoundry.com/blog/")
# Out:
# [{'title': 'Podcast: Analyzing Gamer Behavior, Psychology, and Motivations',
#   'author': 'Nick Yee'},
#  {'title': 'GDC 2019 Talk Video + Updated Reference Sheets',
#   'author': 'Nick Yee'},
#  {'title': 'Older Gamers Who Can Afford VR Tend to Care Less About the Gaming Motivations Linked to VR Adoption',
#   'author': 'Nick Yee'},
#  {'title': 'Chinese Gamers are More Competitive and Completionist, More Homogeneous in Gaming Motivations Than US Gamers',
#   'author': 'Nick Yee'},
#  {'title': 'What Men and Women Consider Hardcore Gaming Are Not The Same',
#   'author': 'Nick Yee'},
#  {'title': 'Visualizing How Steam Tags Are Related', 'author': 'Nick Yee'},
#  {'title': 'Just How Important Are Female Protagonists?',
#   'author': 'Nick Yee'},
#  {'title': 'Solo Board Gamers: Who Are The 1%?', 'author': 'Nick Yee'},
#  {'title': 'The Primary Motivations of Board Gamers: 7 Takeaways',
#   'author': 'Nick Yee'},
#  {'title': 'Competition Is Not The Opposite of Community',
# ...

# %%
import requests

res = requests.get("https://shopee.tw/djdhqishhsh")

print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#
#     <link
#       rel="preconnect"
#       href="//cf.shopee.tw/"
#     />
#
#     <link
#       rel="preconnect"
#       href="//deo.shopeemobile.com/shopee/"
#     />
#
#     <link
#       rel="preconnect"
#       href="//cv.shopee.tw/"
#     />
#
#
#     <meta charset="utf-8" />
#     <meta
#       name="viewport"
#       content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no, viewport-fit=cover"
#     />
#     <meta name="shopee:git-sha" content="67fb03ee7f5efb327eadab445f645dd653e29cbc">
#     <meta name="shopee:version" content="rw-v3.33.0">
#
#     <script>
#       window.__LOCALE__ = 'TW';
#       window.__ENV__ = 'live';
# ...

# %%
import requests

headers = {'user-agent': 'Mozilla/5.0 (Macintosh Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}

res = requests.get("https://shopee.tw/api/v2/search_items/?by=pop&limit=30&match_id=3625341&newest=0&order=desc&page_type=shop", headers=headers)
print(res.request.headers)    # 看requests送出的header
print(res.text)
# Out:
# {'user-agent': 'Mozilla/5.0 (Macintosh Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# ...
